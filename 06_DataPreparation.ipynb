# %%
import pandas as pd
import numpy as np

import seaborn as sns

from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("dados/train_complete.csv")
df.drop(['exchange_exchange'], axis=1, inplace=True)
df.set_index('Date', inplace=True)

# %% [markdown]
# ## Verificando Missing Values

# %%
round(((df.isna().sum().sort_values(ascending=False) / df.shape[0]) * 100), 2).value_counts()
# Out:
# 0.0    118
# Name: count, dtype: int64

# %%
df.isna().sum().value_counts()
# Out:
# 0    118
# Name: count, dtype: int64

# %% [markdown]
# ---
# # Seleção de variáveis
# ---

# %% [markdown]
# ## Causalidade de Granger

# %% [markdown]
# #### Estacionarização das séries

# %%
extra_cols = [
    'epu_pt_epu', 'unemployment_up_15_unemployment', 
    'PPIPT_ppi', 'inflation_target'
]

# %%
def stationary(x, col_name):
    # Aplicar teste
    result = kpss(x, regression='ct')

    # outputs principais
    print("=" * 40)
    print(f"Coluna: {col_name.split('_')[0]}")
    print("=" * 40)
    print('KPSS Statistic:', result[0])
    print('p-value:', result[1])
    print('Estacionária: ', result[1] >= 0.05)
    if not result[1] >= 0.05:
        d = ndiffs(x, test='kpss')
        print('   Diferenciações necessárias: ', d)
    print('Critical Values:', result[3])

# %%
from statsmodels.tsa.stattools import kpss
from pmdarima.arima.utils import ndiffs

for col in extra_cols:
    stationary(df[col], col)
print("=" * 40)
# Out:
# ========================================
# Coluna: epu
# ========================================
# KPSS Statistic: 0.10632577368114085
# p-value: 0.1
# Estacionária:  True
# Critical Values: {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216}
# ========================================
# Coluna: unemployment
# ========================================
# KPSS Statistic: 0.566222230106766
# p-value: 0.01
# Estacionária:  False
#    Diferenciações necessárias:  2
# Critical Values: {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216}
# ========================================
# Coluna: PPIPT
# ========================================
# KPSS Statistic: 0.18314680755851132
# p-value: 0.022319947165558254
# Estacionária:  False
#    Diferenciações necessárias:  0
# Critical Values: {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216}
# ========================================
# Coluna: inflation
# ========================================
# KPSS Statistic: 0.21933157424062677
# p-value: 0.01
# Estacionária:  False
#    Diferenciações necessárias:  1
# Critical Values: {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216}
# ========================================
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2000138784.py:3: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   result = kpss(x, regression='ct')
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2000138784.py:3: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(x, regression='ct')
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2000138784.py:3: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(x, regression='ct')

# %% [markdown]
# Variáveis extras não estacionárias:
# - `unemployment`: duas diferenciações
# - `PPIPT`: ponderando aplicar um logaritmo somando `x` com `k`
#     - `k=min(x)+0.1`
# - `inflation`: uma diferenciação

# %%
extra_cols
# Out:
# ['epu_pt_epu',
#  'unemployment_up_15_unemployment',
#  'PPIPT_ppi',
#  'inflation_target']

# %%
abs(df['PPIPT_ppi'].min())
# Out:
# 6.2

# %%
stationary(df['unemployment_up_15_unemployment'].diff(2).dropna(), 'unemployment_up_15_unemployment')
stationary(df['inflation_target'].diff().dropna(), 'inflation_target')
stationary(np.log(df['PPIPT_ppi'] + abs(df['PPIPT_ppi'].min()) + 0.1), 'PPIPT_ppi')
stationary(df['PPIPT_ppi'].diff().dropna(), 'PPIPT_ppi Diff')
# Out:
# ========================================
# Coluna: unemployment
# ========================================
# KPSS Statistic: 0.14213625188215845
# p-value: 0.05715508910711397
# Estacionária:  True
# Critical Values: {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216}
# ========================================
# Coluna: inflation
# ========================================
# KPSS Statistic: 0.03548879679680336
# p-value: 0.1
# Estacionária:  True
# Critical Values: {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216}
# ========================================
# Coluna: PPIPT
# ========================================
# KPSS Statistic: 0.10258172126764203
# p-value: 0.1
# Estacionária:  True
# Critical Values: {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216}
# ========================================
# Coluna: PPIPT
# ========================================
# KPSS Statistic: 0.061870201956840815
# p-value: 0.1
# Estacionária:  True
# Critical Values: {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216}
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2000138784.py:3: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   result = kpss(x, regression='ct')
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2000138784.py:3: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   result = kpss(x, regression='ct')
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2000138784.py:3: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   result = kpss(x, regression='ct')

# %%
cols_fred_global = [
    'INDPRO', 'IPFINAL', 'IPCONGD',
    'AWOTMAN', 'AWHMAN', 'FEDFUNDS', 'GS1', 'GS5',
    'GS10', 'AAA', 'BAA', 'OILPRICEx', 'CUSR0000SAC',
    'PCEPI', 'S&P 500'
]

new_name = {col:f'{col}_fred-md' for col in cols_fred_global}

df_fred_md = pd.read_csv("dados/2026-01-MD.csv")[cols_fred_global].rename(new_name, axis=1)
df_fred_md.rename({'OILPRICEx_fred-md': 'OILPRICEx_fred-md_Eur'}, axis=1, inplace=True)
df_fred_md.iloc[0]
# Out:
# INDPRO_fred-md           5.0
# IPFINAL_fred-md          5.0
# IPCONGD_fred-md          5.0
# AWOTMAN_fred-md          2.0
# AWHMAN_fred-md           1.0
# FEDFUNDS_fred-md         2.0
# GS1_fred-md              2.0
# GS5_fred-md              2.0
# GS10_fred-md             2.0
# AAA_fred-md              2.0
# BAA_fred-md              2.0
# OILPRICEx_fred-md_Eur    6.0
# CUSR0000SAC_fred-md      6.0
# PCEPI_fred-md            6.0
# S&P 500_fred-md          5.0
# Name: 0, dtype: float64

# %%
df_ea_md_qd = pd.read_excel("dados/EA-MD-QD-2026-02/raw/PTdata.xlsx", sheet_name='info')[['Name', 'TR1', 'Frequency']]

ea_transform = dict()
for idx in range(df_ea_md_qd.shape[0]):
    name, val, freq = df_ea_md_qd.iloc[idx]
    name = f'{name}_ea-md' if freq == 'M' else f'{name}_ea-qd'
    ea_transform[name] = val

pd.Series(ea_transform)[0:10]
# Out:
# GDP_PT_ea-qd       2
# EXPGS_PT_ea-qd     2
# IMPGS_PT_ea-qd     2
# GFCE_PT_ea-qd      2
# HFCE_PT_ea-qd      2
# CONSD_PT_ea-qd     2
# GCF_PT_ea-qd       2
# GFCF_PT_ea-qd      2
# GFACON_PT_ea-qd    2
# GFAMG_PT_ea-qd     2
# dtype: int64

# %%
def stacionarize_fred(X, code):
    if code == 1: return X
    elif code == 2: return X.diff()
    elif code == 3: return X.diff(2)
    elif code == 4: return np.log(X)
    elif code == 5: return np.log(X).diff()
    elif code == 6: return np.log(X).diff(2)
    return (X/X.shift() - 1).diff()


def stacionarize_ea(X, code):
    if code == 1: return 100 * stacionarize_fred(X, 4)
    elif code == 2: return 100 * stacionarize_fred(X, 5)
    elif code == 3: return 100 * stacionarize_fred(stacionarize_fred(X, 4), 3)
    elif code == 4: return X
    return stacionarize_fred(X, 2)

# %%
df_stacionary = df[['epu_pt_epu', 'PPIPT_ppi']].copy()

df_stacionary['unemployment_up_15_unemployment'] = stacionarize_fred(df['unemployment_up_15_unemployment'], 3)
df_stacionary['inflation_target'] = stacionarize_fred(df['inflation_target'], 2)
# df_stacionary['PPIPT_ppi'] = np.log(df['PPIPT_ppi'] + abs(df['PPIPT_ppi'].min()) + 0.1)

# Estacionarizando as variáveis da FRED-MD
for idx, val in df_fred_md.iloc[0].items():
    df_stacionary[idx] = stacionarize_fred(df[idx], val)
    
# Estacionarizando as variáveis da EA-MD-QD
for idx, val in pd.Series(ea_transform)[0:81].items():
    df_stacionary[idx] = stacionarize_ea(df[idx], val)

# %%
# Rode mais uma vez se não gostas de estar a ver estes warnings :)

for idx, val in pd.Series(ea_transform)[81:].items():
    df_stacionary[idx] = stacionarize_ea(df[idx], val)

df_stacionary.head()
# Out:
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2629099123.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_stacionary[idx] = stacionarize_ea(df[idx], val)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2629099123.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_stacionary[idx] = stacionarize_ea(df[idx], val)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2629099123.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_stacionary[idx] = stacionarize_ea(df[idx], val)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2629099123.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_stacionary[idx] = stacionarize_ea(df[idx], val)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2629099123.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_stacionary[idx] = stacionarize_ea(df[idx], val)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2629099123.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_stacionary[idx] = stacionarize_ea(df[idx], val)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2629099123.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_stacionary[idx] = stacionarize_ea(df[idx], val)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2629099123.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_stacionary[idx] = stacionarize_ea(df[idx], val)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2629099123.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_stacionary[idx] = stacionarize_ea(df[idx], val)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2629099123.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_stacionary[idx] = stacionarize_ea(df[idx], val)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2629099123.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_stacionary[idx] = stacionarize_ea(df[idx], val)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2629099123.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_stacionary[idx] = stacionarize_ea(df[idx], val)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2629099123.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_stacionary[idx] = stacionarize_ea(df[idx], val)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2629099123.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_stacionary[idx] = stacionarize_ea(df[idx], val)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2629099123.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_stacionary[idx] = stacionarize_ea(df[idx], val)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2629099123.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_stacionary[idx] = stacionarize_ea(df[idx], val)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\2629099123.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_stacionary[idx] = stacionarize_ea(df[idx], val)
#             epu_pt_epu  PPIPT_ppi  unemployment_up_15_unemployment  \
# Date
# 2000-01-01  107.096201       21.5                              NaN
# 2000-02-01  105.539878       21.9                              NaN
# 2000-03-01   68.844150       21.2                             -0.3
# 2000-04-01   70.292778       20.0                             -0.2
# 2000-05-01   78.451666       17.9                              0.0
#
#             inflation_target  INDPRO_fred-md  IPFINAL_fred-md  \
# Date
# 2000-01-01               NaN             NaN              NaN
# 2000-02-01              -0.3        0.003118         0.005419
# 2000-03-01              -0.3        0.003549         0.000055
# 2000-04-01               0.6        0.005935         0.007305
# 2000-05-01               0.4        0.002704         0.002443
#
#             IPCONGD_fred-md  AWOTMAN_fred-md  AWHMAN_fred-md  \
# Date
# 2000-01-01              NaN              NaN            41.5
# 2000-02-01         0.006679              0.1            41.5
# 2000-03-01        -0.004811             -0.3            41.4
# 2000-04-01         0.007288              0.1            41.6
# 2000-05-01         0.000960             -0.1            41.2
#
#             FEDFUNDS_fred-md  ...  DFGDP_PT_ea-qd  ICONFIX_PT_ea-md  \
# Date                          ...
# 2000-01-01               NaN  ...             NaN               7.3
# 2000-02-01              0.28  ...        0.446157               8.9
# 2000-03-01              0.12  ...        0.823810               7.7
# 2000-04-01              0.17  ...       -0.241874               8.8
# 2000-05-01              0.25  ...        0.362385              10.1
#
#             CCONFIX_PT_ea-md  ESENTIX_PT_ea-md  KCONFIX_PT_ea-md  \
# Date
# 2000-01-01              -2.4             113.9               NaN
# 2000-02-01              -3.0             116.7              10.2
# 2000-03-01              -3.2             116.2               5.5
# 2000-04-01              -9.2             114.1             -13.4
# 2000-05-01              -8.0             113.3               9.8
#
#             RTCONFIX_PT_ea-md  SCONFIX_PT_ea-md  BCI_PT_ea-md  CCI_PT_ea-md  \
# Date
# 2000-01-01                9.4              10.3      102.2262      102.3880
# 2000-02-01               11.0              14.2      102.5146      102.2470
# 2000-03-01               11.7              11.9      102.6476      101.9521
# 2000-04-01                6.1              13.2      102.7988      101.5175
# 2000-05-01                1.5               6.0      102.8972      101.2843
#
#             SHIX_PT_ea-md
# Date
# 2000-01-01            NaN
# 2000-02-01      12.366348
# 2000-03-01       2.686605
# 2000-04-01     -10.407950
# 2000-05-01      -3.188878
#
# [5 rows x 118 columns]

# %%
from statsmodels.tsa.stattools import grangercausalitytests

# Perform Granger-Causality test
importancesCG = dict()
for causador in df_stacionary.drop('inflation_target', axis=1).columns:
    result = grangercausalitytests(df_stacionary[['inflation_target', causador]].dropna(), maxlag=[6])
    p_value = result[6][0]['ssr_ftest'][1]
    if p_value < 0.05:
        importancesCG[causador] = p_value
# Out:
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.4148  , p=0.8689  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=2.6121  , p=0.8557  , df=6
# likelihood ratio test: chi2=2.5998  , p=0.8571  , df=6
# parameter F test:         F=0.4148  , p=0.8689  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=5.3603  , p=0.0000  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=33.7574 , p=0.0000  , df=6
# likelihood ratio test: chi2=31.8408 , p=0.0000  , df=6
# parameter F test:         F=5.3603  , p=0.0000  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3172  , p=0.2496  , df_denom=261, df_num=6
# ssr based chi2 test:   chi2=8.2970  , p=0.2171  , df=6
# likelihood ratio test: chi2=8.1739  , p=0.2256  , df=6
# parameter F test:         F=1.3172  , p=0.2496  , df_denom=261, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.5442  , p=0.1640  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=9.7248  , p=0.1367  , df=6
# likelihood ratio test: chi2=9.5568  , p=0.1446  , df=6
# parameter F test:         F=1.5442  , p=0.1640  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9251  , p=0.4773  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=5.8260  , p=0.4430  , df=6
# likelihood ratio test: chi2=5.7651  , p=0.4500  , df=6
# parameter F test:         F=0.9251  , p=0.4773  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8411  , p=0.5391  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=5.2971  , p=0.5063  , df=6
# likelihood ratio test: chi2=5.2467  , p=0.5126  , df=6
# parameter F test:         F=0.8411  , p=0.5391  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.5083  , p=0.1756  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=9.4988  , p=0.1474  , df=6
# likelihood ratio test: chi2=9.3384  , p=0.1554  , df=6
# parameter F test:         F=1.5083  , p=0.1756  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3237  , p=0.2467  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=8.3363  , p=0.2145  , df=6
# likelihood ratio test: chi2=8.2125  , p=0.2229  , df=6
# parameter F test:         F=1.3237  , p=0.2467  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.4194  , p=0.2073  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=8.9388  , p=0.1770  , df=6
# likelihood ratio test: chi2=8.7966  , p=0.1853  , df=6
# parameter F test:         F=1.4194  , p=0.2073  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.2331  , p=0.0405  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=14.0633 , p=0.0289  , df=6
# likelihood ratio test: chi2=13.7155 , p=0.0330  , df=6
# parameter F test:         F=2.2331  , p=0.0405  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.1437  , p=0.0489  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=13.5005 , p=0.0357  , df=6
# likelihood ratio test: chi2=13.1796 , p=0.0403  , df=6
# parameter F test:         F=2.1437  , p=0.0489  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.1296  , p=0.3453  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=7.1138  , p=0.3104  , df=6
# likelihood ratio test: chi2=7.0234  , p=0.3187  , df=6
# parameter F test:         F=1.1296  , p=0.3453  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8314  , p=0.5465  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=5.2358  , p=0.5139  , df=6
# likelihood ratio test: chi2=5.1866  , p=0.5201  , df=6
# parameter F test:         F=0.8314  , p=0.5465  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7958  , p=0.5739  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=5.0116  , p=0.5423  , df=6
# likelihood ratio test: chi2=4.9665  , p=0.5481  , df=6
# parameter F test:         F=0.7958  , p=0.5739  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=4.1916  , p=0.0005  , df_denom=261, df_num=6
# ssr based chi2 test:   chi2=26.4025 , p=0.0002  , df=6
# likelihood ratio test: chi2=25.2067 , p=0.0003  , df=6
# parameter F test:         F=4.1916  , p=0.0005  , df_denom=261, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=4.2829  , p=0.0004  , df_denom=261, df_num=6
# ssr based chi2 test:   chi2=26.9771 , p=0.0001  , df=6
# likelihood ratio test: chi2=25.7302 , p=0.0002  , df=6
# parameter F test:         F=4.2829  , p=0.0004  , df_denom=261, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.3204  , p=0.0036  , df_denom=261, df_num=6
# ssr based chi2 test:   chi2=20.9149 , p=0.0019  , df=6
# likelihood ratio test: chi2=20.1551 , p=0.0026  , df=6
# parameter F test:         F=3.3204  , p=0.0036  , df_denom=261, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.4936  , p=0.8129  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=3.1084  , p=0.7951  , df=6
# likelihood ratio test: chi2=3.0910  , p=0.7973  , df=6
# parameter F test:         F=0.4936  , p=0.8129  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.1010  , p=0.3621  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=6.9336  , p=0.3270  , df=6
# likelihood ratio test: chi2=6.8476  , p=0.3352  , df=6
# parameter F test:         F=1.1010  , p=0.3621  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7704  , p=0.5938  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=4.8519  , p=0.5629  , df=6
# likelihood ratio test: chi2=4.8096  , p=0.5685  , df=6
# parameter F test:         F=0.7704  , p=0.5938  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0611  , p=0.3864  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=6.6828  , p=0.3512  , df=6
# likelihood ratio test: chi2=6.6029  , p=0.3591  , df=6
# parameter F test:         F=1.0611  , p=0.3864  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9530  , p=0.4577  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=6.0016  , p=0.4230  , df=6
# likelihood ratio test: chi2=5.9370  , p=0.4303  , df=6
# parameter F test:         F=0.9530  , p=0.4577  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0199  , p=0.4126  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=6.4230  , p=0.3775  , df=6
# likelihood ratio test: chi2=6.3491  , p=0.3852  , df=6
# parameter F test:         F=1.0199  , p=0.4126  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9714  , p=0.4450  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=6.1178  , p=0.4101  , df=6
# likelihood ratio test: chi2=6.0507  , p=0.4175  , df=6
# parameter F test:         F=0.9714  , p=0.4450  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.1158  , p=0.3533  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=7.0271  , p=0.3184  , df=6
# likelihood ratio test: chi2=6.9388  , p=0.3265  , df=6
# parameter F test:         F=1.1158  , p=0.3533  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9848  , p=0.4359  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=6.2020  , p=0.4009  , df=6
# likelihood ratio test: chi2=6.1331  , p=0.4084  , df=6
# parameter F test:         F=0.9848  , p=0.4359  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8189  , p=0.5560  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=5.1575  , p=0.5238  , df=6
# likelihood ratio test: chi2=5.1097  , p=0.5298  , df=6
# parameter F test:         F=0.8189  , p=0.5560  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.4196  , p=0.2072  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=8.9402  , p=0.1770  , df=6
# likelihood ratio test: chi2=8.7979  , p=0.1853  , df=6
# parameter F test:         F=1.4196  , p=0.2072  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.2800  , p=0.2667  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=8.0612  , p=0.2337  , df=6
# likelihood ratio test: chi2=7.9453  , p=0.2421  , df=6
# parameter F test:         F=1.2800  , p=0.2667  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.1289  , p=0.9926  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=0.8120  , p=0.9917  , df=6
# likelihood ratio test: chi2=0.8108  , p=0.9918  , df=6
# parameter F test:         F=0.1289  , p=0.9926  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9254  , p=0.4771  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=5.8277  , p=0.4428  , df=6
# likelihood ratio test: chi2=5.7668  , p=0.4498  , df=6
# parameter F test:         F=0.9254  , p=0.4771  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.1633  , p=0.3264  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=7.3259  , p=0.2918  , df=6
# likelihood ratio test: chi2=7.2300  , p=0.3001  , df=6
# parameter F test:         F=1.1633  , p=0.3264  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7368  , p=0.6204  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=4.6401  , p=0.5907  , df=6
# likelihood ratio test: chi2=4.6013  , p=0.5959  , df=6
# parameter F test:         F=0.7368  , p=0.6204  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.2388  , p=0.2867  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=7.8018  , p=0.2530  , df=6
# likelihood ratio test: chi2=7.6932  , p=0.2615  , df=6
# parameter F test:         F=1.2388  , p=0.2867  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.4859  , p=0.1831  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=9.3579  , p=0.1544  , df=6
# likelihood ratio test: chi2=9.2022  , p=0.1625  , df=6
# parameter F test:         F=1.4859  , p=0.1831  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7718  , p=0.5927  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=4.8608  , p=0.5618  , df=6
# likelihood ratio test: chi2=4.8184  , p=0.5673  , df=6
# parameter F test:         F=0.7718  , p=0.5927  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.2144  , p=0.9720  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=1.3503  , p=0.9688  , df=6
# likelihood ratio test: chi2=1.3470  , p=0.9690  , df=6
# parameter F test:         F=0.2144  , p=0.9720  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.5815  , p=0.1527  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=9.9598  , p=0.1264  , df=6
# likelihood ratio test: chi2=9.7837  , p=0.1341  , df=6
# parameter F test:         F=1.5815  , p=0.1527  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.4152  , p=0.2089  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=8.9123  , p=0.1786  , df=6
# likelihood ratio test: chi2=8.7710  , p=0.1869  , df=6
# parameter F test:         F=1.4152  , p=0.2089  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5866  , p=0.7409  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=3.6942  , p=0.7180  , df=6
# likelihood ratio test: chi2=3.6696  , p=0.7213  , df=6
# parameter F test:         F=0.5866  , p=0.7409  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7802  , p=0.5861  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=4.9138  , p=0.5549  , df=6
# likelihood ratio test: chi2=4.8704  , p=0.5605  , df=6
# parameter F test:         F=0.7802  , p=0.5861  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.2551  , p=0.2786  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=7.9044  , p=0.2452  , df=6
# likelihood ratio test: chi2=7.7929  , p=0.2537  , df=6
# parameter F test:         F=1.2551  , p=0.2786  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5617  , p=0.7606  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=3.5372  , p=0.7390  , df=6
# likelihood ratio test: chi2=3.5147  , p=0.7420  , df=6
# parameter F test:         F=0.5617  , p=0.7606  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6285  , p=0.7075  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=3.9578  , p=0.6824  , df=6
# likelihood ratio test: chi2=3.9296  , p=0.6862  , df=6
# parameter F test:         F=0.6285  , p=0.7075  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.2320  , p=0.9659  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=1.4613  , p=0.9620  , df=6
# likelihood ratio test: chi2=1.4575  , p=0.9623  , df=6
# parameter F test:         F=0.2320  , p=0.9659  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.3600  , p=0.9036  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=2.2674  , p=0.8935  , df=6
# likelihood ratio test: chi2=2.2581  , p=0.8945  , df=6
# parameter F test:         F=0.3600  , p=0.9036  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.3768  , p=0.0297  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=14.9683 , p=0.0205  , df=6
# likelihood ratio test: chi2=14.5752 , p=0.0238  , df=6
# parameter F test:         F=2.3768  , p=0.0297  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8325  , p=0.5457  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=5.2427  , p=0.5131  , df=6
# likelihood ratio test: chi2=5.1933  , p=0.5193  , df=6
# parameter F test:         F=0.8325  , p=0.5457  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8303  , p=0.5473  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=5.2289  , p=0.5148  , df=6
# likelihood ratio test: chi2=5.1798  , p=0.5210  , df=6
# parameter F test:         F=0.8303  , p=0.5473  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.4319  , p=0.2026  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=9.0180  , p=0.1726  , df=6
# likelihood ratio test: chi2=8.8733  , p=0.1808  , df=6
# parameter F test:         F=1.4319  , p=0.2026  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8844  , p=0.5068  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=5.5698  , p=0.4731  , df=6
# likelihood ratio test: chi2=5.5141  , p=0.4798  , df=6
# parameter F test:         F=0.8844  , p=0.5068  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8695  , p=0.5178  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=5.4758  , p=0.4844  , df=6
# likelihood ratio test: chi2=5.4220  , p=0.4909  , df=6
# parameter F test:         F=0.8695  , p=0.5178  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.1527  , p=0.9884  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=0.9616  , p=0.9870  , df=6
# likelihood ratio test: chi2=0.9599  , p=0.9871  , df=6
# parameter F test:         F=0.1527  , p=0.9884  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.1656  , p=0.3251  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=7.3404  , p=0.2905  , df=6
# likelihood ratio test: chi2=7.2441  , p=0.2989  , df=6
# parameter F test:         F=1.1656  , p=0.3251  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7704  , p=0.5938  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=4.8516  , p=0.5630  , df=6
# likelihood ratio test: chi2=4.8093  , p=0.5685  , df=6
# parameter F test:         F=0.7704  , p=0.5938  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9655  , p=0.4490  , df_denom=261, df_num=6
# ssr based chi2 test:   chi2=6.0816  , p=0.4141  , df=6
# likelihood ratio test: chi2=6.0151  , p=0.4215  , df=6
# parameter F test:         F=0.9655  , p=0.4490  , df_denom=261, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9926  , p=0.4307  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=6.2510  , p=0.3957  , df=6
# likelihood ratio test: chi2=6.1810  , p=0.4032  , df=6
# parameter F test:         F=0.9926  , p=0.4307  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.4687  , p=0.8312  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=2.9519  , p=0.8149  , df=6
# likelihood ratio test: chi2=2.9362  , p=0.8168  , df=6
# parameter F test:         F=0.4687  , p=0.8312  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9219  , p=0.4796  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=5.8057  , p=0.4453  , df=6
# likelihood ratio test: chi2=5.7453  , p=0.4523  , df=6
# parameter F test:         F=0.9219  , p=0.4796  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7297  , p=0.6261  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=4.5955  , p=0.5966  , df=6
# likelihood ratio test: chi2=4.5575  , p=0.6017  , df=6
# parameter F test:         F=0.7297  , p=0.6261  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.4330  , p=0.8565  , df_denom=261, df_num=6
# ssr based chi2 test:   chi2=2.7276  , p=0.8422  , df=6
# likelihood ratio test: chi2=2.7142  , p=0.8438  , df=6
# parameter F test:         F=0.4330  , p=0.8565  , df_denom=261, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7390  , p=0.6186  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=4.6543  , p=0.5889  , df=6
# likelihood ratio test: chi2=4.6153  , p=0.5940  , df=6
# parameter F test:         F=0.7390  , p=0.6186  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0744  , p=0.3782  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=6.7660  , p=0.3430  , df=6
# likelihood ratio test: chi2=6.6841  , p=0.3510  , df=6
# parameter F test:         F=1.0744  , p=0.3782  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6191  , p=0.7150  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=3.8989  , p=0.6904  , df=6
# likelihood ratio test: chi2=3.8715  , p=0.6941  , df=6
# parameter F test:         F=0.6191  , p=0.7150  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.2336  , p=0.2893  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=7.7686  , p=0.2556  , df=6
# likelihood ratio test: chi2=7.6609  , p=0.2640  , df=6
# parameter F test:         F=1.2336  , p=0.2893  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.7029  , p=0.1205  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=10.7242 , p=0.0973  , df=6
# likelihood ratio test: chi2=10.5204 , p=0.1044  , df=6
# parameter F test:         F=1.7029  , p=0.1205  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7933  , p=0.5759  , df_denom=261, df_num=6
# ssr based chi2 test:   chi2=4.9967  , p=0.5442  , df=6
# likelihood ratio test: chi2=4.9517  , p=0.5500  , df=6
# parameter F test:         F=0.7933  , p=0.5759  , df_denom=261, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.1701  , p=0.9846  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=1.0715  , p=0.9828  , df=6
# likelihood ratio test: chi2=1.0695  , p=0.9828  , df=6
# parameter F test:         F=0.1701  , p=0.9846  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.1548  , p=0.9880  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=0.9746  , p=0.9866  , df=6
# likelihood ratio test: chi2=0.9728  , p=0.9866  , df=6
# parameter F test:         F=0.1548  , p=0.9880  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.2566  , p=0.9563  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=1.6161  , p=0.9514  , df=6
# likelihood ratio test: chi2=1.6114  , p=0.9518  , df=6
# parameter F test:         F=0.2566  , p=0.9563  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.4218  , p=0.8642  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=2.6564  , p=0.8506  , df=6
# likelihood ratio test: chi2=2.6436  , p=0.8521  , df=6
# parameter F test:         F=0.4218  , p=0.8642  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.2101  , p=0.9734  , df_denom=261, df_num=6
# ssr based chi2 test:   chi2=1.3232  , p=0.9704  , df=6
# likelihood ratio test: chi2=1.3200  , p=0.9705  , df=6
# parameter F test:         F=0.2101  , p=0.9734  , df_denom=261, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.4574  , p=0.8394  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=2.8804  , p=0.8237  , df=6
# likelihood ratio test: chi2=2.8654  , p=0.8255  , df=6
# parameter F test:         F=0.4574  , p=0.8394  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.1696  , p=0.9847  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=1.0679  , p=0.9829  , df=6
# likelihood ratio test: chi2=1.0658  , p=0.9830  , df=6
# parameter F test:         F=0.1696  , p=0.9847  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5801  , p=0.7461  , df_denom=261, df_num=6
# ssr based chi2 test:   chi2=3.6538  , p=0.7234  , df=6
# likelihood ratio test: chi2=3.6296  , p=0.7267  , df=6
# parameter F test:         F=0.5801  , p=0.7461  , df_denom=261, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.4033  , p=0.8765  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=2.5400  , p=0.8640  , df=6
# likelihood ratio test: chi2=2.5283  , p=0.8653  , df=6
# parameter F test:         F=0.4033  , p=0.8765  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.0266  , p=0.0625  , df_denom=261, df_num=6
# ssr based chi2 test:   chi2=12.7651 , p=0.0469  , df=6
# likelihood ratio test: chi2=12.4767 , p=0.0521  , df=6
# parameter F test:         F=2.0266  , p=0.0625  , df_denom=261, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7548  , p=0.6061  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=4.7537  , p=0.5758  , df=6
# likelihood ratio test: chi2=4.7131  , p=0.5811  , df=6
# parameter F test:         F=0.7548  , p=0.6061  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.3615  , p=0.9028  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=2.2766  , p=0.8926  , df=6
# likelihood ratio test: chi2=2.2672  , p=0.8936  , df=6
# parameter F test:         F=0.3615  , p=0.9028  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6273  , p=0.7084  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=3.9504  , p=0.6834  , df=6
# likelihood ratio test: chi2=3.9223  , p=0.6872  , df=6
# parameter F test:         F=0.6273  , p=0.7084  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.2462  , p=0.2830  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=7.8484  , p=0.2494  , df=6
# likelihood ratio test: chi2=7.7385  , p=0.2579  , df=6
# parameter F test:         F=1.2462  , p=0.2830  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.6987  , p=0.1215  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=10.6980 , p=0.0982  , df=6
# likelihood ratio test: chi2=10.4951 , p=0.1053  , df=6
# parameter F test:         F=1.6987  , p=0.1215  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5312  , p=0.7844  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=3.3452  , p=0.7644  , df=6
# likelihood ratio test: chi2=3.3250  , p=0.7671  , df=6
# parameter F test:         F=0.5312  , p=0.7844  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.7511  , p=0.1095  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=11.0281 , p=0.0875  , df=6
# likelihood ratio test: chi2=10.8127 , p=0.0943  , df=6
# parameter F test:         F=1.7511  , p=0.1095  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6658  , p=0.6774  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=4.1932  , p=0.6506  , df=6
# likelihood ratio test: chi2=4.1615  , p=0.6548  , df=6
# parameter F test:         F=0.6658  , p=0.6774  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.2555  , p=0.0386  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=14.2042 , p=0.0274  , df=6
# likelihood ratio test: chi2=13.8495 , p=0.0314  , df=6
# parameter F test:         F=2.2555  , p=0.0386  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6911  , p=0.6570  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=4.3526  , p=0.6291  , df=6
# likelihood ratio test: chi2=4.3185  , p=0.6337  , df=6
# parameter F test:         F=0.6911  , p=0.6570  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.2921  , p=0.2610  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=8.1376  , p=0.2282  , df=6
# likelihood ratio test: chi2=8.0195  , p=0.2367  , df=6
# parameter F test:         F=1.2921  , p=0.2610  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3007  , p=0.2571  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=8.1914  , p=0.2244  , df=6
# likelihood ratio test: chi2=8.0718  , p=0.2329  , df=6
# parameter F test:         F=1.3007  , p=0.2571  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.2804  , p=0.2665  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=8.0636  , p=0.2335  , df=6
# likelihood ratio test: chi2=7.9477  , p=0.2420  , df=6
# parameter F test:         F=1.2804  , p=0.2665  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6763  , p=0.6690  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=4.2589  , p=0.6417  , df=6
# likelihood ratio test: chi2=4.2262  , p=0.6461  , df=6
# parameter F test:         F=0.6763  , p=0.6690  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.4743  , p=0.1872  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=9.2850  , p=0.1582  , df=6
# likelihood ratio test: chi2=9.1317  , p=0.1663  , df=6
# parameter F test:         F=1.4743  , p=0.1872  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0798  , p=0.3749  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=6.8001  , p=0.3397  , df=6
# likelihood ratio test: chi2=6.7174  , p=0.3478  , df=6
# parameter F test:         F=1.0798  , p=0.3749  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.5037  , p=0.1771  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=9.4700  , p=0.1488  , df=6
# likelihood ratio test: chi2=9.3106  , p=0.1569  , df=6
# parameter F test:         F=1.5037  , p=0.1771  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8941  , p=0.4997  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=5.6307  , p=0.4658  , df=6
# likelihood ratio test: chi2=5.5738  , p=0.4726  , df=6
# parameter F test:         F=0.8941  , p=0.4997  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8575  , p=0.5268  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=5.4000  , p=0.4936  , df=6
# likelihood ratio test: chi2=5.3477  , p=0.5001  , df=6
# parameter F test:         F=0.8575  , p=0.5268  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6649  , p=0.6781  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=4.1875  , p=0.6513  , df=6
# likelihood ratio test: chi2=4.1559  , p=0.6556  , df=6
# parameter F test:         F=0.6649  , p=0.6781  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7112  , p=0.6409  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=4.4790  , p=0.6121  , df=6
# likelihood ratio test: chi2=4.4429  , p=0.6170  , df=6
# parameter F test:         F=0.7112  , p=0.6409  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6693  , p=0.6746  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=4.2150  , p=0.6476  , df=6
# likelihood ratio test: chi2=4.1830  , p=0.6519  , df=6
# parameter F test:         F=0.6693  , p=0.6746  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.1544  , p=0.3313  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=7.2700  , p=0.2966  , df=6
# likelihood ratio test: chi2=7.1756  , p=0.3049  , df=6
# parameter F test:         F=1.1544  , p=0.3313  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5406  , p=0.7771  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=3.4043  , p=0.7567  , df=6
# likelihood ratio test: chi2=3.3834  , p=0.7594  , df=6
# parameter F test:         F=0.5406  , p=0.7771  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.2454  , p=0.0394  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=14.1408 , p=0.0281  , df=6
# likelihood ratio test: chi2=13.7892 , p=0.0321  , df=6
# parameter F test:         F=2.2454  , p=0.0394  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.3245  , p=0.0333  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=14.6388 , p=0.0233  , df=6
# likelihood ratio test: chi2=14.2624 , p=0.0268  , df=6
# parameter F test:         F=2.3245  , p=0.0333  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.0442  , p=0.0603  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=12.8735 , p=0.0451  , df=6
# likelihood ratio test: chi2=12.5813 , p=0.0502  , df=6
# parameter F test:         F=2.0442  , p=0.0603  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.4660  , p=0.1901  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=9.2327  , p=0.1609  , df=6
# likelihood ratio test: chi2=9.0811  , p=0.1691  , df=6
# parameter F test:         F=1.4660  , p=0.1901  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.1148  , p=0.0058  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=19.6164 , p=0.0032  , df=6
# likelihood ratio test: chi2=18.9483 , p=0.0043  , df=6
# parameter F test:         F=3.1148  , p=0.0058  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.5738  , p=0.0020  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=22.5066 , p=0.0010  , df=6
# likelihood ratio test: chi2=21.6329 , p=0.0014  , df=6
# parameter F test:         F=3.5738  , p=0.0020  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.2709  , p=0.0373  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=14.3016 , p=0.0264  , df=6
# likelihood ratio test: chi2=13.9421 , p=0.0303  , df=6
# parameter F test:         F=2.2709  , p=0.0373  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7040  , p=0.6466  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=4.4339  , p=0.6182  , df=6
# likelihood ratio test: chi2=4.3985  , p=0.6229  , df=6
# parameter F test:         F=0.7040  , p=0.6466  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.1567  , p=0.0476  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=13.5824 , p=0.0347  , df=6
# likelihood ratio test: chi2=13.2576 , p=0.0391  , df=6
# parameter F test:         F=2.1567  , p=0.0476  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9664  , p=0.4484  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=6.0864  , p=0.4136  , df=6
# likelihood ratio test: chi2=6.0200  , p=0.4210  , df=6
# parameter F test:         F=0.9664  , p=0.4484  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5516  , p=0.7685  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=3.4741  , p=0.7474  , df=6
# likelihood ratio test: chi2=3.4523  , p=0.7503  , df=6
# parameter F test:         F=0.5516  , p=0.7685  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8240  , p=0.5521  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=5.1895  , p=0.5198  , df=6
# likelihood ratio test: chi2=5.1411  , p=0.5258  , df=6
# parameter F test:         F=0.8240  , p=0.5521  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.7315  , p=0.1139  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=10.9043 , p=0.0914  , df=6
# likelihood ratio test: chi2=10.6937 , p=0.0983  , df=6
# parameter F test:         F=1.7315  , p=0.1139  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.4248  , p=0.2053  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=8.9727  , p=0.1751  , df=6
# likelihood ratio test: chi2=8.8294  , p=0.1834  , df=6
# parameter F test:         F=1.4248  , p=0.2053  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.0017  , p=0.0658  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=12.6064 , p=0.0497  , df=6
# likelihood ratio test: chi2=12.3260 , p=0.0551  , df=6
# parameter F test:         F=2.0017  , p=0.0658  , df_denom=262, df_num=6
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6160  , p=0.7175  , df_denom=262, df_num=6
# ssr based chi2 test:   chi2=3.8791  , p=0.6930  , df=6
# likelihood ratio test: chi2=3.8520  , p=0.6967  , df=6
# parameter F test:         F=0.6160  , p=0.7175  , df_denom=262, df_num=6

# %%
importancesCG = pd.Series(importancesCG)
importancesCG
# Out:
# PPIPT_ppi                0.000031
# GS1_fred-md              0.040471
# GS5_fred-md              0.048912
# OILPRICEx_fred-md_Eur    0.000481
# CUSR0000SAC_fred-md      0.000389
# PCEPI_fred-md            0.003620
# EMPENT_PT_ea-qd          0.029732
# REER42_PT_ea-md          0.038585
# HICPOV_PT_ea-md          0.039423
# HICPNEF_PT_ea-md         0.033282
# HICPSV_PT_ea-md          0.005776
# HICPNG_PT_ea-md          0.002021
# DFGDP_PT_ea-qd           0.037331
# CCONFIX_PT_ea-md         0.047588
# dtype: float64

# %% [markdown]
# ## Quais são as variáveis mais importantes?

# %%
model_selection = list()

for var in importancesCG.index:
    if var not in model_selection:
        model_selection.append(var)

model_selection
# Out:
# ['PPIPT_ppi',
#  'GS1_fred-md',
#  'GS5_fred-md',
#  'OILPRICEx_fred-md_Eur',
#  'CUSR0000SAC_fred-md',
#  'PCEPI_fred-md',
#  'EMPENT_PT_ea-qd',
#  'REER42_PT_ea-md',
#  'HICPOV_PT_ea-md',
#  'HICPNEF_PT_ea-md',
#  'HICPSV_PT_ea-md',
#  'HICPNG_PT_ea-md',
#  'DFGDP_PT_ea-qd',
#  'CCONFIX_PT_ea-md']

# %% [markdown]
# ---
# ### As variáveis selecionadas foram
#
# #### Seleção por modelos
# - HICP excluindo energia (HICPNG-PT)
# - HICP total (HICPOV_PT)
# - HICP excluindo energia e alimentos (HICPNEF-PT)
# - HICP excluindo Serviços (HICPSV-PT)
# - Treasury yelds 1 year (GS1)
# - Treasury yelds 5 years (GS5)
# - Preço do petróleo em Euros
# - _Índice de Preços do consumidor para todos os consumidores Urbanos: Commodities médios nas cidades de US_
#     - Consumer Price Index for All Urban Consumers: Commodities in U.S. City Average (CUSR0000SAC)
# - Índice de Preços do Consumo Pessoal (PCEPI)
# - Empregos no setor de Entretenimento e outros serviços (EMPENT-PT) *
# - Taxa de Câmbio real efetiva (REER42-PT)
# - Deflator do PIB (DFGDP-PT) *
# - Custos na construção (CCONFIX-PT)
# - Taxa de variação homóloga do Índice de Preço de Produção (PPIPT)
#
# #### Seleção pela teoria económica
# - Índice de Incerteza Política (epu_pt_epu)
# - Custo Unitário do Trabalho na Indústria (ULCIN_PT) *
# - Exportações de bens e serviços (EXPGS_PT ) *
# - Importações de bens e serviços (IMPGS_PT) *
# - Indicador de confiança do Consumidor (CCI_PT)
# - Produto Interno Bruto (GDP_PT) *
# - Taxa de desemprego total (UNETOT_PT)
#
# \* *Variáveis trimestrais*
#
# ---

# %%
teorical_variables = [
    'epu_pt_epu', 'GDP_PT_ea-qd', 'ULCIN_PT_ea-qd', 
    'EXPGS_PT_ea-qd', 'IMPGS_PT_ea-qd', 'CCI_PT_ea-md', 
    'UNETOT_PT_ea-md'
]

target = 'inflation_target'

df_train = df[model_selection + teorical_variables + [target, ]].copy()
df_train.head(4)
# Out:
#             PPIPT_ppi  GS1_fred-md  GS5_fred-md  OILPRICEx_fred-md_Eur  \
# Date
# 2000-01-01       21.5         6.12         6.58              27.760188
# 2000-02-01       21.9         6.22         6.68              30.214124
# 2000-03-01       21.2         6.22         6.50              31.288600
# 2000-04-01       20.0         6.15         6.26              28.332416
#
#             CUSR0000SAC_fred-md  PCEPI_fred-md  EMPENT_PT_ea-qd  \
# Date
# 2000-01-01                146.7         72.961       251.203770
# 2000-02-01                147.6         73.191       251.246137
# 2000-03-01                149.1         73.505       251.470000
# 2000-04-01                148.5         73.444       251.937929
#
#             REER42_PT_ea-md  HICPOV_PT_ea-md  HICPNEF_PT_ea-md  ...  \
# Date                                                            ...
# 2000-01-01         96.14621        57.431740         62.712032  ...
# 2000-02-01         95.12462        57.437413         62.746704  ...
# 2000-03-01         94.49293        57.466046         62.816039  ...
# 2000-04-01         94.90064        57.722524         62.851899  ...
#
#             DFGDP_PT_ea-qd  CCONFIX_PT_ea-md  epu_pt_epu  GDP_PT_ea-qd  \
# Date
# 2000-01-01       71.515980              -2.4  107.096201  43392.510865
# 2000-02-01       71.835766              -3.0  105.539878  43410.337894
# 2000-03-01       72.430000              -3.2   68.844150  43450.600000
# 2000-04-01       72.255022              -9.2   70.292778  43354.566667
#
#             ULCIN_PT_ea-qd  EXPGS_PT_ea-qd  IMPGS_PT_ea-qd  CCI_PT_ea-md  \
# Date
# 2000-01-01       63.215907    10321.943654    12861.845198      102.3880
# 2000-02-01       63.915202    10258.591955    13052.288749      102.2470
# 2000-03-01       64.800000    10151.500000    13257.600000      101.9521
# 2000-04-01       65.463501    10061.805642    13372.931249      101.5175
#
#             UNETOT_PT_ea-md  inflation_target
# Date
# 2000-01-01              5.6               2.1
# 2000-02-01              5.4               1.8
# 2000-03-01              5.3               1.5
# 2000-04-01              5.2               2.1
#
# [4 rows x 22 columns]

# %%
df_train.shape
# Out:
# (282, 22)

# %%
df_train.columns
# Out:
# Index(['PPIPT_ppi', 'GS1_fred-md', 'GS5_fred-md', 'OILPRICEx_fred-md_Eur',
#        'CUSR0000SAC_fred-md', 'PCEPI_fred-md', 'EMPENT_PT_ea-qd',
#        'REER42_PT_ea-md', 'HICPOV_PT_ea-md', 'HICPNEF_PT_ea-md',
#        'HICPSV_PT_ea-md', 'HICPNG_PT_ea-md', 'DFGDP_PT_ea-qd',
#        'CCONFIX_PT_ea-md', 'epu_pt_epu', 'GDP_PT_ea-qd', 'ULCIN_PT_ea-qd',
#        'EXPGS_PT_ea-qd', 'IMPGS_PT_ea-qd', 'CCI_PT_ea-md', 'UNETOT_PT_ea-md',
#        'inflation_target'],
#       dtype='object')

# %% [markdown]
# # Estacionarizando as variáveis

# %%
df_train['PPIPT_ppi'].min()
# Out:
# -6.2

# %%
df_final_stacionary = df_train[['epu_pt_epu']].copy()

df_final_stacionary['inflation_target'] = stacionarize_fred(df_train['inflation_target'], 2)
df_final_stacionary['PPIPT_ppi'] = np.log(df_train['PPIPT_ppi'] + abs(df_train['PPIPT_ppi'].min()) + 0.1)

fred_var = [var for var in df_train.columns if '_fred-md' in var]
ea_var = [var for var in df_train.columns if '_ea-' in var]

# Estacionarizando as variáveis da FRED-MD
for idx, val in df_fred_md[fred_var].iloc[0].items():
    df_final_stacionary[idx] = stacionarize_fred(df_train[idx], val)

# Estacionarizando as variáveis da EA-MD-QD
for idx, val in pd.Series(ea_transform)[ea_var].items():
    df_final_stacionary[idx] = stacionarize_ea(df_train[idx], val)

df_final_stacionary.head()
# Out:
#             epu_pt_epu  inflation_target  PPIPT_ppi  GS1_fred-md  GS5_fred-md  \
# Date
# 2000-01-01  107.096201               NaN   3.325036          NaN          NaN
# 2000-02-01  105.539878              -0.3   3.339322         0.10         0.10
# 2000-03-01   68.844150              -0.3   3.314186         0.00        -0.18
# 2000-04-01   70.292778               0.6   3.269569        -0.07        -0.24
# 2000-05-01   78.451666               0.4   3.186353         0.18         0.43
#
#             OILPRICEx_fred-md_Eur  CUSR0000SAC_fred-md  PCEPI_fred-md  \
# Date
# 2000-01-01                    NaN                  NaN            NaN
# 2000-02-01                    NaN                  NaN            NaN
# 2000-03-01               0.119651             0.016228       0.007428
# 2000-04-01              -0.064303             0.006079       0.003451
# 2000-05-01              -0.011325            -0.004032       0.000000
#
#             EMPENT_PT_ea-qd  REER42_PT_ea-md  ...  HICPSV_PT_ea-md  \
# Date                                          ...
# 2000-01-01              NaN              NaN  ...              NaN
# 2000-02-01         0.016864         -1.02159  ...         0.177079
# 2000-03-01         0.089061         -0.63169  ...         0.131228
# 2000-04-01         0.185905          0.40771  ...         0.127484
# 2000-05-01         0.250760          0.06696  ...         0.315931
#
#             HICPNG_PT_ea-md  DFGDP_PT_ea-qd  CCONFIX_PT_ea-md  GDP_PT_ea-qd  \
# Date
# 2000-01-01              NaN             NaN              -2.4           NaN
# 2000-02-01         0.279953        0.446157              -3.0      0.041075
# 2000-03-01         0.014668        0.823810              -3.2      0.092705
# 2000-04-01         3.720325       -0.241874              -9.2     -0.221262
# 2000-05-01        -0.425857        0.362385              -8.0     -0.221753
#
#             ULCIN_PT_ea-qd  EXPGS_PT_ea-qd  IMPGS_PT_ea-qd  CCI_PT_ea-md  \
# Date
# 2000-01-01             NaN             NaN             NaN      102.3880
# 2000-02-01        1.100126       -0.615649        1.469831      102.2470
# 2000-03-01        1.374837       -1.049412        1.560747      101.9521
# 2000-04-01        1.018715       -0.887484        0.866163      101.5175
# 2000-05-01        0.366824       -0.333989       -0.071786      101.2843
#
#             UNETOT_PT_ea-md
# Date
# 2000-01-01              NaN
# 2000-02-01             -0.2
# 2000-03-01             -0.1
# 2000-04-01             -0.1
# 2000-05-01              0.1
#
# [5 rows x 22 columns]

# %%
df_final_stacionary.to_csv("dados/train_stationary.csv")

# %% [markdown]
# # Tratamento de Outliers

# %%
def outliers(X, level=0):
    """
        - X: variável onde se verifica os outliers
        - level: default 0 - outliers não severos; 1 outliers severos
    """

    assert level in (0, 1), "Level invalido - valores aceites (0, 1)"

    out_level = (1.5, 3)
    Q1 = X.quantile(.25)
    Q3 = X.quantile(.75)
    IQR = Q3 - Q1

    left = Q1 - out_level[level] * IQR
    right = Q3 + out_level[level] * IQR

    return (left, right)

# %%
variables = dict()

for col in df_train.columns:
    left, right = outliers(df_train[col])
    variables[col] = df_train.loc[(df_train[col] < left) | (df_train[col] > right)].shape[0]

pd.Series(variables).sort_values(ascending=False)
# Out:
# PPIPT_ppi                25
# ULCIN_PT_ea-qd           14
# GDP_PT_ea-qd             14
# CUSR0000SAC_fred-md      12
# inflation_target         11
# epu_pt_epu               10
# DFGDP_PT_ea-qd            1
# OILPRICEx_fred-md_Eur     1
# PCEPI_fred-md             0
# UNETOT_PT_ea-md           0
# CCI_PT_ea-md              0
# IMPGS_PT_ea-qd            0
# EXPGS_PT_ea-qd            0
# GS5_fred-md               0
# CCONFIX_PT_ea-md          0
# EMPENT_PT_ea-qd           0
# GS1_fred-md               0
# HICPSV_PT_ea-md           0
# HICPNEF_PT_ea-md          0
# HICPOV_PT_ea-md           0
# REER42_PT_ea-md           0
# HICPNG_PT_ea-md           0
# dtype: int64

# %%
from sklearn.preprocessing import QuantileTransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

out_variables = pd.Series(variables).sort_values(ascending=False)

cols_quantile = [col for col in out_variables[out_variables > 0].index if col != 'inflation_target']
cols_standard = out_variables[out_variables == 0].index.tolist()

# Define os transformers
preprocessor = ColumnTransformer(
    transformers=[
        ('std', StandardScaler(), cols_standard),
        ('quantile', QuantileTransformer(n_quantiles=min(100, df_train.shape[0]), 
                                         output_distribution='normal',
                                         random_state=322
                                        ), cols_quantile)
    ],
    remainder='passthrough'  # mantém outras colunas sem alteração
)

transformer = preprocessor.fit(df_train)

# %%
cols_out = cols_standard + cols_quantile + [col for col in df_train.columns if col not in cols_standard + cols_quantile]

df_transformed = pd.DataFrame(transformer.transform(df_train), columns=cols_out)
df_transformed.index = df_train.index
df_transformed.head()
# Out:
#             PCEPI_fred-md  UNETOT_PT_ea-md  CCI_PT_ea-md  IMPGS_PT_ea-qd  \
# Date
# 2000-01-01      -1.672367        -1.181375      1.622256       -1.292128
# 2000-02-01      -1.652773        -1.239516      1.555927       -1.236524
# 2000-03-01      -1.626023        -1.268586      1.417198       -1.176579
# 2000-04-01      -1.631220        -1.297657      1.212752       -1.142906
# 2000-05-01      -1.626023        -1.268586      1.103049       -1.145707
#
#             EXPGS_PT_ea-qd  GS5_fred-md  CCONFIX_PT_ea-md  EMPENT_PT_ea-qd  \
# Date
# 2000-01-01       -1.333842     2.651460          1.612561        -1.857139
# 2000-02-01       -1.348731     2.718651          1.557800        -1.854185
# 2000-03-01       -1.373899     2.597707          1.539546        -1.838577
# 2000-04-01       -1.394979     2.436448          0.991927        -1.805954
# 2000-05-01       -1.402864     2.725370          1.101451        -1.761853
#
#             GS1_fred-md  HICPSV_PT_ea-md  ...  REER42_PT_ea-md  \
# Date                                      ...
# 2000-01-01     2.370485        -2.090914  ...        -2.037451
# 2000-02-01     2.425870        -2.082324  ...        -2.347105
# 2000-03-01     2.425870        -2.075948  ...        -2.538577
# 2000-04-01     2.387100        -2.069746  ...        -2.414996
# 2000-05-01     2.486794        -2.054342  ...        -2.394699
#
#             HICPNG_PT_ea-md  PPIPT_ppi  ULCIN_PT_ea-qd  GDP_PT_ea-qd  \
# Date
# 2000-01-01        -1.810267   2.112112       -2.309865     -1.911430
# 2000-02-01        -1.802991   2.266949       -2.113992     -1.853788
# 2000-03-01        -1.802610   1.956981       -1.917631     -1.759427
# 2000-04-01        -1.703956   1.819146       -1.779384     -2.062445
# 2000-05-01        -1.715435   1.700008       -1.741123     -2.276094
#
#             CUSR0000SAC_fred-md  epu_pt_epu  DFGDP_PT_ea-qd  \
# Date
# 2000-01-01            -5.199338    0.579501       -5.199338
# 2000-02-01            -2.531313    0.517177       -2.683129
# 2000-03-01            -1.888129   -1.118873       -2.309995
# 2000-04-01            -2.049594   -1.083752       -2.389831
# 2000-05-01            -2.049594   -0.669207       -2.273296
#
#             OILPRICEx_fred-md_Eur  inflation_target
# Date
# 2000-01-01              -1.466960               2.1
# 2000-02-01              -1.118196               1.8
# 2000-03-01              -0.958600               1.5
# 2000-04-01              -1.336194               2.1
# 2000-05-01              -0.992480               2.5
#
# [5 rows x 22 columns]

# %%
import joblib

# guardar no disco
joblib.dump(transformer, "models/preprocessor.pkl")
# Out:
# ['models/preprocessor.pkl']

# %%
cols_out
# Out:
# ['PCEPI_fred-md',
#  'UNETOT_PT_ea-md',
#  'CCI_PT_ea-md',
#  'IMPGS_PT_ea-qd',
#  'EXPGS_PT_ea-qd',
#  'GS5_fred-md',
#  'CCONFIX_PT_ea-md',
#  'EMPENT_PT_ea-qd',
#  'GS1_fred-md',
#  'HICPSV_PT_ea-md',
#  'HICPNEF_PT_ea-md',
#  'HICPOV_PT_ea-md',
#  'REER42_PT_ea-md',
#  'HICPNG_PT_ea-md',
#  'PPIPT_ppi',
#  'ULCIN_PT_ea-qd',
#  'GDP_PT_ea-qd',
#  'CUSR0000SAC_fred-md',
#  'epu_pt_epu',
#  'DFGDP_PT_ea-qd',
#  'OILPRICEx_fred-md_Eur',
#  'inflation_target']

# %% [raw]
# import joblib
#
# cols_out = [
#     'HICPOV_PT_ea-md', 'HICPNEF_PT_ea-md', 'HICPSV_PT_ea-md',
#     'HICPNG_PT_ea-md', 'GS5_fred-md', 'CCONFIX_PT_ea-md',
#     'REER42_PT_ea-md', 'EMPENT_PT_ea-qd', 'PCEPI_fred-md',
#     'EXPGS_PT_ea-qd', 'IMPGS_PT_ea-qd', 'CCI_PT_ea-md',
#     'UNETOT_PT_ea-md', 'GS1_fred-md', 'PPIPT_ppi',
#     'ULCIN_PT_ea-qd', 'GDP_PT_ea-qd', 'CUSR0000SAC_fred-md',
#     'epu_pt_epu', 'DFGDP_PT_ea-qd', 'OILPRICEx_fred-md_Eur',
#     'inflation_target'
# ]
#
# # carregar transformer
# transformer_loaded = joblib.load("models/preprocessor.pkl")
#
# df_new_transformed = transformer_loaded.transform(df_new)
#
# df_new_transformed = pd.DataFrame(df_new_transformed, columns=cols_out)

# %% [markdown]
# # Defasamento das Features

# %%
target = 'inflation_target'
df_lags = df_transformed.copy()
lags = dict()

for col in df_transformed.drop(target, axis=1).columns:
    lags[col] = list()
    lags[col].append(df_lags[[col, target]].corr()[col].values[-1])
    for lag in range(1, 13):
        new_var = f'{col}_lag{lag}'
        df_lags[new_var] = df_lags[col].shift(lag)
        lags[col].append(df_lags[[new_var, target]].corr()[new_var].values[-1])

df_lags = df_lags.copy()
# Out:
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)
# C:\Users\josev\AppData\Local\Temp\ipykernel_59340\3876981247.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_lags[new_var] = df_lags[col].shift(lag)

# %%
lag_df = pd.DataFrame(lags)
cols = dict()
for col in lag_df.columns:
    clean = col.replace('_fred-md', '').replace('_ea-md', '').replace('_ea-qd', '').replace('_Eur', '')
    cols[col] = clean

lag_df.rename(cols, axis=1, inplace=True)
lag_df.T
# Out:
#                    0         1         2         3         4         5   \
# PCEPI       -0.017848 -0.023084 -0.030400 -0.039327 -0.046835 -0.053873
# UNETOT_PT   -0.363086 -0.376440 -0.389733 -0.402273 -0.411539 -0.418317
# CCI_PT      -0.245555 -0.221759 -0.190299 -0.151150 -0.109372 -0.067975
# IMPGS_PT     0.090341  0.092889  0.093894  0.093179  0.091490  0.087328
# EXPGS_PT    -0.002459 -0.009236 -0.017905 -0.027992 -0.038034 -0.049491
# GS5          0.466527  0.460549  0.450043  0.439690  0.427278  0.411886
# CCONFIX_PT  -0.241735 -0.217350 -0.189132 -0.149166 -0.104769 -0.065863
# EMPENT_PT   -0.108946 -0.131069 -0.156017 -0.183661 -0.209639 -0.233074
# GS1          0.492596  0.477276  0.458366  0.438312  0.415011  0.389056
# HICPSV_PT   -0.144145 -0.155105 -0.166236 -0.178763 -0.188304 -0.196337
# HICPNEF_PT  -0.118178 -0.134834 -0.152332 -0.171387 -0.187522 -0.201870
# HICPOV_PT   -0.055905 -0.072007 -0.090460 -0.111288 -0.130399 -0.148679
# REER42_PT   -0.244921 -0.274501 -0.298782 -0.318930 -0.334563 -0.344764
# HICPNG_PT    0.005351  0.002879 -0.006583 -0.020730 -0.036933 -0.056579
# PPIPT_ppi    0.640482  0.681935  0.701282  0.710407  0.709096  0.696618
# ULCIN_PT    -0.007753 -0.023612 -0.039233 -0.058994 -0.066842 -0.066710
# GDP_PT       0.259807  0.259841  0.255286  0.249207  0.242110  0.233252
# CUSR0000SAC  0.047415  0.042824  0.030013  0.014773  0.005899 -0.008648
# epu_pt_epu  -0.046579 -0.059839 -0.065804 -0.067896 -0.068697 -0.071431
# DFGDP_PT    -0.046958 -0.062822 -0.072767 -0.087101 -0.098152 -0.107286
# OILPRICEx    0.204788  0.223066  0.219009  0.211943  0.205063  0.185119
#
#                    6         7         8         9         10        11  \
# PCEPI       -0.060472 -0.066603 -0.072572 -0.079264 -0.085894 -0.091891
# UNETOT_PT   -0.422674 -0.425663 -0.428816 -0.431281 -0.432609 -0.432797
# CCI_PT      -0.027998  0.010289  0.046670  0.081841  0.115069  0.145089
# IMPGS_PT     0.080603  0.072369  0.063461  0.053845  0.044105  0.034212
# EXPGS_PT    -0.062930 -0.078168 -0.094916 -0.113023 -0.130999 -0.147848
# GS5          0.392600  0.370098  0.348013  0.326860  0.303958  0.280097
# CCONFIX_PT  -0.027850  0.010908  0.045906  0.079497  0.112896  0.140324
# EMPENT_PT   -0.253210 -0.270336 -0.285808 -0.300605 -0.313502 -0.323284
# GS1          0.360342  0.331125  0.303003  0.275658  0.249233  0.224090
# HICPSV_PT   -0.203048 -0.207967 -0.212213 -0.216523 -0.220194 -0.221861
# HICPNEF_PT  -0.214439 -0.224826 -0.234494 -0.244176 -0.252987 -0.259800
# HICPOV_PT   -0.165591 -0.181033 -0.195866 -0.210772 -0.224560 -0.236526
# REER42_PT   -0.352311 -0.356331 -0.357374 -0.356690 -0.352748 -0.347302
# HICPNG_PT   -0.077956 -0.101471 -0.126105 -0.153923 -0.181832 -0.209422
# PPIPT_ppi    0.683694  0.659448  0.629299  0.592077  0.547468  0.500379
# ULCIN_PT    -0.067529 -0.063050 -0.058989 -0.057336 -0.058338 -0.059718
# GDP_PT       0.220794  0.203379  0.186042  0.167935  0.148667  0.125869
# CUSR0000SAC -0.023929 -0.041584 -0.053610 -0.072833 -0.096439 -0.118623
# epu_pt_epu  -0.077223 -0.077419 -0.071113 -0.053310 -0.035505 -0.019383
# DFGDP_PT    -0.114238 -0.116950 -0.118294 -0.121403 -0.122484 -0.123512
# OILPRICEx    0.160853  0.129429  0.092014  0.043033 -0.014851 -0.070668
#
#                    12
# PCEPI       -0.097061
# UNETOT_PT   -0.432822
# CCI_PT       0.171038
# IMPGS_PT     0.024460
# EXPGS_PT    -0.162668
# GS5          0.256150
# CCONFIX_PT   0.167855
# EMPENT_PT   -0.329430
# GS1          0.200130
# HICPSV_PT   -0.222770
# HICPNEF_PT  -0.265536
# HICPOV_PT   -0.246866
# REER42_PT   -0.340185
# HICPNG_PT   -0.236429
# PPIPT_ppi    0.451329
# ULCIN_PT    -0.059116
# GDP_PT       0.105994
# CUSR0000SAC -0.135891
# epu_pt_epu  -0.003175
# DFGDP_PT    -0.125747
# OILPRICEx   -0.122415

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6), dpi=500)

sns.heatmap(lag_df.T, annot=False)

plt.xlabel("Lags", loc='left', fontdict={
    'fontsize':14
})
plt.ylabel("Variáveis", loc='top', fontdict={
    'fontsize':14
})
plt.title("Defasamento dos lags", loc='left', fontdict={
    'fontsize':22
})

plt.show()

# %%
df_lags.head()
# Out:
#             PCEPI_fred-md  UNETOT_PT_ea-md  CCI_PT_ea-md  IMPGS_PT_ea-qd  \
# Date
# 2000-01-01      -1.672367        -1.181375      1.622256       -1.292128
# 2000-02-01      -1.652773        -1.239516      1.555927       -1.236524
# 2000-03-01      -1.626023        -1.268586      1.417198       -1.176579
# 2000-04-01      -1.631220        -1.297657      1.212752       -1.142906
# 2000-05-01      -1.626023        -1.268586      1.103049       -1.145707
#
#             EXPGS_PT_ea-qd  GS5_fred-md  CCONFIX_PT_ea-md  EMPENT_PT_ea-qd  \
# Date
# 2000-01-01       -1.333842     2.651460          1.612561        -1.857139
# 2000-02-01       -1.348731     2.718651          1.557800        -1.854185
# 2000-03-01       -1.373899     2.597707          1.539546        -1.838577
# 2000-04-01       -1.394979     2.436448          0.991927        -1.805954
# 2000-05-01       -1.402864     2.725370          1.101451        -1.761853
#
#             GS1_fred-md  HICPSV_PT_ea-md  ...  OILPRICEx_fred-md_Eur_lag3  \
# Date                                      ...
# 2000-01-01     2.370485        -2.090914  ...                         NaN
# 2000-02-01     2.425870        -2.082324  ...                         NaN
# 2000-03-01     2.425870        -2.075948  ...                         NaN
# 2000-04-01     2.387100        -2.069746  ...                   -1.466960
# 2000-05-01     2.486794        -2.054342  ...                   -1.118196
#
#             OILPRICEx_fred-md_Eur_lag4  OILPRICEx_fred-md_Eur_lag5  \
# Date
# 2000-01-01                         NaN                         NaN
# 2000-02-01                         NaN                         NaN
# 2000-03-01                         NaN                         NaN
# 2000-04-01                         NaN                         NaN
# 2000-05-01                    -1.46696                         NaN
#
#             OILPRICEx_fred-md_Eur_lag6  OILPRICEx_fred-md_Eur_lag7  \
# Date
# 2000-01-01                         NaN                         NaN
# 2000-02-01                         NaN                         NaN
# 2000-03-01                         NaN                         NaN
# 2000-04-01                         NaN                         NaN
# 2000-05-01                         NaN                         NaN
#
#             OILPRICEx_fred-md_Eur_lag8  OILPRICEx_fred-md_Eur_lag9  \
# Date
# 2000-01-01                         NaN                         NaN
# 2000-02-01                         NaN                         NaN
# 2000-03-01                         NaN                         NaN
# 2000-04-01                         NaN                         NaN
# 2000-05-01                         NaN                         NaN
#
#             OILPRICEx_fred-md_Eur_lag10  OILPRICEx_fred-md_Eur_lag11  \
# Date
# 2000-01-01                          NaN                          NaN
# 2000-02-01                          NaN                          NaN
# 2000-03-01                          NaN                          NaN
# 2000-04-01                          NaN                          NaN
# 2000-05-01                          NaN                          NaN
#
#             OILPRICEx_fred-md_Eur_lag12
# Date
# 2000-01-01                          NaN
# 2000-02-01                          NaN
# 2000-03-01                          NaN
# 2000-04-01                          NaN
# 2000-05-01                          NaN
#
# [5 rows x 274 columns]

# %%
# df_lags.to_csv("Test zone/dados.csv", index=False)

# %%
df_lags.shape
# Out:
# (282, 274)

# %%
from sklearn.linear_model import Lasso

# %%
lags_selected = dict()

for col in df_train.drop('inflation_target', axis=1).columns:
    clf = Lasso(alpha=0.1, max_iter=1000, random_state=322)
    
    cols_lag = [lag_col for lag_col in df_lags.columns if col == lag_col[:len(col)]]
    data = df_lags[cols_lag + [target,]].copy()
    data.dropna(inplace=True)
    X = data.drop(target, axis=1)
    y = data[target]

    clf.fit(X, y)

    coef_selected = list()
    coef = np.abs(clf.coef_)
    for i, lag_selected in enumerate(X.columns):
        if coef[i] != 0:
            coef_selected.append(lag_selected)

    lags_selected[col] = coef_selected
    
lags_selected
# Out:
# {'PPIPT_ppi': ['PPIPT_ppi',
#   'PPIPT_ppi_lag1',
#   'PPIPT_ppi_lag2',
#   'PPIPT_ppi_lag3',
#   'PPIPT_ppi_lag4',
#   'PPIPT_ppi_lag6',
#   'PPIPT_ppi_lag7',
#   'PPIPT_ppi_lag8',
#   'PPIPT_ppi_lag9',
#   'PPIPT_ppi_lag10',
#   'PPIPT_ppi_lag11',
#   'PPIPT_ppi_lag12'],
#  'GS1_fred-md': ['GS1_fred-md', 'GS1_fred-md_lag10'],
#  'GS5_fred-md': ['GS5_fred-md', 'GS5_fred-md_lag12'],
#  'OILPRICEx_fred-md_Eur': ['OILPRICEx_fred-md_Eur',
#   'OILPRICEx_fred-md_Eur_lag1',
#   'OILPRICEx_fred-md_Eur_lag2',
#   'OILPRICEx_fred-md_Eur_lag3',
#   'OILPRICEx_fred-md_Eur_lag4',
#   'OILPRICEx_fred-md_Eur_lag5',
#   'OILPRICEx_fred-md_Eur_lag6',
#   'OILPRICEx_fred-md_Eur_lag7',
#   'OILPRICEx_fred-md_Eur_lag12'],
#  'CUSR0000SAC_fred-md': ['CUSR0000SAC_fred-md',
#   'CUSR0000SAC_fred-md_lag1',
#   'CUSR0000SAC_fred-md_lag2',
#   'CUSR0000SAC_fred-md_lag11',
#   'CUSR0000SAC_fred-md_lag12'],
#  'PCEPI_fred-md': ['PCEPI_fred-md', 'PCEPI_fred-md_lag12'],
#  'EMPENT_PT_ea-qd': ['EMPENT_PT_ea-qd', 'EMPENT_PT_ea-qd_lag12'],
#  'REER42_PT_ea-md': ['REER42_PT_ea-md_lag6',
#   'REER42_PT_ea-md_lag7',
#   'REER42_PT_ea-md_lag8',
#   'REER42_PT_ea-md_lag9',
#   'REER42_PT_ea-md_lag10',
#   'REER42_PT_ea-md_lag11',
#   'REER42_PT_ea-md_lag12'],
#  'HICPOV_PT_ea-md': ['HICPOV_PT_ea-md', 'HICPOV_PT_ea-md_lag12'],
#  'HICPNEF_PT_ea-md': ['HICPNEF_PT_ea-md', 'HICPNEF_PT_ea-md_lag12'],
#  'HICPSV_PT_ea-md': ['HICPSV_PT_ea-md_lag12'],
#  'HICPNG_PT_ea-md': ['HICPNG_PT_ea-md_lag1',
#   'HICPNG_PT_ea-md_lag3',
#   'HICPNG_PT_ea-md_lag4',
#   'HICPNG_PT_ea-md_lag12'],
#  'DFGDP_PT_ea-qd': ['DFGDP_PT_ea-qd_lag12'],
#  'CCONFIX_PT_ea-md': ['CCONFIX_PT_ea-md',
#   'CCONFIX_PT_ea-md_lag1',
#   'CCONFIX_PT_ea-md_lag2',
#   'CCONFIX_PT_ea-md_lag11',
#   'CCONFIX_PT_ea-md_lag12'],
#  'epu_pt_epu': ['epu_pt_epu_lag6', 'epu_pt_epu_lag7', 'epu_pt_epu_lag8'],
#  'GDP_PT_ea-qd': ['GDP_PT_ea-qd',
#   'GDP_PT_ea-qd_lag1',
#   'GDP_PT_ea-qd_lag2',
#   'GDP_PT_ea-qd_lag3',
#   'GDP_PT_ea-qd_lag4',
#   'GDP_PT_ea-qd_lag5',
#   'GDP_PT_ea-qd_lag12'],
#  'ULCIN_PT_ea-qd': ['ULCIN_PT_ea-qd_lag12'],
#  'EXPGS_PT_ea-qd': ['EXPGS_PT_ea-qd', 'EXPGS_PT_ea-qd_lag12'],
#  'IMPGS_PT_ea-qd': ['IMPGS_PT_ea-qd_lag2', 'IMPGS_PT_ea-qd_lag3'],
#  'CCI_PT_ea-md': ['CCI_PT_ea-md', 'CCI_PT_ea-md_lag12'],
#  'UNETOT_PT_ea-md': ['UNETOT_PT_ea-md_lag12']}

# %%
for col, lags in lags_selected.items():
    print("=" * 40)
    print(f"Coluna: {col}")
    print("=" * 40)
    for lag in lags:
        print(f"- {lag}")
# Out:
# ========================================
# Coluna: PPIPT_ppi
# ========================================
# - PPIPT_ppi
# - PPIPT_ppi_lag1
# - PPIPT_ppi_lag2
# - PPIPT_ppi_lag3
# - PPIPT_ppi_lag4
# - PPIPT_ppi_lag6
# - PPIPT_ppi_lag7
# - PPIPT_ppi_lag8
# - PPIPT_ppi_lag9
# - PPIPT_ppi_lag10
# - PPIPT_ppi_lag11
# - PPIPT_ppi_lag12
# ========================================
# Coluna: GS1_fred-md
# ========================================
# - GS1_fred-md
# - GS1_fred-md_lag10
# ========================================
# Coluna: GS5_fred-md
# ========================================
# - GS5_fred-md
# - GS5_fred-md_lag12
# ========================================
# Coluna: OILPRICEx_fred-md_Eur
# ========================================
# - OILPRICEx_fred-md_Eur
# - OILPRICEx_fred-md_Eur_lag1
# - OILPRICEx_fred-md_Eur_lag2
# - OILPRICEx_fred-md_Eur_lag3
# - OILPRICEx_fred-md_Eur_lag4
# - OILPRICEx_fred-md_Eur_lag5
# - OILPRICEx_fred-md_Eur_lag6
# - OILPRICEx_fred-md_Eur_lag7
# - OILPRICEx_fred-md_Eur_lag12
# ========================================
# Coluna: CUSR0000SAC_fred-md
# ========================================
# - CUSR0000SAC_fred-md
# - CUSR0000SAC_fred-md_lag1
# - CUSR0000SAC_fred-md_lag2
# - CUSR0000SAC_fred-md_lag11
# - CUSR0000SAC_fred-md_lag12
# ========================================
# Coluna: PCEPI_fred-md
# ========================================
# - PCEPI_fred-md
# - PCEPI_fred-md_lag12
# ========================================
# Coluna: EMPENT_PT_ea-qd
# ========================================
# - EMPENT_PT_ea-qd
# - EMPENT_PT_ea-qd_lag12
# ========================================
# Coluna: REER42_PT_ea-md
# ========================================
# - REER42_PT_ea-md_lag6
# - REER42_PT_ea-md_lag7
# - REER42_PT_ea-md_lag8
# - REER42_PT_ea-md_lag9
# - REER42_PT_ea-md_lag10
# - REER42_PT_ea-md_lag11
# - REER42_PT_ea-md_lag12
# ========================================
# Coluna: HICPOV_PT_ea-md
# ========================================
# - HICPOV_PT_ea-md
# - HICPOV_PT_ea-md_lag12
# ========================================
# Coluna: HICPNEF_PT_ea-md
# ========================================
# - HICPNEF_PT_ea-md
# - HICPNEF_PT_ea-md_lag12
# ========================================
# Coluna: HICPSV_PT_ea-md
# ========================================
# - HICPSV_PT_ea-md_lag12
# ========================================
# Coluna: HICPNG_PT_ea-md
# ========================================
# - HICPNG_PT_ea-md_lag1
# - HICPNG_PT_ea-md_lag3
# - HICPNG_PT_ea-md_lag4
# - HICPNG_PT_ea-md_lag12
# ========================================
# Coluna: DFGDP_PT_ea-qd
# ========================================
# - DFGDP_PT_ea-qd_lag12
# ========================================
# Coluna: CCONFIX_PT_ea-md
# ========================================
# - CCONFIX_PT_ea-md
# - CCONFIX_PT_ea-md_lag1
# - CCONFIX_PT_ea-md_lag2
# - CCONFIX_PT_ea-md_lag11
# - CCONFIX_PT_ea-md_lag12
# ========================================
# Coluna: epu_pt_epu
# ========================================
# - epu_pt_epu_lag6
# - epu_pt_epu_lag7
# - epu_pt_epu_lag8
# ========================================
# Coluna: GDP_PT_ea-qd
# ========================================
# - GDP_PT_ea-qd
# - GDP_PT_ea-qd_lag1
# - GDP_PT_ea-qd_lag2
# - GDP_PT_ea-qd_lag3
# - GDP_PT_ea-qd_lag4
# - GDP_PT_ea-qd_lag5
# - GDP_PT_ea-qd_lag12
# ========================================
# Coluna: ULCIN_PT_ea-qd
# ========================================
# - ULCIN_PT_ea-qd_lag12
# ========================================
# Coluna: EXPGS_PT_ea-qd
# ========================================
# - EXPGS_PT_ea-qd
# - EXPGS_PT_ea-qd_lag12
# ========================================
# Coluna: IMPGS_PT_ea-qd
# ========================================
# - IMPGS_PT_ea-qd_lag2
# - IMPGS_PT_ea-qd_lag3
# ========================================
# Coluna: CCI_PT_ea-md
# ========================================
# - CCI_PT_ea-md
# - CCI_PT_ea-md_lag12
# ========================================
# Coluna: UNETOT_PT_ea-md
# ========================================
# - UNETOT_PT_ea-md_lag12

# %%
tot = 0
for lags in lags_selected.values():
    tot += len(lags)

tot
# Out:
# 74

# %%
lags_for_var = dict()
for var, lags in lags_selected.items():
    lags_for_var[var] = list()
    for lag in lags:
        if 'lag' in lag:
            lags_for_var[var].append(int(lag.split('lag')[-1]))

lags_for_var
# Out:
# {'PPIPT_ppi': [1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 12],
#  'GS1_fred-md': [10],
#  'GS5_fred-md': [12],
#  'OILPRICEx_fred-md_Eur': [1, 2, 3, 4, 5, 6, 7, 12],
#  'CUSR0000SAC_fred-md': [1, 2, 11, 12],
#  'PCEPI_fred-md': [12],
#  'EMPENT_PT_ea-qd': [12],
#  'REER42_PT_ea-md': [6, 7, 8, 9, 10, 11, 12],
#  'HICPOV_PT_ea-md': [12],
#  'HICPNEF_PT_ea-md': [12],
#  'HICPSV_PT_ea-md': [12],
#  'HICPNG_PT_ea-md': [1, 3, 4, 12],
#  'DFGDP_PT_ea-qd': [12],
#  'CCONFIX_PT_ea-md': [1, 2, 11, 12],
#  'epu_pt_epu': [6, 7, 8],
#  'GDP_PT_ea-qd': [1, 2, 3, 4, 5, 12],
#  'ULCIN_PT_ea-qd': [12],
#  'EXPGS_PT_ea-qd': [12],
#  'IMPGS_PT_ea-qd': [2, 3],
#  'CCI_PT_ea-md': [12],
#  'UNETOT_PT_ea-md': [12]}

# %%
tot = 0
for lags in lags_for_var.values():
    tot += len(lags)

tot
# Out:
# 61

# %% [markdown]
# # Defasamentos da variável alvo

# %%
from statsmodels.tsa.stattools import acf

import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4), dpi=500)

plot_acf(
    df_train['inflation_target'], 
    lags=24, alpha=.05, title='',
    ax=ax[0])

plot_pacf(
    df_train['inflation_target'], 
    lags=24, alpha=.05, title='',
    ax=ax[1])

ax[0].set_title("Autocorrelation Function (ACF)", loc='Left')
ax[0].set_xlabel("Lag", loc='left')
ax[0].set_ylabel("Autocorrelation", loc='top')
ax[0].set_ylim(-1.10, 1.10)

ax[1].set_title("Partial Autocorrelation Function (PACF)", loc='Left')
ax[1].set_xlabel("Lag", loc='left')
ax[1].set_ylabel("Partial Autocorrelation", loc='top')
ax[1].set_ylim(-1.10, 1.10)

ax[0].grid(True)
ax[1].grid(True)

plt.show()

# %% [markdown]
# A inflação em Portugal é afetada por uma memória de curto prazo, ou seja, a inflação homóloga do ano anterior não demontra ter relação estatiscamente significativa com a inflação do ano atual, no entanto, a inflação dos últimos 6-8 meses demonstra sempre ter grande impacto na inflação do presente.

# %%
fig, ax = plt.subplots(figsize=(10, 4), dpi=500)

plot_acf(
    df_train['inflation_target'], 
    lags=24, alpha=.05, title='',
    ax=ax)

ax.set_title("Função de Autocorrelação (ACF)", loc='Left', 
            fontdict=dict(fontsize=22))
ax.set_xlabel("Lag", loc='left',
             fontdict=dict(fontsize=16))
ax.set_ylabel("Autocorrelação", loc='top',
             fontdict=dict(fontsize=16))

ax.set_ylim(-0.10, 1.10)
ax.grid(True)
plt.show()

# %%
df_transformed.head(3)
# Out:
#             PCEPI_fred-md  UNETOT_PT_ea-md  CCI_PT_ea-md  IMPGS_PT_ea-qd  \
# Date
# 2000-01-01      -1.672367        -1.181375      1.622256       -1.292128
# 2000-02-01      -1.652773        -1.239516      1.555927       -1.236524
# 2000-03-01      -1.626023        -1.268586      1.417198       -1.176579
#
#             EXPGS_PT_ea-qd  GS5_fred-md  CCONFIX_PT_ea-md  EMPENT_PT_ea-qd  \
# Date
# 2000-01-01       -1.333842     2.651460          1.612561        -1.857139
# 2000-02-01       -1.348731     2.718651          1.557800        -1.854185
# 2000-03-01       -1.373899     2.597707          1.539546        -1.838577
#
#             GS1_fred-md  HICPSV_PT_ea-md  ...  REER42_PT_ea-md  \
# Date                                      ...
# 2000-01-01     2.370485        -2.090914  ...        -2.037451
# 2000-02-01     2.425870        -2.082324  ...        -2.347105
# 2000-03-01     2.425870        -2.075948  ...        -2.538577
#
#             HICPNG_PT_ea-md  PPIPT_ppi  ULCIN_PT_ea-qd  GDP_PT_ea-qd  \
# Date
# 2000-01-01        -1.810267   2.112112       -2.309865     -1.911430
# 2000-02-01        -1.802991   2.266949       -2.113992     -1.853788
# 2000-03-01        -1.802610   1.956981       -1.917631     -1.759427
#
#             CUSR0000SAC_fred-md  epu_pt_epu  DFGDP_PT_ea-qd  \
# Date
# 2000-01-01            -5.199338    0.579501       -5.199338
# 2000-02-01            -2.531313    0.517177       -2.683129
# 2000-03-01            -1.888129   -1.118873       -2.309995
#
#             OILPRICEx_fred-md_Eur  inflation_target
# Date
# 2000-01-01              -1.466960               2.1
# 2000-02-01              -1.118196               1.8
# 2000-03-01              -0.958600               1.5
#
# [3 rows x 22 columns]

# %%
target = 'inflation_target'
df_lags_target = df_transformed[[target]].copy()

for lag in range(1, 13):
    new_var = f'{target}_lag{lag}'
    df_lags_target[new_var] = df_lags_target[target].shift(lag)

# df_lags_target.dropna(inplace=True)
X = df_lags_target.dropna().drop(target, axis=1)
y = df_lags_target[target].iloc[12:]

clf = Lasso(alpha=0.1, max_iter=1000, random_state=322)

clf.fit(X, y)
# Out:
# Lasso(alpha=0.1, random_state=322)

# %%
coef = np.abs(clf.coef_)
var_coef = dict()

for i, col in enumerate(X.columns):
    # print(f"{col} - {coef[i]}")
    if coef[i] != 0:
        var_coef[col] = coef[i]

pd.Series(var_coef).sort_values(ascending=False)
# Out:
# inflation_target_lag1     0.977512
# inflation_target_lag11    0.043256
# inflation_target_lag10    0.007089
# dtype: float64

# %%
df_lags.head()
# Out:
#             PCEPI_fred-md  UNETOT_PT_ea-md  CCI_PT_ea-md  IMPGS_PT_ea-qd  \
# Date
# 2000-01-01      -1.672367        -1.181375      1.622256       -1.292128
# 2000-02-01      -1.652773        -1.239516      1.555927       -1.236524
# 2000-03-01      -1.626023        -1.268586      1.417198       -1.176579
# 2000-04-01      -1.631220        -1.297657      1.212752       -1.142906
# 2000-05-01      -1.626023        -1.268586      1.103049       -1.145707
#
#             EXPGS_PT_ea-qd  GS5_fred-md  CCONFIX_PT_ea-md  EMPENT_PT_ea-qd  \
# Date
# 2000-01-01       -1.333842     2.651460          1.612561        -1.857139
# 2000-02-01       -1.348731     2.718651          1.557800        -1.854185
# 2000-03-01       -1.373899     2.597707          1.539546        -1.838577
# 2000-04-01       -1.394979     2.436448          0.991927        -1.805954
# 2000-05-01       -1.402864     2.725370          1.101451        -1.761853
#
#             GS1_fred-md  HICPSV_PT_ea-md  ...  OILPRICEx_fred-md_Eur_lag3  \
# Date                                      ...
# 2000-01-01     2.370485        -2.090914  ...                         NaN
# 2000-02-01     2.425870        -2.082324  ...                         NaN
# 2000-03-01     2.425870        -2.075948  ...                         NaN
# 2000-04-01     2.387100        -2.069746  ...                   -1.466960
# 2000-05-01     2.486794        -2.054342  ...                   -1.118196
#
#             OILPRICEx_fred-md_Eur_lag4  OILPRICEx_fred-md_Eur_lag5  \
# Date
# 2000-01-01                         NaN                         NaN
# 2000-02-01                         NaN                         NaN
# 2000-03-01                         NaN                         NaN
# 2000-04-01                         NaN                         NaN
# 2000-05-01                    -1.46696                         NaN
#
#             OILPRICEx_fred-md_Eur_lag6  OILPRICEx_fred-md_Eur_lag7  \
# Date
# 2000-01-01                         NaN                         NaN
# 2000-02-01                         NaN                         NaN
# 2000-03-01                         NaN                         NaN
# 2000-04-01                         NaN                         NaN
# 2000-05-01                         NaN                         NaN
#
#             OILPRICEx_fred-md_Eur_lag8  OILPRICEx_fred-md_Eur_lag9  \
# Date
# 2000-01-01                         NaN                         NaN
# 2000-02-01                         NaN                         NaN
# 2000-03-01                         NaN                         NaN
# 2000-04-01                         NaN                         NaN
# 2000-05-01                         NaN                         NaN
#
#             OILPRICEx_fred-md_Eur_lag10  OILPRICEx_fred-md_Eur_lag11  \
# Date
# 2000-01-01                          NaN                          NaN
# 2000-02-01                          NaN                          NaN
# 2000-03-01                          NaN                          NaN
# 2000-04-01                          NaN                          NaN
# 2000-05-01                          NaN                          NaN
#
#             OILPRICEx_fred-md_Eur_lag12
# Date
# 2000-01-01                          NaN
# 2000-02-01                          NaN
# 2000-03-01                          NaN
# 2000-04-01                          NaN
# 2000-05-01                          NaN
#
# [5 rows x 274 columns]

# %%
df_final = df_lags[[col for col in df_lags.columns if 'lag' not in col]].copy()
df_final.head()
# Out:
#             PCEPI_fred-md  UNETOT_PT_ea-md  CCI_PT_ea-md  IMPGS_PT_ea-qd  \
# Date
# 2000-01-01      -1.672367        -1.181375      1.622256       -1.292128
# 2000-02-01      -1.652773        -1.239516      1.555927       -1.236524
# 2000-03-01      -1.626023        -1.268586      1.417198       -1.176579
# 2000-04-01      -1.631220        -1.297657      1.212752       -1.142906
# 2000-05-01      -1.626023        -1.268586      1.103049       -1.145707
#
#             EXPGS_PT_ea-qd  GS5_fred-md  CCONFIX_PT_ea-md  EMPENT_PT_ea-qd  \
# Date
# 2000-01-01       -1.333842     2.651460          1.612561        -1.857139
# 2000-02-01       -1.348731     2.718651          1.557800        -1.854185
# 2000-03-01       -1.373899     2.597707          1.539546        -1.838577
# 2000-04-01       -1.394979     2.436448          0.991927        -1.805954
# 2000-05-01       -1.402864     2.725370          1.101451        -1.761853
#
#             GS1_fred-md  HICPSV_PT_ea-md  ...  REER42_PT_ea-md  \
# Date                                      ...
# 2000-01-01     2.370485        -2.090914  ...        -2.037451
# 2000-02-01     2.425870        -2.082324  ...        -2.347105
# 2000-03-01     2.425870        -2.075948  ...        -2.538577
# 2000-04-01     2.387100        -2.069746  ...        -2.414996
# 2000-05-01     2.486794        -2.054342  ...        -2.394699
#
#             HICPNG_PT_ea-md  PPIPT_ppi  ULCIN_PT_ea-qd  GDP_PT_ea-qd  \
# Date
# 2000-01-01        -1.810267   2.112112       -2.309865     -1.911430
# 2000-02-01        -1.802991   2.266949       -2.113992     -1.853788
# 2000-03-01        -1.802610   1.956981       -1.917631     -1.759427
# 2000-04-01        -1.703956   1.819146       -1.779384     -2.062445
# 2000-05-01        -1.715435   1.700008       -1.741123     -2.276094
#
#             CUSR0000SAC_fred-md  epu_pt_epu  DFGDP_PT_ea-qd  \
# Date
# 2000-01-01            -5.199338    0.579501       -5.199338
# 2000-02-01            -2.531313    0.517177       -2.683129
# 2000-03-01            -1.888129   -1.118873       -2.309995
# 2000-04-01            -2.049594   -1.083752       -2.389831
# 2000-05-01            -2.049594   -0.669207       -2.273296
#
#             OILPRICEx_fred-md_Eur  inflation_target
# Date
# 2000-01-01              -1.466960               2.1
# 2000-02-01              -1.118196               1.8
# 2000-03-01              -0.958600               1.5
# 2000-04-01              -1.336194               2.1
# 2000-05-01              -0.992480               2.5
#
# [5 rows x 22 columns]

# %%
for col, lags in lags_selected.items():
    for lag in lags:
        if 'lag' in lag:
            df_final[lag] = df_lags[lag]

df_final.head()
# Out:
#             PCEPI_fred-md  UNETOT_PT_ea-md  CCI_PT_ea-md  IMPGS_PT_ea-qd  \
# Date
# 2000-01-01      -1.672367        -1.181375      1.622256       -1.292128
# 2000-02-01      -1.652773        -1.239516      1.555927       -1.236524
# 2000-03-01      -1.626023        -1.268586      1.417198       -1.176579
# 2000-04-01      -1.631220        -1.297657      1.212752       -1.142906
# 2000-05-01      -1.626023        -1.268586      1.103049       -1.145707
#
#             EXPGS_PT_ea-qd  GS5_fred-md  CCONFIX_PT_ea-md  EMPENT_PT_ea-qd  \
# Date
# 2000-01-01       -1.333842     2.651460          1.612561        -1.857139
# 2000-02-01       -1.348731     2.718651          1.557800        -1.854185
# 2000-03-01       -1.373899     2.597707          1.539546        -1.838577
# 2000-04-01       -1.394979     2.436448          0.991927        -1.805954
# 2000-05-01       -1.402864     2.725370          1.101451        -1.761853
#
#             GS1_fred-md  HICPSV_PT_ea-md  ...  GDP_PT_ea-qd_lag3  \
# Date                                      ...
# 2000-01-01     2.370485        -2.090914  ...                NaN
# 2000-02-01     2.425870        -2.082324  ...                NaN
# 2000-03-01     2.425870        -2.075948  ...                NaN
# 2000-04-01     2.387100        -2.069746  ...          -1.911430
# 2000-05-01     2.486794        -2.054342  ...          -1.853788
#
#             GDP_PT_ea-qd_lag4  GDP_PT_ea-qd_lag5  GDP_PT_ea-qd_lag12  \
# Date
# 2000-01-01                NaN                NaN                 NaN
# 2000-02-01                NaN                NaN                 NaN
# 2000-03-01                NaN                NaN                 NaN
# 2000-04-01                NaN                NaN                 NaN
# 2000-05-01           -1.91143                NaN                 NaN
#
#             ULCIN_PT_ea-qd_lag12  EXPGS_PT_ea-qd_lag12  IMPGS_PT_ea-qd_lag2  \
# Date
# 2000-01-01                   NaN                   NaN                  NaN
# 2000-02-01                   NaN                   NaN                  NaN
# 2000-03-01                   NaN                   NaN            -1.292128
# 2000-04-01                   NaN                   NaN            -1.236524
# 2000-05-01                   NaN                   NaN            -1.176579
#
#             IMPGS_PT_ea-qd_lag3  CCI_PT_ea-md_lag12  UNETOT_PT_ea-md_lag12
# Date
# 2000-01-01                  NaN                 NaN                    NaN
# 2000-02-01                  NaN                 NaN                    NaN
# 2000-03-01                  NaN                 NaN                    NaN
# 2000-04-01            -1.292128                 NaN                    NaN
# 2000-05-01            -1.236524                 NaN                    NaN
#
# [5 rows x 83 columns]

# %%
df_lags_target.head()
# Out:
#             inflation_target  inflation_target_lag1  inflation_target_lag2  \
# Date
# 2000-01-01               2.1                    NaN                    NaN
# 2000-02-01               1.8                    2.1                    NaN
# 2000-03-01               1.5                    1.8                    2.1
# 2000-04-01               2.1                    1.5                    1.8
# 2000-05-01               2.5                    2.1                    1.5
#
#             inflation_target_lag3  inflation_target_lag4  \
# Date
# 2000-01-01                    NaN                    NaN
# 2000-02-01                    NaN                    NaN
# 2000-03-01                    NaN                    NaN
# 2000-04-01                    2.1                    NaN
# 2000-05-01                    1.8                    2.1
#
#             inflation_target_lag5  inflation_target_lag6  \
# Date
# 2000-01-01                    NaN                    NaN
# 2000-02-01                    NaN                    NaN
# 2000-03-01                    NaN                    NaN
# 2000-04-01                    NaN                    NaN
# 2000-05-01                    NaN                    NaN
#
#             inflation_target_lag7  inflation_target_lag8  \
# Date
# 2000-01-01                    NaN                    NaN
# 2000-02-01                    NaN                    NaN
# 2000-03-01                    NaN                    NaN
# 2000-04-01                    NaN                    NaN
# 2000-05-01                    NaN                    NaN
#
#             inflation_target_lag9  inflation_target_lag10  \
# Date
# 2000-01-01                    NaN                     NaN
# 2000-02-01                    NaN                     NaN
# 2000-03-01                    NaN                     NaN
# 2000-04-01                    NaN                     NaN
# 2000-05-01                    NaN                     NaN
#
#             inflation_target_lag11  inflation_target_lag12
# Date
# 2000-01-01                     NaN                     NaN
# 2000-02-01                     NaN                     NaN
# 2000-03-01                     NaN                     NaN
# 2000-04-01                     NaN                     NaN
# 2000-05-01                     NaN                     NaN

# %%
df_final['inflation_target_lag1'] = df_lags_target['inflation_target_lag1']
df_final.to_csv('dados/train_lags.csv', index=True)
