# %% [markdown]
# # **Modeling ML**
#
# Este notebook estuda a previsão de `inflation_target` com modelos de machine learning, usando variáveis teóricas em nível, lags selecionados e diferentes combinações dessas variáveis. A comparação entre modelos é feita com métricas de erro e análise de overfitting no treino e no teste.

# %%
# ! pip install lightgbm

# %%
# ! pip install optuna 
# Optuna is a hyperparameter optimization framework that automates the process of finding the best hyperparameters for machine learning models.

# %%
import numpy as np
import pandas as pd

from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import TimeSeriesSplit
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
from lightgbm import LGBMRegressor
import matplotlib.pyplot as plt
import optuna
import pipeline_datapreparation as DataPipeline
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

RANDOM_STATE = 322
np.random.seed(RANDOM_STATE)

# %% [markdown]
# ---

# %% [markdown]
# ## **Configurações**

# %% [markdown]
# ### **Obtenção dos dados**
# Os conjuntos de treino e teste já estão divididos previamente. Ambos passam pela mesma *pipeline* com seleção de variáveis, tratamento de outliers e criação dos lags selecionados.

# %%
df_train = DataPipeline.prepare_dataset(
    "dados/train.csv",
    select_features=True,
    stationary=False,
    treat_outliers=True,
    create_lags=True,
)["prepared_data"]

df_test = DataPipeline.prepare_dataset(
    "dados/test.csv",
    select_features=True,
    stationary=False,
    treat_outliers=True,
    create_lags=True,
)["prepared_data"].loc["2023-07-01":]

TARGET_COL = DataPipeline.TARGET_COL

THEORETICAL_VARIABLES = [
     "epu_pt_epu",
     "ULCIN_PT_ea-qd",
     "EXPGS_PT_ea-qd",
     "IMPGS_PT_ea-qd",
     "CCI_PT_ea-md",
     "GDP_PT_ea-qd",
     "UNETOT_PT_ea-md",
     "PPIPT_ppi",
]

# %%
import importlib
import pipeline_datapreparation as p

importlib.reload(p)
print(p.__file__)
# Out:
# c:\Users\sasah\Documents\faculdade\3Ano_Goncalo_Henriques\2_Semestre_2025_2026\Projeto_Final\pipeline_datapreparation.py

# %% [markdown]
# ### **Modelos**
#
# Modelos avaliados: **`Ridge`**, **`Random Forest`** e **`LGBMRegressor`**.

# %%
models = {
    "Ridge": Ridge(random_state=RANDOM_STATE),
    "RF - MSE": RandomForestRegressor(
        criterion='squared_error',
        random_state=RANDOM_STATE,
    ),
    "RF - MAE": RandomForestRegressor(
        criterion='absolute_error',
        random_state=RANDOM_STATE,
    ),
    "LGBMRegressor": LGBMRegressor(        
        random_state=RANDOM_STATE,
        verbose=-1,
    ),
}

# %% [markdown]
# ### **Avaliação**
#
# As métricas calculadas são **`RMSE`** e **`MAE`** em valor absoluto, e **`WAPE (%)`** em percentagem. Para verificar *overfitting*, compara-se o erro de teste com o erro de treino e considera-se que existe *overfitting* quando essa diferença percentual ultrapassa **15%** em pelo menos uma das métricas.

# %%
OVERFITTING_THRESHOLD_PCT = 15.0

def relative_error_increase_pct(train_metric, test_metric):
    if pd.isna(train_metric) or train_metric == 0:
        return np.nan
    return round(((test_metric - train_metric) / train_metric) * 100, 3)

def has_overfitting(train_metrics, test_metrics, threshold_pct=OVERFITTING_THRESHOLD_PCT):
    metric_increases = [
        relative_error_increase_pct(train_metric, test_metric)
        for train_metric, test_metric in zip(train_metrics, test_metrics)
    ]
    return any(pd.notna(increase) and increase > threshold_pct for increase in metric_increases)

def regression_metrics(y_true, y_pred):
    rmse = round(np.sqrt(mean_squared_error(y_true, y_pred)), 2)
    mae = round(mean_absolute_error(y_true, y_pred), 2)
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)
    denom = np.sum(np.abs(y_true))
    wape = np.sum(np.abs(y_true - y_pred)) / denom if denom != 0 else np.nan
    return (
        rmse,
        mae,
        round(wape, 5) if not np.isnan(wape) else np.nan,
    )

metric_cols = ["rmse", "mae", "wape"]

colors = {"Treino": "#8E9091", "Teste": "#5B8CC0"}

# %% [markdown]
# ### **Ranking Models**

# %%
def rank_models_by_average_test_rank(performance_df):
    ranked_df = performance_df.copy()

    ranked_df["rank_test_rmse"] = ranked_df["test_rmse"].rank(
        method="average", # empates recebem a média dos ranks possíveis
        ascending=True,
    )

    ranked_df["rank_test_mae"] = ranked_df["test_mae"].rank(
        method="average",
        ascending=True,
    )

    ranked_df["rank_test_wape"] = ranked_df["test_wape"].rank(
        method="average",
        ascending=True,
    )

    ranked_df["Overfitting?"] = ranked_df.apply(
        lambda row: has_overfitting(
            [row["train_rmse"], row["train_mae"], row["train_wape"]],
            [row["test_rmse"], row["test_mae"], row["test_wape"]],
        ),
        axis=1,
    )

    ranked_df["rank_medio"] = ranked_df[
        ["rank_test_rmse", "rank_test_mae", "rank_test_wape"]
    ].mean(axis=1)

    ranked_df = (
        ranked_df
        .sort_values(["rank_medio"])
        .reset_index(drop=True)
    )

    return ranked_df

# %% [markdown]
# ---

# %% [markdown]
# ## **Modelação com o desfasamento da variável alvo**
#
# Nesta seção avalia-se um modelo base usando apenas `inflation_target` e o seu primeiro lag (`inflation_target_lag_1`). O objetivo é servir de referência para comparar o desempenho dos modelos com variáveis teóricas, em nível e com lags.
#
# A comparação entre treino e teste é feita com `RMSE`, `MAE` e `WAPE (%)`. Considera-se *overfitting* quando o erro de teste ultrapassa em mais de `15%` o erro de treino em pelo menos uma destas métricas.

# %%
# target_lag_col = f"{TARGET_COL}_lag_1"
target_lag_col = [f"{TARGET_COL}_lag_{i}" for i in range(1, 4)]


# train_lag_df = df_train[[TARGET_COL, target_lag_col]].dropna().copy()
# test_lag_df = df_test[[TARGET_COL, target_lag_col]].dropna().copy()

train_lag_df = df_train[[TARGET_COL] + target_lag_col].dropna().copy()
test_lag_df = df_test[[TARGET_COL] + target_lag_col].copy()


# Ajustamento das datas de treino e teste para garantir que não haja sobreposição de datas
common_dates = train_lag_df.index.intersection(test_lag_df.index)
test_lag_df = test_lag_df.drop(index=common_dates)

X_train = train_lag_df[target_lag_col]
y_train = train_lag_df[TARGET_COL]

X_test = test_lag_df[target_lag_col]
y_test = test_lag_df[TARGET_COL]

print(f"Train: {X_train.index.min().date()} -> {X_train.index.max().date()} | {len(X_train)} obs")
print(f"Test:  {X_test.index.min().date()} -> {X_test.index.max().date()} | {len(X_test)} obs")
# Out:
# Train: 2000-04-01 -> 2023-06-01 | 279 obs
# Test:  2023-07-01 -> 2025-10-01 | 28 obs

# %%
X_train
# Out:
#             inflation_target_lag_1  inflation_target_lag_2  \
# Date
# 2000-04-01                     1.5                     1.8
# 2000-05-01                     2.1                     1.5
# 2000-06-01                     2.5                     2.1
# 2000-07-01                     2.9                     2.5
# 2000-08-01                     3.3                     2.9
# ...                            ...                     ...
# 2023-02-01                     8.4                     9.6
# 2023-03-01                     8.2                     8.4
# 2023-04-01                     7.4                     8.2
# 2023-05-01                     5.7                     7.4
# 2023-06-01                     4.0                     5.7
#
#             inflation_target_lag_3
# Date
# 2000-04-01                     2.1
# 2000-05-01                     1.8
# 2000-06-01                     1.5
# 2000-07-01                     2.1
# 2000-08-01                     2.5
# ...                            ...
# 2023-02-01                     9.9
# 2023-03-01                     9.6
# 2023-04-01                     8.4
# 2023-05-01                     8.2
# 2023-06-01                     7.4
#
# [279 rows x 3 columns]

# %%
results = []
predictions = {}

for model_name, model in models.items():
    model.fit(X_train, y_train)

    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)

    train_rmse, train_mae, train_wape = regression_metrics(y_train, y_pred_train)
    test_rmse, test_mae, test_wape = regression_metrics(y_test, y_pred_test)

    results.append({
        "model": model_name,
        "train_rmse": train_rmse,
        "train_mae": train_mae,
        "train_wape": train_wape,
        "test_rmse": test_rmse,
        "test_mae": test_mae,
        "test_wape": test_wape,
        "relative_error_increase_pct_rmse": relative_error_increase_pct(train_rmse, test_rmse),
        "relative_error_increase_pct_mae": relative_error_increase_pct(train_mae, test_mae),
        "relative_error_increase_pct_wape": relative_error_increase_pct(train_wape, test_wape),
        "Overfitting?": has_overfitting(
            [train_rmse, train_mae, train_wape],
            [test_rmse, test_mae, test_wape],
        ),
    })

    predictions[model_name] = pd.DataFrame(
        {"y_true": y_test, "y_pred": y_pred_test},
        index=y_test.index,
    )

metrics_df = pd.DataFrame(results).sort_values("test_rmse").reset_index(drop=True)
metrics_df = rank_models_by_average_test_rank(metrics_df)
display(metrics_df)
# Out:
#            model  train_rmse  train_mae  train_wape  test_rmse  test_mae  \
# 0       RF - MAE        0.21       0.15     0.06506       0.48      0.33
# 1       RF - MSE        0.20       0.14     0.06209       0.50      0.35
# 2          Ridge        0.39       0.30     0.13147       0.51      0.38
# 3  LGBMRegressor        0.63       0.36     0.15863       0.52      0.39
#
#    test_wape  relative_error_increase_pct_rmse  \
# 0    0.13693                           128.571
# 1    0.14265                           150.000
# 2    0.15565                            30.769
# 3    0.16169                           -17.460
#
#    relative_error_increase_pct_mae  relative_error_increase_pct_wape  \
# 0                          120.000                           110.467
# 1                          150.000                           129.747
# 2                           26.667                            18.392
# 3                            8.333                             1.929
#
#    Overfitting?  rank_test_rmse  rank_test_mae  rank_test_wape  rank_medio
# 0          True             1.0            1.0             1.0         1.0
# 1          True             2.0            2.0             2.0         2.0
# 2          True             3.0            3.0             3.0         3.0
# 3         False             4.0            4.0             4.0         4.0

# %%
theoretical_plot_data = []
metric_display = {"rmse": "RMSE", "mae": "MAE", "wape": "WAPE (%)"}

for _, row in metrics_df.iterrows():
    for metric in metric_cols:
        theoretical_plot_data.append({
            "model": row["model"],
            "metric": metric_display[metric],
            "dataset": "Treino",
            "value": row[f"train_{metric}"],
        })

        theoretical_plot_data.append({
            "model": row["model"],
            "metric": metric_display[metric],
            "dataset": "Teste",
            "value": row[f"test_{metric}"],
        })


theoretical_plot_df = pd.DataFrame(theoretical_plot_data)

fig, axes = plt.subplots(1, 3, figsize=(19, 6), sharex=False)

metrics_order = ["RMSE", "MAE", "WAPE (%)"]

for ax, metric in zip(axes, metrics_order):
    metric_df = theoretical_plot_df[theoretical_plot_df["metric"] == metric]
    pivot_df = metric_df.pivot(index="model", columns="dataset", values="value")
    pivot_df = pivot_df[["Treino", "Teste"]]

    pivot_df.plot(
        kind="bar",
        ax=ax,
        color=[colors["Treino"], colors["Teste"]],
        width=0.72,
        edgecolor="white",
        linewidth=0.7,
    )

    ymax = pivot_df.max().max()
    ax.set_ylim(0, ymax * 1.22)
    ax.set_title(metric, fontsize=13, fontweight="bold", pad=12)
    ax.set_xlabel("")
    ax.set_ylabel("Valor", fontsize=10)
    ax.tick_params(axis="x", rotation=20, labelsize=9)
    ax.tick_params(axis="y", labelsize=9)
    ax.grid(axis="y", alpha=0.25)
    ax.set_axisbelow(True)

    for container in ax.containers:
        for bar in container:
            height = bar.get_height()
            bar_color = bar.get_facecolor()
            ax.annotate(
                f"{height:.2f}",
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 4),
                textcoords="offset points",
                ha="center",
                va="bottom",
                fontsize=8.5,
                fontweight="bold",
                color=bar_color,
            )

    ax.get_legend().remove()

handles, labels = axes[0].get_legend_handles_labels()

fig.legend(
    handles,
    labels,
    loc="upper center",
    bbox_to_anchor=(0.5, 1.02),
    ncol=2,
    frameon=False,
)

fig.suptitle(
    "Desfasamento da variável alvo: treino vs teste",
    fontsize=15,
    fontweight="bold",
    y=1.07,
)

fig.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
def plot_top_model_metrics(metrics_df, top_n=1):
    top_models = metrics_df.sort_values("test_rmse").head(top_n).copy()

    metric_labels = ["RMSE", "MAE", "WAPE (%)"]
    train_cols = ["train_rmse", "train_mae", "train_wape"]
    test_cols = ["test_rmse", "test_mae", "test_wape"]

    for _, row in top_models.iterrows():
        model_name = row["model"]
        overfitting_col = "Overfitting?" if "Overfitting?" in row.index else "overfitting?"
        overfitting = row[overfitting_col]

        train_values = [row[col] for col in train_cols]
        test_values = [row[col] for col in test_cols]

        x = np.arange(len(metric_labels))
        width = 0.35

        fig, ax = plt.subplots(figsize=(11, 6.5))

        bars_train = ax.bar(
            x - width / 2,
            train_values,
            width,
            label="Treino fitted",
            color=colors["Treino"],
            edgecolor="white",
            linewidth=0.7,
        )

        bars_test = ax.bar(
            x + width / 2,
            test_values,
            width,
            label="Teste forecast",
            color=colors["Teste"],
            edgecolor="white",
            linewidth=0.7,
        )

        ymax = max(max(train_values), max(test_values))
        ax.set_ylim(0, ymax * 1.22)

        fig.suptitle(
            f"{model_name}: treino vs teste (Overfitting? - {overfitting})",
            fontsize=14,
            fontweight="bold",
            y=0.97,
        )

        fig.legend(
            handles=[bars_train, bars_test],
            labels=["Treino fitted", "Teste forecast"],
            loc="upper center",
            bbox_to_anchor=(0.5, 0.91),
            ncol=2,
            frameon=False,
        )

        ax.set_ylabel("Valor", fontsize=11)
        ax.set_xticks(x)
        ax.set_xticklabels(metric_labels, fontsize=10)
        ax.tick_params(axis="y", labelsize=10)
        ax.grid(axis="y", alpha=0.25)
        ax.set_axisbelow(True)

        for bars in [bars_train, bars_test]:
            labels = [f"{bar.get_height():.2f}" for bar in bars]
            ax.bar_label(
                bars,
                labels=labels,
                padding=3,
                fontsize=9,
                fontweight="bold",
            )

        fig.subplots_adjust(top=0.80)
        plt.show()


plot_top_model_metrics(metrics_df, top_n=1)

# %% [markdown]
# ---

# %% [markdown]
# ## **Modelos com variáveis teóricas em nível**
#
# Nesta secção usam-se apenas as variáveis teóricas selecionadas, em nível. A `pipeline` é aplicada para preparar os dados e tratar os *outliers*, sem criação de lags. Os modelos são comparados com `RMSE`, `MAE` e `WAPE`, avaliando o desempenho em treino e teste.

# %%
from sklearn.base import clone

level_cols = [TARGET_COL] + THEORETICAL_VARIABLES

train_levels = df_train[level_cols].dropna().copy()
test_levels = df_test[level_cols].dropna().copy()

# Ajustamento das datas de treino e teste para garantir que não haja sobreposição de datas
common_dates = train_levels.index.intersection(test_levels.index)
test_levels = test_levels.drop(index=common_dates)

X_train = train_levels[THEORETICAL_VARIABLES]
y_train = train_levels[TARGET_COL]

X_test = test_levels[THEORETICAL_VARIABLES]
y_test = test_levels[TARGET_COL]

print(f"Treino: {X_train.index.min().date()} -> {X_train.index.max().date()} | {len(X_train)} obs")
print(f"Teste:  {X_test.index.min().date()} -> {X_test.index.max().date()} | {len(X_test)} obs")
# Out:
# Treino: 2000-01-01 -> 2023-06-01 | 282 obs
# Teste:  2023-07-01 -> 2025-10-01 | 28 obs

# %%
results = []
predictions = {}

for model_name, model in models.items():
    fitted_model = clone(model)
    fitted_model.fit(X_train, y_train)

    y_pred_train = fitted_model.predict(X_train)
    y_pred_test = fitted_model.predict(X_test)

    train_rmse, train_mae, train_wape = regression_metrics(y_train, y_pred_train)
    test_rmse, test_mae, test_wape = regression_metrics(y_test, y_pred_test)

    results.append({
        "model": model_name,
        "train_rmse": train_rmse,
        "train_mae": train_mae,
        "train_wape": train_wape,
        "test_rmse": test_rmse,
        "test_mae": test_mae,
        "test_wape": test_wape,
        "Overfitting?": has_overfitting(
            [train_rmse, train_mae, train_wape],
            [test_rmse, test_mae, test_wape],
        ),
    })

    predictions[model_name] = pd.DataFrame(
        {"y_true": y_test, "y_pred": y_pred_test},
        index=y_test.index,
    )

theoretical_metrics_df = pd.DataFrame(results).sort_values("test_rmse").reset_index(drop=True)
theoretical_metrics_df = rank_models_by_average_test_rank(theoretical_metrics_df)
display(theoretical_metrics_df)
# Out:
#            model  train_rmse  train_mae  train_wape  test_rmse  test_mae  \
# 0          Ridge        1.04       0.82     0.36703       1.18      0.96
# 1       RF - MSE        0.16       0.11     0.04761       2.06      1.98
# 2       RF - MAE        0.16       0.11     0.05020       2.21      1.80
# 3  LGBMRegressor        0.26       0.18     0.07900       2.13      2.02
#
#    test_wape  Overfitting?  rank_test_rmse  rank_test_mae  rank_test_wape  \
# 0    0.39397          True             1.0            1.0             1.0
# 1    0.81330          True             2.0            3.0             3.0
# 2    0.74029          True             4.0            2.0             2.0
# 3    0.83082          True             3.0            4.0             4.0
#
#    rank_medio
# 0    1.000000
# 1    2.666667
# 2    2.666667
# 3    3.666667

# %%
def plot_top_theoretical_model_metrics(theoretical_metrics_df, top_n=1):
    top_models = theoretical_metrics_df.sort_values("test_rmse").head(top_n).copy()

    metric_labels = ["RMSE", "MAE", "WAPE (%)"]
    train_cols = ["train_rmse", "train_mae", "train_wape"]
    test_cols = ["test_rmse", "test_mae", "test_wape"]

    for _, row in top_models.iterrows():
        model_name = row["model"]
        overfitting_col = "Overfitting?" if "Overfitting?" in row.index else "overfitting?"
        overfitting = row[overfitting_col]

        train_values = [row[col] for col in train_cols]
        test_values = [row[col] for col in test_cols]

        x = np.arange(len(metric_labels))
        width = 0.35

        fig, ax = plt.subplots(figsize=(11, 6.5))

        bars_train = ax.bar(
            x - width / 2,
            train_values,
            width,
            label="Treino fitted",
            color=colors["Treino"],
            edgecolor="white",
            linewidth=0.7,
        )

        bars_test = ax.bar(
            x + width / 2,
            test_values,
            width,
            label="Teste forecast",
            color=colors["Teste"],
            edgecolor="white",
            linewidth=0.7,
        )

        ymax = max(max(train_values), max(test_values))
        ax.set_ylim(0, ymax * 1.22)

        fig.suptitle(
            f"{model_name}: treino vs teste (Overfitting? - {overfitting})",
            fontsize=14,
            fontweight="bold",
            y=0.97,
        )

        fig.legend(
            handles=[bars_train, bars_test],
            labels=["Treino fitted", "Teste forecast"],
            loc="upper center",
            bbox_to_anchor=(0.5, 0.91),
            ncol=2,
            frameon=False,
        )

        ax.set_ylabel("Valor", fontsize=11)
        ax.set_xticks(x)
        ax.set_xticklabels(metric_labels, fontsize=10)
        ax.tick_params(axis="y", labelsize=10)
        ax.grid(axis="y", alpha=0.25)
        ax.set_axisbelow(True)

        for bars in [bars_train, bars_test]:
            labels = [f"{bar.get_height():.2f}" for bar in bars]
            ax.bar_label(
                bars,
                labels=labels,
                padding=3,
                fontsize=9,
                fontweight="bold",
            )

        fig.subplots_adjust(top=0.80)
        plt.show()


plot_top_theoretical_model_metrics(theoretical_metrics_df, top_n=1)

# %% [markdown]
# ---

# %% [markdown]
# ## **Modelos com variáveis teóricas em nível e os respetivos lags significativos**
#
# Nesta fase usam-se as variáveis teóricas em nivel e, para cada uma, os respetivos lags na lista `SELECTED_LAGS`. A *pipeline* aplica o tratamento de outliers e cria os lags selecionados de forma gradual.

# %%
var_lags = {'GS1_fred-md': [10],
 'GS5_fred-md': [12],
 'OILPRICEx_fred-md_Eur': [1, 2, 3, 4, 5, 6, 7, 12],
 'CUSR0000SAC_fred-md': [1, 2, 11, 12],
 'PCEPI_fred-md': [12],
 'EMPENT_PT_ea-qd': [12],
 'REER42_PT_ea-md': [6, 7, 8, 9, 10, 11, 12],
 'HICPOV_PT_ea-md': [12],
 'HICPNEF_PT_ea-md': [12],
 'HICPSV_PT_ea-md': [12],
 'HICPNG_PT_ea-md': [1, 3, 4, 12],
 'DFGDP_PT_ea-qd': [12],
 'CCONFIX_PT_ea-md': [1, 2, 11, 12],
 'epu_pt_epu': [6, 7, 8],
 'GDP_PT_ea-qd': [1, 2, 3, 4, 5, 12],
 'ULCIN_PT_ea-qd': [12],
 'EXPGS_PT_ea-qd': [12],
 'IMPGS_PT_ea-qd': [2, 3],
 'CCI_PT_ea-md': [12],
 'UNETOT_PT_ea-md': [12],
 'PPIPT_ppi': [1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 12]}

# %%
COMPUTACIONAL_VARIABLES = [
    'GS1_fred-md', 'GS5_fred-md', 'OILPRICEx_fred-md_Eur',
    'CUSR0000SAC_fred-md', 'PCEPI_fred-md', 'EMPENT_PT_ea-qd',
    'REER42_PT_ea-md', 'HICPOV_PT_ea-md', 'HICPNEF_PT_ea-md',
    'HICPSV_PT_ea-md', 'HICPNG_PT_ea-md', 'DFGDP_PT_ea-qd',
    'CCONFIX_PT_ea-md'
]

# %%
def build_lag_model(lag, models=models, include_target_lags=False, variables=THEORETICAL_VARIABLES):
    lags = list()
    for key, value in var_lags.items():
        if key in variables:
            for v in value:
                if v <= lag:
                    lags.append(f'{key}_lag_{v}')

    scores_train = {}
    scores_test = {}
    if include_target_lags:
        target_lags = ["inflation_target_lag_1"]

    # root_mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
    if include_target_lags:
        X_train = df_train[variables + lags + target_lags].dropna()
    else:
        X_train = df_train[variables + lags].dropna()
    y_train = df_train[TARGET_COL].iloc[lag:]
    
    if include_target_lags:
        X_test = df_test[variables + lags + target_lags]
    else:
        X_test = df_test[variables + lags]
    y_test = df_test[TARGET_COL]
    
    for model_name, clf in models.items():
        model_score_train = dict()
        model_score_test = dict()
        clf.fit(X_train, y_train)
    
        # Train set
        pred = clf.predict(X_train)
        model_score_train['rmse'], model_score_train['mae'], model_score_train['wape'] = regression_metrics(y_train, pred)
    
        # Test set
        pred = clf.predict(X_test)
        model_score_test['rmse'], model_score_test['mae'], model_score_test['wape'] = regression_metrics(y_test, pred)

        scores_train[model_name] = model_score_train
        scores_test[model_name] = model_score_test

    return X_test, scores_train, scores_test

# %%
def evaluate_lag_performance(
    variables,
    include_target_lags=False,
    lag_range=range(1, 13),
    models=models,
):
    lag_performance = {}

    for lag in lag_range:
        X_test, scores_train, scores_test = build_lag_model(
            lag=lag,
            models=models,
            include_target_lags=include_target_lags,
            variables=variables,
        )

        lag_performance[lag] = {
            "train": scores_train,
            "test": scores_test,
        }

    lag_performance_rows = []

    for lag, lag_results in lag_performance.items():
        for model_name in lag_results["train"].keys():
            row = {
                "lag": lag,
                "model": model_name,
                "train_rmse": lag_results["train"][model_name]["rmse"],
                "train_mae": lag_results["train"][model_name]["mae"],
                "train_wape": lag_results["train"][model_name]["wape"],
                "test_rmse": lag_results["test"][model_name]["rmse"],
                "test_mae": lag_results["test"][model_name]["mae"],
                "test_wape": lag_results["test"][model_name]["wape"],
            }
            lag_performance_rows.append(row)

    lag_performance_df = pd.DataFrame(lag_performance_rows)
    lag_performance_ranked_df = rank_models_by_average_test_rank(lag_performance_df)

    return {
        "raw_results": lag_performance,
        "performance_df": lag_performance_df,
        "ranked_df": lag_performance_ranked_df,
    }

# %%
results_computacional = evaluate_lag_performance(
    variables=COMPUTACIONAL_VARIABLES,
    include_target_lags=True,
)

results_theoretical = evaluate_lag_performance(
    variables=THEORETICAL_VARIABLES,
    include_target_lags=False,
)

# %%
lag_performance_df_theoretical = results_theoretical["ranked_df"][0:5]
print("Top 5 - Teóricas:")
lag_performance_df_theoretical
# Out:
# Top 5 - Teóricas:
#    lag          model  train_rmse  train_mae  train_wape  test_rmse  test_mae  \
# 0   10  LGBMRegressor        0.19       0.11     0.04937       0.48      0.40
# 1   11  LGBMRegressor        0.19       0.11     0.05019       0.63      0.50
# 2    7       RF - MSE        0.15       0.11     0.04999       0.70      0.57
# 3    8       RF - MSE        0.15       0.11     0.05070       0.69      0.58
# 4    9  LGBMRegressor        0.18       0.12     0.05188       0.68      0.58
#
#    test_wape  rank_test_rmse  rank_test_mae  rank_test_wape  Overfitting?  \
# 0    0.16222             1.0            1.0             1.0          True
# 1    0.20428             2.0            2.0             2.0          True
# 2    0.23538             5.0            3.0             3.0          True
# 3    0.23686             4.0            4.5             4.0          True
# 4    0.23967             3.0            4.5             5.0          True
#
#    rank_medio
# 0    1.000000
# 1    2.000000
# 2    3.666667
# 3    4.166667
# 4    4.166667

# %%
lag_performance_df_computacional = results_computacional["ranked_df"][0:5]
print("Top 5 - Computacionais:")    
lag_performance_df_computacional
# Out:
# Top 5 - Computacionais:
#    lag  model  train_rmse  train_mae  train_wape  test_rmse  test_mae  \
# 0   12  Ridge        0.23       0.17     0.07839       0.46      0.35
# 1   11  Ridge        0.31       0.23     0.10507       0.49      0.37
# 2    1  Ridge        0.34       0.26     0.11445       0.51      0.42
# 3    9  Ridge        0.32       0.24     0.10850       0.57      0.43
# 4    8  Ridge        0.32       0.24     0.10873       0.57      0.43
#
#    test_wape  rank_test_rmse  rank_test_mae  rank_test_wape  Overfitting?  \
# 0    0.14394             1.0            1.0             1.0          True
# 1    0.15003             2.0            2.0             2.0          True
# 2    0.17179             3.0            3.0             3.0          True
# 3    0.17582             9.0            5.0             4.0          True
# 4    0.17713             9.0            5.0             5.0          True
#
#    rank_medio
# 0    1.000000
# 1    2.000000
# 2    3.000000
# 3    6.000000
# 4    6.333333

# %%
def plot_top_lag_model_metrics(lag_performance_ranked_df):
    top5_models = lag_performance_ranked_df.head(3).copy()

    metric_labels = ["RMSE", "MAE", "WAPE (%)"]
    train_cols = ["train_rmse", "train_mae", "train_wape"]
    test_cols = ["test_rmse", "test_mae", "test_wape"]

    for _, row in top5_models.iterrows():
        model_name = row["model"]
        lag = row["lag"]
        overfitting = row["Overfitting?"]

        train_values = [row[col] for col in train_cols]
        test_values = [row[col] for col in test_cols]

        x = np.arange(len(metric_labels))
        width = 0.35

        fig, ax = plt.subplots(figsize=(11, 6.5))

        bars_train = ax.bar(
            x - width / 2,
            train_values,
            width,
            label="Treino fitted",
            color=colors["Treino"],
            edgecolor="white",
            linewidth=0.7,
        )

        bars_test = ax.bar(
            x + width / 2,
            test_values,
            width,
            label="Teste forecast",
            color=colors["Teste"],
            edgecolor="white",
            linewidth=0.7,
        )

        ymax = max(max(train_values), max(test_values))
        ax.set_ylim(0, ymax * 1.22)

        fig.suptitle(
            f"{model_name} - lag {lag}: treino vs teste (Overfitting? - {overfitting})",
            fontsize=14,
            fontweight="bold",
            y=0.97,
        )

        fig.legend(
            handles=[bars_train, bars_test],
            labels=["Treino fitted", "Teste forecast"],
            loc="upper center",
            bbox_to_anchor=(0.5, 0.91),
            ncol=2,
            frameon=False,
        )

        ax.set_ylabel("Valor", fontsize=11)
        ax.set_xticks(x)
        ax.set_xticklabels(metric_labels, fontsize=10)
        ax.tick_params(axis="y", labelsize=10)
        ax.grid(axis="y", alpha=0.25)
        ax.set_axisbelow(True)

        for bars in [bars_train, bars_test]:
            labels = [f"{bar.get_height():.2f}" for bar in bars]
            ax.bar_label(
                bars,
                labels=labels,
                padding=3,
                fontsize=9,
                fontweight="bold",
            )

        fig.subplots_adjust(top=0.80)
        plt.show()


plot_top_lag_model_metrics(lag_performance_df_theoretical)

# %%
print(f"Best Theoretical Model by increasing the lags number: {lag_performance_df_theoretical.loc[0, 'model']} with lag {lag_performance_df_theoretical.loc[0, 'lag']} and Overfitting? - {lag_performance_df_theoretical.loc[0, 'Overfitting?']}")
print(f"Best Computational Model by increasing the lags number: {lag_performance_df_computacional.loc[0, 'model']} with lag {lag_performance_df_computacional.loc[0, 'lag']} and Overfitting? - {lag_performance_df_computacional.loc[0, 'Overfitting?']}")
# Out:
# Best Theoretical Model by increasing the lags number: LGBMRegressor with lag 10 and Overfitting? - True
# Best Computational Model by increasing the lags number: Ridge with lag 12 and Overfitting? - True

# %% [markdown]
# ---

# %% [markdown]
# ## **Feature Importance of the Selected Theoretical Model**

# %%
def get_lag_xy(lag, include_target_lag=True, get_features_selected=False):
    lags = []
    for key, values in var_lags.items():
        if key in THEORETICAL_VARIABLES:
            for v in values:
                if v <= lag:
                    lags.append(f"{key}_lag_{v}")

    target_lags = ["inflation_target_lag_1"] if include_target_lag else []
    feature_cols = THEORETICAL_VARIABLES + lags + target_lags
    model_cols = [TARGET_COL] + feature_cols

    train_data = df_train[model_cols].dropna().copy()
    test_data = df_test[model_cols].dropna().copy()

    X_train = train_data[feature_cols]
    y_train = train_data[TARGET_COL]

    X_test = test_data[feature_cols]
    y_test = test_data[TARGET_COL]

    if get_features_selected:
        return X_train, y_train, X_test, y_test, feature_cols
    else:
        return X_train, y_train, X_test, y_test

# %% [markdown]
# **LGBM Model**

# %%
from lightgbm import LGBMRegressor
import pandas as pd
import matplotlib.pyplot as plt

X_train, y_train, X_test, y_test, feature_cols = get_lag_xy(
    lag=10,
    include_target_lag=False,
    get_features_selected=True,
)

lgbm = LGBMRegressor(random_state=RANDOM_STATE, verbose=-1)
lgbm.fit(X_train, y_train)

y_pred_train = lgbm.predict(X_train)
y_pred_test = lgbm.predict(X_test)

train_rmse, train_mae, train_wape = regression_metrics(y_train, y_pred_train)
test_rmse, test_mae, test_wape = regression_metrics(y_test, y_pred_test)

print("Train RMSE:", train_rmse)
print("Train MAE:", train_mae)
print("Train WAPE (%):", train_wape)
print("Test RMSE:", test_rmse)
print("Test MAE:", test_mae)
print("Test WAPE (%):", test_wape)

importance_df = pd.DataFrame({
    "feature": X_train.columns,
    "importance": lgbm.feature_importances_,
})

importance_plot_df = (
    importance_df.sort_values("importance", ascending=False)
    .head(10)
    .sort_values("importance", ascending=True)
)

plt.figure(figsize=(8, 7))
plt.barh(
    importance_plot_df["feature"],
    importance_plot_df["importance"],
    color=colors["Teste"],
)

plt.title("Importância das Variáveis Teóricas - LGBM (lag=10)", fontsize=12, fontweight="bold")
plt.xlabel("Importância", fontsize=10, fontweight="bold")
plt.ylabel("Variáveis")
plt.grid(axis="x", alpha=0.25)
plt.tight_layout()
plt.show()
# Out:
# Train RMSE: 0.19
# Train MAE: 0.11
# Train WAPE (%): 0.04937
# Test RMSE: 0.48
# Test MAE: 0.4
# Test WAPE (%): 0.16222

# %% [markdown]
# ---

# %% [markdown]
# ## **Most Important Variables (Theoretical + Computational)**

# %%
BEST_FEATURES = [
    "PPIPT_ppi",
    "CCI_PT_ea-md",
    "EXPGS_PT_ea-qd",
    "epu_pt_epu_lag_6",
    "PPIPT_ppi_lag_1",
    "HICPNG_PT_ea-md",
   "HICPOV_PT_ea-md",
    "HICPNEF_PT_ea-md",
    "HICPSV_PT_ea-md_lag_12",
    "HICPNEF_PT_ea-md_lag_12",
    "HICPOV_PT_ea-md_lag_12",
    "HICPNG_PT_ea-md_lag_12",
    "inflation_target_lag_1",
    "PCEPI_fred-md",
]

# %%
from sklearn.base import clone

model_cols = [TARGET_COL] + BEST_FEATURES

train_best_data = df_train[model_cols].dropna().copy()
test_best_data = df_test[model_cols].dropna().copy()

common_dates = train_best_data.index.intersection(test_best_data.index)
test_best_data = test_best_data.drop(index=common_dates)

X_train = train_best_data[BEST_FEATURES]
y_train = train_best_data[TARGET_COL]

X_test = test_best_data[BEST_FEATURES]
y_test = test_best_data[TARGET_COL]

print(f"Treino: {X_train.index.min().date()} -> {X_train.index.max().date()} | {len(X_train)} obs")
print(f"Teste:  {X_test.index.min().date()} -> {X_test.index.max().date()} | {len(X_test)} obs")
# Out:
# Treino: 2001-01-01 -> 2023-06-01 | 270 obs
# Teste:  2023-07-01 -> 2025-10-01 | 28 obs

# %%
results = []
predictions = {}

for model_name, model in models.items():
    fitted_model = clone(model)
    fitted_model.fit(X_train, y_train)

    y_pred_train = fitted_model.predict(X_train)
    y_pred_test = fitted_model.predict(X_test)

    train_rmse, train_mae, train_wape = regression_metrics(y_train, y_pred_train)
    test_rmse, test_mae, test_wape = regression_metrics(y_test, y_pred_test)

    results.append({
        "model": model_name,
        "train_rmse": train_rmse,
        "train_mae": train_mae,
        "train_wape": train_wape,
        "test_rmse": test_rmse,
        "test_mae": test_mae,
        "test_wape": test_wape,
        "rmse_increase_pct": relative_error_increase_pct(train_rmse, test_rmse),
        "mae_increase_pct": relative_error_increase_pct(train_mae, test_mae),
        "wape_increase_pct": relative_error_increase_pct(train_wape, test_wape),
        "Overfitting?": has_overfitting(
            [train_rmse, train_mae, train_wape],
            [test_rmse, test_mae, test_wape],
        ),
    })

    predictions[model_name] = pd.DataFrame(
        {"y_true": y_test, "y_pred": y_pred_test},
        index=y_test.index,
    )

best_features_metrics_df = pd.DataFrame(results).sort_values("test_rmse").reset_index(drop=True)
best_features_metrics_df = rank_models_by_average_test_rank(best_features_metrics_df)
display(best_features_metrics_df)
# Out:
#            model  train_rmse  train_mae  train_wape  test_rmse  test_mae  \
# 0          Ridge        0.26       0.20     0.08844       0.36      0.31
# 1  LGBMRegressor        0.22       0.14     0.06394       0.62      0.51
# 2       RF - MAE        0.14       0.10     0.04597       1.55      1.44
# 3       RF - MSE        0.14       0.10     0.04610       2.24      2.06
#
#    test_wape  rmse_increase_pct  mae_increase_pct  wape_increase_pct  \
# 0    0.12630             38.462            55.000             42.809
# 1    0.20788            181.818           264.286            225.117
# 2    0.59089           1007.143          1340.000           1185.382
# 3    0.84567           1500.000          1960.000           1734.425
#
#    Overfitting?  rank_test_rmse  rank_test_mae  rank_test_wape  rank_medio
# 0          True             1.0            1.0             1.0         1.0
# 1          True             2.0            2.0             2.0         2.0
# 2          True             3.0            3.0             3.0         3.0
# 3          True             4.0            4.0             4.0         4.0

# %%
def plot_top_best_model_metrics(best_features_metrics_df, top_n=1):
    top_models = best_features_metrics_df.sort_values("test_rmse").head(top_n).copy()

    metric_labels = ["RMSE", "MAE", "WAPE (%)"]
    train_cols = ["train_rmse", "train_mae", "train_wape"]
    test_cols = ["test_rmse", "test_mae", "test_wape"]

    for _, row in top_models.iterrows():
        model_name = row["model"]
        overfitting = row["Overfitting?"]

        train_values = [row[col] for col in train_cols]
        test_values = [row[col] for col in test_cols]

        x = np.arange(len(metric_labels))
        width = 0.35

        fig, ax = plt.subplots(figsize=(11, 6.5))

        bars_train = ax.bar(
            x - width / 2,
            train_values,
            width,
            label="Treino fitted",
            color=colors["Treino"],
            edgecolor="white",
            linewidth=0.7,
        )

        bars_test = ax.bar(
            x + width / 2,
            test_values,
            width,
            label="Teste forecast",
            color=colors["Teste"],
            edgecolor="white",
            linewidth=0.7,
        )

        ymax = max(max(train_values), max(test_values))
        ax.set_ylim(0, ymax * 1.22)

        fig.suptitle(
            f"{model_name}: treino vs teste (Overfitting? - {overfitting})",
            fontsize=14,
            fontweight="bold",
            y=0.97,
        )

        fig.legend(
            handles=[bars_train, bars_test],
            labels=["Treino fitted", "Teste forecast"],
            loc="upper center",
            bbox_to_anchor=(0.5, 0.91),
            ncol=2,
            frameon=False,
        )

        ax.set_ylabel("Valor", fontsize=11)
        ax.set_xticks(x)
        ax.set_xticklabels(metric_labels, fontsize=10)
        ax.tick_params(axis="y", labelsize=10)
        ax.grid(axis="y", alpha=0.25)
        ax.set_axisbelow(True)

        for bars in [bars_train, bars_test]:
            labels = [f"{bar.get_height():.2f}" for bar in bars]
            ax.bar_label(
                bars,
                labels=labels,
                padding=3,
                fontsize=9,
                fontweight="bold",
            )

        fig.subplots_adjust(top=0.80)
        plt.show()


plot_top_best_model_metrics(best_features_metrics_df, top_n=1)

# %% [markdown]
# ---

# %% [markdown]
# ## **Optimizing the Best Model Achieved**

# %%
import optuna
import numpy as np
from sklearn.linear_model import Ridge

# Split temporal dentro do treino
split_idx = int(len(X_train) * 0.8)
X_tr, X_val = X_train.iloc[:split_idx], X_train.iloc[split_idx:]
y_tr, y_val = y_train.iloc[:split_idx], y_train.iloc[split_idx:]

def objective(trial):
    alpha = trial.suggest_float("alpha", 1e-2, 10.0, log=True)

    model = Ridge(
        alpha=alpha,
        fit_intercept=True,
        random_state=RANDOM_STATE,
    )
    model.fit(X_tr, y_tr)

    y_pred_val = model.predict(X_val)
    val_rmse, val_mae, val_wape = regression_metrics(y_val, y_pred_val)

    trial.set_user_attr("val_rmse", val_rmse)
    trial.set_user_attr("val_mae", val_mae)
    return val_wape

study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=1000, show_progress_bar=False)

print("Best params:", study.best_params)
print("Best validation WAPE (%):", study.best_value)
print("Best validation RMSE:", study.best_trial.user_attrs["val_rmse"])
print("Best validation MAE:", study.best_trial.user_attrs["val_mae"])

best_ridge = Ridge(
    alpha=study.best_params["alpha"],
    fit_intercept=True,
    random_state=RANDOM_STATE,
)
best_ridge.fit(X_train, y_train)

y_pred_train = best_ridge.predict(X_train)
y_pred_test = best_ridge.predict(X_test)

train_rmse, train_mae, train_wape = regression_metrics(y_train, y_pred_train)
test_rmse, test_mae, test_wape = regression_metrics(y_test, y_pred_test)

print("Train RMSE:", train_rmse)
print("Train MAE:", train_mae)
print("Train WAPE (%):", train_wape)
print("Test RMSE:", test_rmse)
print("Test MAE:", test_mae)
print("Test WAPE (%):", test_wape)
print("Overfitting?", has_overfitting(
    [train_rmse, train_mae, train_wape],
    [test_rmse, test_mae, test_wape]
))
# Out:
# [I 2026-05-20 12:30:52,446] A new study created in memory with name: no-name-613e9f31-965f-4fa9-86a4-94b591c170b6
# [I 2026-05-20 12:30:52,460] Trial 0 finished with value: 0.11233 and parameters: {'alpha': 0.7910494376510742}. Best is trial 0 with value: 0.11233.
# [I 2026-05-20 12:30:52,464] Trial 1 finished with value: 0.1068 and parameters: {'alpha': 0.576278310361084}. Best is trial 1 with value: 0.1068.
# [I 2026-05-20 12:30:52,468] Trial 2 finished with value: 0.09777 and parameters: {'alpha': 0.03505058280662424}. Best is trial 2 with value: 0.09777.
# [I 2026-05-20 12:30:52,471] Trial 3 finished with value: 0.08964 and parameters: {'alpha': 0.13346156757263455}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,475] Trial 4 finished with value: 0.11629 and parameters: {'alpha': 0.9527204498515356}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,479] Trial 5 finished with value: 0.09011 and parameters: {'alpha': 0.10621560169898524}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,482] Trial 6 finished with value: 0.16543 and parameters: {'alpha': 8.602962931106484}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,486] Trial 7 finished with value: 0.10355 and parameters: {'alpha': 0.014976468680748301}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,489] Trial 8 finished with value: 0.10244 and parameters: {'alpha': 0.43734975414168853}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,494] Trial 9 finished with value: 0.16296 and parameters: {'alpha': 7.906718464899844}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,505] Trial 10 finished with value: 0.09001 and parameters: {'alpha': 0.10757147878704455}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,511] Trial 11 finished with value: 0.09011 and parameters: {'alpha': 0.10625295245571133}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,516] Trial 12 finished with value: 0.08986 and parameters: {'alpha': 0.11001747858385359}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,521] Trial 13 finished with value: 0.08978 and parameters: {'alpha': 0.1774243452448803}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,526] Trial 14 finished with value: 0.12843 and parameters: {'alpha': 1.7547435287785256}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,530] Trial 15 finished with value: 0.09099 and parameters: {'alpha': 0.21075546391082262}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,536] Trial 16 finished with value: 0.09691 and parameters: {'alpha': 0.040572044084074374}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,541] Trial 17 finished with value: 0.13598 and parameters: {'alpha': 2.639736989855511}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,546] Trial 18 finished with value: 0.09254 and parameters: {'alpha': 0.23873634342478375}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,551] Trial 19 finished with value: 0.09948 and parameters: {'alpha': 0.026501463147870167}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,557] Trial 20 finished with value: 0.09491 and parameters: {'alpha': 0.058922263156402636}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,561] Trial 21 finished with value: 0.08974 and parameters: {'alpha': 0.1756996980884577}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,567] Trial 22 finished with value: 0.09155 and parameters: {'alpha': 0.2217231318627431}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,571] Trial 23 finished with value: 0.09676 and parameters: {'alpha': 0.3131652207911365}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,575] Trial 24 finished with value: 0.09336 and parameters: {'alpha': 0.07310491106377807}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,580] Trial 25 finished with value: 0.10661 and parameters: {'alpha': 0.010172499934270274}. Best is trial 3 with value: 0.08964.
# [I 2026-05-20 12:30:52,585] Trial 26 finished with value: 0.08961 and parameters: {'alpha': 0.1481006490625171}. Best is trial 26 with value: 0.08961.
# [I 2026-05-20 12:30:52,589] Trial 27 finished with value: 0.10302 and parameters: {'alpha': 0.4531205021386366}. Best is trial 26 with value: 0.08961.
# [I 2026-05-20 12:30:52,595] Trial 28 finished with value: 0.09457 and parameters: {'alpha': 0.06177533945532358}. Best is trial 26 with value: 0.08961.
# [I 2026-05-20 12:30:52,600] Trial 29 finished with value: 0.1154 and parameters: {'alpha': 0.9145473941232205}. Best is trial 26 with value: 0.08961.
# [I 2026-05-20 12:30:52,605] Trial 30 finished with value: 0.08973 and parameters: {'alpha': 0.17508417167145823}. Best is trial 26 with value: 0.08961.
# [I 2026-05-20 12:30:52,611] Trial 31 finished with value: 0.08958 and parameters: {'alpha': 0.1528106525739422}. Best is trial 31 with value: 0.08958.
# [I 2026-05-20 12:30:52,616] Trial 32 finished with value: 0.08964 and parameters: {'alpha': 0.13554220788696608}. Best is trial 31 with value: 0.08958.
# [I 2026-05-20 12:30:52,621] Trial 33 finished with value: 0.0995 and parameters: {'alpha': 0.36619917409512087}. Best is trial 31 with value: 0.08958.
# [I 2026-05-20 12:30:52,625] Trial 34 finished with value: 0.10877 and parameters: {'alpha': 0.6560467578484133}. Best is trial 31 with value: 0.08958.
# [I 2026-05-20 12:30:52,629] Trial 35 finished with value: 0.09665 and parameters: {'alpha': 0.04314381679560813}. Best is trial 31 with value: 0.08958.
# [I 2026-05-20 12:30:52,634] Trial 36 finished with value: 0.09962 and parameters: {'alpha': 0.025834103046163823}. Best is trial 31 with value: 0.08958.
# [I 2026-05-20 12:30:52,639] Trial 37 finished with value: 0.09258 and parameters: {'alpha': 0.08084971615780122}. Best is trial 31 with value: 0.08958.
# [I 2026-05-20 12:30:52,644] Trial 38 finished with value: 0.08964 and parameters: {'alpha': 0.1381423459246811}. Best is trial 31 with value: 0.08958.
# [I 2026-05-20 12:30:52,649] Trial 39 finished with value: 0.09735 and parameters: {'alpha': 0.3236226820834016}. Best is trial 31 with value: 0.08958.
# [I 2026-05-20 12:30:52,654] Trial 40 finished with value: 0.08964 and parameters: {'alpha': 0.1419805872875408}. Best is trial 31 with value: 0.08958.
# [I 2026-05-20 12:30:52,659] Trial 41 finished with value: 0.08963 and parameters: {'alpha': 0.13010175545392186}. Best is trial 31 with value: 0.08958.
# [I 2026-05-20 12:30:52,664] Trial 42 finished with value: 0.09189 and parameters: {'alpha': 0.08741130484901764}. Best is trial 31 with value: 0.08958.
# [I 2026-05-20 12:30:52,669] Trial 43 finished with value: 0.08964 and parameters: {'alpha': 0.1358369214190487}. Best is trial 31 with value: 0.08958.
# [I 2026-05-20 12:30:52,674] Trial 44 finished with value: 0.09497 and parameters: {'alpha': 0.2797384149785521}. Best is trial 31 with value: 0.08958.
# [I 2026-05-20 12:30:52,680] Trial 45 finished with value: 0.09463 and parameters: {'alpha': 0.06127257013931197}. Best is trial 31 with value: 0.08958.
# [I 2026-05-20 12:30:52,685] Trial 46 finished with value: 0.10457 and parameters: {'alpha': 0.49985127202789703}. Best is trial 31 with value: 0.08958.
# [I 2026-05-20 12:30:52,689] Trial 47 finished with value: 0.09029 and parameters: {'alpha': 0.10381315767787763}. Best is trial 31 with value: 0.08958.
# [I 2026-05-20 12:30:52,695] Trial 48 finished with value: 0.12172 and parameters: {'alpha': 1.2370762549260568}. Best is trial 31 with value: 0.08958.
# [I 2026-05-20 12:30:52,700] Trial 49 finished with value: 0.09592 and parameters: {'alpha': 0.05007033498184686}. Best is trial 31 with value: 0.08958.
# [I 2026-05-20 12:30:52,706] Trial 50 finished with value: 0.09815 and parameters: {'alpha': 0.03310288635394555}. Best is trial 31 with value: 0.08958.
# [I 2026-05-20 12:30:52,711] Trial 51 finished with value: 0.08978 and parameters: {'alpha': 0.11240616216190978}. Best is trial 31 with value: 0.08958.
# [I 2026-05-20 12:30:52,717] Trial 52 finished with value: 0.08959 and parameters: {'alpha': 0.15263207540484017}. Best is trial 31 with value: 0.08958.
# [I 2026-05-20 12:30:52,721] Trial 53 finished with value: 0.08957 and parameters: {'alpha': 0.1672466423871551}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,727] Trial 54 finished with value: 0.0925 and parameters: {'alpha': 0.23808129616769796}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,731] Trial 55 finished with value: 0.09001 and parameters: {'alpha': 0.18662695507950522}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,736] Trial 56 finished with value: 0.09989 and parameters: {'alpha': 0.3745708726734674}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,741] Trial 57 finished with value: 0.14897 and parameters: {'alpha': 4.674246266192532}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,746] Trial 58 finished with value: 0.09423 and parameters: {'alpha': 0.26622459711225593}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,751] Trial 59 finished with value: 0.08957 and parameters: {'alpha': 0.1641856078354946}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,756] Trial 60 finished with value: 0.09205 and parameters: {'alpha': 0.08584781013857737}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,762] Trial 61 finished with value: 0.08984 and parameters: {'alpha': 0.18101702002967063}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,776] Trial 62 finished with value: 0.0896 and parameters: {'alpha': 0.15071113718014018}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,786] Trial 63 finished with value: 0.08957 and parameters: {'alpha': 0.16217579228576925}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,798] Trial 64 finished with value: 0.08957 and parameters: {'alpha': 0.15718576525295785}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,810] Trial 65 finished with value: 0.09135 and parameters: {'alpha': 0.21809196484794835}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,816] Trial 66 finished with value: 0.09037 and parameters: {'alpha': 0.1027039898375478}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,822] Trial 67 finished with value: 0.0899 and parameters: {'alpha': 0.1833126146628066}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,832] Trial 68 finished with value: 0.10784 and parameters: {'alpha': 0.61612128295846}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,840] Trial 69 finished with value: 0.09362 and parameters: {'alpha': 0.07035659323138709}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,844] Trial 70 finished with value: 0.09965 and parameters: {'alpha': 0.3692495644663888}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,850] Trial 71 finished with value: 0.08959 and parameters: {'alpha': 0.1521850680580562}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,855] Trial 72 finished with value: 0.08957 and parameters: {'alpha': 0.16088867561229706}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,861] Trial 73 finished with value: 0.09529 and parameters: {'alpha': 0.2857875203214009}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,866] Trial 74 finished with value: 0.08967 and parameters: {'alpha': 0.1153471705691784}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,872] Trial 75 finished with value: 0.0912 and parameters: {'alpha': 0.21552807335530108}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,876] Trial 76 finished with value: 0.09123 and parameters: {'alpha': 0.09343688725991353}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,880] Trial 77 finished with value: 0.08957 and parameters: {'alpha': 0.1610692265524579}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,887] Trial 78 finished with value: 0.08961 and parameters: {'alpha': 0.16909343802477356}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,892] Trial 79 finished with value: 0.09238 and parameters: {'alpha': 0.23627888118825577}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,898] Trial 80 finished with value: 0.09318 and parameters: {'alpha': 0.07492744624265116}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,902] Trial 81 finished with value: 0.08957 and parameters: {'alpha': 0.1585454564504576}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,908] Trial 82 finished with value: 0.09073 and parameters: {'alpha': 0.20434879314760357}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,914] Trial 83 finished with value: 0.08962 and parameters: {'alpha': 0.12780631769716752}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,918] Trial 84 finished with value: 0.09679 and parameters: {'alpha': 0.3135568490268136}. Best is trial 53 with value: 0.08957.
# [I 2026-05-20 12:30:52,922] Trial 85 finished with value: 0.08956 and parameters: {'alpha': 0.16479944839093572}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:52,927] Trial 86 finished with value: 0.08962 and parameters: {'alpha': 0.11798576645532553}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:52,933] Trial 87 finished with value: 0.09441 and parameters: {'alpha': 0.26931650402499246}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:52,938] Trial 88 finished with value: 0.08956 and parameters: {'alpha': 0.16617309615509676}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:52,942] Trial 89 finished with value: 0.10306 and parameters: {'alpha': 0.45405329632283103}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:52,948] Trial 90 finished with value: 0.09138 and parameters: {'alpha': 0.09206975837332312}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:52,953] Trial 91 finished with value: 0.08957 and parameters: {'alpha': 0.1625863374401382}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:52,958] Trial 92 finished with value: 0.09059 and parameters: {'alpha': 0.20116711470919033}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:52,963] Trial 93 finished with value: 0.08956 and parameters: {'alpha': 0.16663339015719442}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:52,969] Trial 94 finished with value: 0.09292 and parameters: {'alpha': 0.2444521938440508}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:52,975] Trial 95 finished with value: 0.09028 and parameters: {'alpha': 0.10392671210625334}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:52,980] Trial 96 finished with value: 0.0896 and parameters: {'alpha': 0.12524575746184763}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:52,985] Trial 97 finished with value: 0.09866 and parameters: {'alpha': 0.3486643031794496}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:52,991] Trial 98 finished with value: 0.09024 and parameters: {'alpha': 0.19347376543492906}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:52,995] Trial 99 finished with value: 0.09585 and parameters: {'alpha': 0.050682051518920426}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,001] Trial 100 finished with value: 0.08964 and parameters: {'alpha': 0.13361233878652695}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,006] Trial 101 finished with value: 0.08967 and parameters: {'alpha': 0.17200089530243995}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,011] Trial 102 finished with value: 0.08957 and parameters: {'alpha': 0.16301943304664906}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,016] Trial 103 finished with value: 0.09276 and parameters: {'alpha': 0.24208858751684315}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,021] Trial 104 finished with value: 0.0896 and parameters: {'alpha': 0.15062398002859326}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,027] Trial 105 finished with value: 0.09587 and parameters: {'alpha': 0.29727938587182073}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,032] Trial 106 finished with value: 0.09051 and parameters: {'alpha': 0.1006583648349025}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,038] Trial 107 finished with value: 0.09277 and parameters: {'alpha': 0.07899518260175181}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,042] Trial 108 finished with value: 0.08962 and parameters: {'alpha': 0.11753955746958368}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,047] Trial 109 finished with value: 0.09041 and parameters: {'alpha': 0.1970678164685124}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,052] Trial 110 finished with value: 0.09406 and parameters: {'alpha': 0.06625099529339276}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,057] Trial 111 finished with value: 0.08966 and parameters: {'alpha': 0.17162159708256539}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,063] Trial 112 finished with value: 0.08957 and parameters: {'alpha': 0.16072337609287904}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,067] Trial 113 finished with value: 0.08964 and parameters: {'alpha': 0.13896798990269446}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,073] Trial 114 finished with value: 0.091 and parameters: {'alpha': 0.21092243451016204}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,079] Trial 115 finished with value: 0.09399 and parameters: {'alpha': 0.2620227490717789}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,085] Trial 116 finished with value: 0.08957 and parameters: {'alpha': 0.1647406881545639}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,091] Trial 117 finished with value: 0.0896 and parameters: {'alpha': 0.12458066851204178}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,099] Trial 118 finished with value: 0.10112 and parameters: {'alpha': 0.40373325795839476}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,107] Trial 119 finished with value: 0.09139 and parameters: {'alpha': 0.2187613861895836}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,112] Trial 120 finished with value: 0.08962 and parameters: {'alpha': 0.14690848692250005}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,118] Trial 121 finished with value: 0.09017 and parameters: {'alpha': 0.19201529913261767}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,123] Trial 122 finished with value: 0.08957 and parameters: {'alpha': 0.1617134600097845}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,130] Trial 123 finished with value: 0.08957 and parameters: {'alpha': 0.16308528510596645}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,135] Trial 124 finished with value: 0.09029 and parameters: {'alpha': 0.10385282169499169}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,140] Trial 125 finished with value: 0.08962 and parameters: {'alpha': 0.11805733427776328}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,147] Trial 126 finished with value: 0.09154 and parameters: {'alpha': 0.0906163872811574}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,153] Trial 127 finished with value: 0.08963 and parameters: {'alpha': 0.14271188359446282}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,159] Trial 128 finished with value: 0.09198 and parameters: {'alpha': 0.22950432309408997}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,164] Trial 129 finished with value: 0.08984 and parameters: {'alpha': 0.18120970994771274}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,170] Trial 130 finished with value: 0.09433 and parameters: {'alpha': 0.2680009747157411}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,177] Trial 131 finished with value: 0.08957 and parameters: {'alpha': 0.16296466424685013}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,182] Trial 132 finished with value: 0.08956 and parameters: {'alpha': 0.16589339715474904}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,188] Trial 133 finished with value: 0.09099 and parameters: {'alpha': 0.21074027838347967}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,193] Trial 134 finished with value: 0.08964 and parameters: {'alpha': 0.133483243150147}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,200] Trial 135 finished with value: 0.08972 and parameters: {'alpha': 0.11393858101135153}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,205] Trial 136 finished with value: 0.09011 and parameters: {'alpha': 0.18973829012149723}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,210] Trial 137 finished with value: 0.09697 and parameters: {'alpha': 0.31675003439840643}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,215] Trial 138 finished with value: 0.08961 and parameters: {'alpha': 0.14758472304648204}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,220] Trial 139 finished with value: 0.09224 and parameters: {'alpha': 0.23410806436139978}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,225] Trial 140 finished with value: 0.08977 and parameters: {'alpha': 0.17683742758927723}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,229] Trial 141 finished with value: 0.08957 and parameters: {'alpha': 0.16155150704884508}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,234] Trial 142 finished with value: 0.08963 and parameters: {'alpha': 0.1315932190747929}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,240] Trial 143 finished with value: 0.08957 and parameters: {'alpha': 0.16224526412878584}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,246] Trial 144 finished with value: 0.0904 and parameters: {'alpha': 0.1968741549841982}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,251] Trial 145 finished with value: 0.08999 and parameters: {'alpha': 0.1078905224714073}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,256] Trial 146 finished with value: 0.08961 and parameters: {'alpha': 0.12563570405565894}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,262] Trial 147 finished with value: 0.08961 and parameters: {'alpha': 0.14849065777869286}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,266] Trial 148 finished with value: 0.09114 and parameters: {'alpha': 0.09426579224683461}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,271] Trial 149 finished with value: 0.09363 and parameters: {'alpha': 0.2559112752248089}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,276] Trial 150 finished with value: 0.08972 and parameters: {'alpha': 0.17453156888434457}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,281] Trial 151 finished with value: 0.08957 and parameters: {'alpha': 0.1570199419655758}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,287] Trial 152 finished with value: 0.09013 and parameters: {'alpha': 0.19035852106799223}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,293] Trial 153 finished with value: 0.09185 and parameters: {'alpha': 0.22703828652134905}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,298] Trial 154 finished with value: 0.08964 and parameters: {'alpha': 0.1386112469994034}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,303] Trial 155 finished with value: 0.08956 and parameters: {'alpha': 0.1652678526876795}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,309] Trial 156 finished with value: 0.0896 and parameters: {'alpha': 0.12148111463296246}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,313] Trial 157 finished with value: 0.09093 and parameters: {'alpha': 0.2093534145464276}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,317] Trial 158 finished with value: 0.0897 and parameters: {'alpha': 0.17342526234232958}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,324] Trial 159 finished with value: 0.09517 and parameters: {'alpha': 0.28348017140350734}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,331] Trial 160 finished with value: 0.08981 and parameters: {'alpha': 0.11154539996564851}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,337] Trial 161 finished with value: 0.08957 and parameters: {'alpha': 0.16427358013070326}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,343] Trial 162 finished with value: 0.08962 and parameters: {'alpha': 0.14526659970003972}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,349] Trial 163 finished with value: 0.09018 and parameters: {'alpha': 0.1922381898659004}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,354] Trial 164 finished with value: 0.08964 and parameters: {'alpha': 0.1336647448519737}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,360] Trial 165 finished with value: 0.08957 and parameters: {'alpha': 0.1581768539041135}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,366] Trial 166 finished with value: 0.0914 and parameters: {'alpha': 0.21890262743734976}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,371] Trial 167 finished with value: 0.15013 and parameters: {'alpha': 4.894563008348053}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,377] Trial 168 finished with value: 0.0898 and parameters: {'alpha': 0.1787407525628364}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,382] Trial 169 finished with value: 0.09229 and parameters: {'alpha': 0.08360180671701165}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,388] Trial 170 finished with value: 0.08961 and parameters: {'alpha': 0.12537056122000637}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,393] Trial 171 finished with value: 0.08957 and parameters: {'alpha': 0.16172559557275018}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,399] Trial 172 finished with value: 0.08962 and parameters: {'alpha': 0.14701984496698733}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,405] Trial 173 finished with value: 0.0902 and parameters: {'alpha': 0.1925711640990673}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,410] Trial 174 finished with value: 0.08957 and parameters: {'alpha': 0.16133603306616615}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,416] Trial 175 finished with value: 0.09279 and parameters: {'alpha': 0.24256025509070808}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,421] Trial 176 finished with value: 0.08964 and parameters: {'alpha': 0.13550342067774881}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,426] Trial 177 finished with value: 0.09082 and parameters: {'alpha': 0.20651742105025414}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,432] Trial 178 finished with value: 0.09024 and parameters: {'alpha': 0.10450822369633236}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,437] Trial 179 finished with value: 0.08967 and parameters: {'alpha': 0.17209547962828367}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,442] Trial 180 finished with value: 0.08962 and parameters: {'alpha': 0.11757496062407044}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,448] Trial 181 finished with value: 0.08959 and parameters: {'alpha': 0.1520695274092764}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,453] Trial 182 finished with value: 0.08963 and parameters: {'alpha': 0.1698062367847611}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,458] Trial 183 finished with value: 0.08964 and parameters: {'alpha': 0.13970787656041}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,463] Trial 184 finished with value: 0.09012 and parameters: {'alpha': 0.19012098801912625}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,469] Trial 185 finished with value: 0.08957 and parameters: {'alpha': 0.15685070566719805}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,474] Trial 186 finished with value: 0.08963 and parameters: {'alpha': 0.12939230238048233}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,479] Trial 187 finished with value: 0.09153 and parameters: {'alpha': 0.22122698966552407}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,485] Trial 188 finished with value: 0.08977 and parameters: {'alpha': 0.17695998476377206}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,491] Trial 189 finished with value: 0.0933 and parameters: {'alpha': 0.2506130291939087}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,497] Trial 190 finished with value: 0.09055 and parameters: {'alpha': 0.20037548125615867}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,503] Trial 191 finished with value: 0.08959 and parameters: {'alpha': 0.15232265800134911}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,508] Trial 192 finished with value: 0.08957 and parameters: {'alpha': 0.16719922676140136}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,514] Trial 193 finished with value: 0.08957 and parameters: {'alpha': 0.16478048938238526}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,519] Trial 194 finished with value: 0.0896 and parameters: {'alpha': 0.12246205971972288}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,524] Trial 195 finished with value: 0.08963 and parameters: {'alpha': 0.14339008426476024}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,531] Trial 196 finished with value: 0.09009 and parameters: {'alpha': 0.18906221663818248}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,537] Trial 197 finished with value: 0.10236 and parameters: {'alpha': 0.017199167376260798}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,542] Trial 198 finished with value: 0.09176 and parameters: {'alpha': 0.22539952931058005}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,548] Trial 199 finished with value: 0.08981 and parameters: {'alpha': 0.11156379514077092}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,552] Trial 200 finished with value: 0.08957 and parameters: {'alpha': 0.16314357184127826}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,558] Trial 201 finished with value: 0.08958 and parameters: {'alpha': 0.1533454790103511}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,564] Trial 202 finished with value: 0.08974 and parameters: {'alpha': 0.17532455030943372}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,569] Trial 203 finished with value: 0.08964 and parameters: {'alpha': 0.13481335590284513}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,575] Trial 204 finished with value: 0.09053 and parameters: {'alpha': 0.1997184314593651}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,579] Trial 205 finished with value: 0.08957 and parameters: {'alpha': 0.15537628445072202}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,586] Trial 206 finished with value: 0.08964 and parameters: {'alpha': 0.1379516422699564}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,592] Trial 207 finished with value: 0.08984 and parameters: {'alpha': 0.1812269221777493}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,597] Trial 208 finished with value: 0.09116 and parameters: {'alpha': 0.21481542415412033}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,603] Trial 209 finished with value: 0.08957 and parameters: {'alpha': 0.15900074660031832}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,608] Trial 210 finished with value: 0.08962 and parameters: {'alpha': 0.11741284814540001}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,614] Trial 211 finished with value: 0.08957 and parameters: {'alpha': 0.15808300117984028}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,621] Trial 212 finished with value: 0.0898 and parameters: {'alpha': 0.17886596456080409}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,625] Trial 213 finished with value: 0.08964 and parameters: {'alpha': 0.13736688798806682}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,631] Trial 214 finished with value: 0.08957 and parameters: {'alpha': 0.16017984199655128}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,636] Trial 215 finished with value: 0.09013 and parameters: {'alpha': 0.19050790021279532}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,642] Trial 216 finished with value: 0.08962 and parameters: {'alpha': 0.12795205258197995}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,648] Trial 217 finished with value: 0.09094 and parameters: {'alpha': 0.20952805473577685}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,654] Trial 218 finished with value: 0.0896 and parameters: {'alpha': 0.1504057337657115}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,659] Trial 219 finished with value: 0.09029 and parameters: {'alpha': 0.10379493043004866}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,664] Trial 220 finished with value: 0.08975 and parameters: {'alpha': 0.17592124008156393}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,670] Trial 221 finished with value: 0.08957 and parameters: {'alpha': 0.16350401937363843}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,676] Trial 222 finished with value: 0.08961 and parameters: {'alpha': 0.14898321611657714}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,682] Trial 223 finished with value: 0.08968 and parameters: {'alpha': 0.17231836560194808}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,687] Trial 224 finished with value: 0.08963 and parameters: {'alpha': 0.13123431411340822}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,692] Trial 225 finished with value: 0.09063 and parameters: {'alpha': 0.20219807629411224}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,697] Trial 226 finished with value: 0.09276 and parameters: {'alpha': 0.24203660336793043}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,703] Trial 227 finished with value: 0.08963 and parameters: {'alpha': 0.14278908824211364}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,708] Trial 228 finished with value: 0.08963 and parameters: {'alpha': 0.16997130839498614}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,714] Trial 229 finished with value: 0.08959 and parameters: {'alpha': 0.12319491639950542}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,720] Trial 230 finished with value: 0.09029 and parameters: {'alpha': 0.19439424057699645}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,728] Trial 231 finished with value: 0.08957 and parameters: {'alpha': 0.15639302651507442}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,739] Trial 232 finished with value: 0.08957 and parameters: {'alpha': 0.15424670089154385}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,749] Trial 233 finished with value: 0.0897 and parameters: {'alpha': 0.17331411949387868}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,756] Trial 234 finished with value: 0.08964 and parameters: {'alpha': 0.14028910731623107}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,763] Trial 235 finished with value: 0.09031 and parameters: {'alpha': 0.19484123967906586}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,771] Trial 236 finished with value: 0.12796 and parameters: {'alpha': 1.711262191097211}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,777] Trial 237 finished with value: 0.08957 and parameters: {'alpha': 0.15883479763538264}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,781] Trial 238 finished with value: 0.0896 and parameters: {'alpha': 0.12481091705039327}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,788] Trial 239 finished with value: 0.09141 and parameters: {'alpha': 0.21907496729959203}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,794] Trial 240 finished with value: 0.08975 and parameters: {'alpha': 0.17583013705972889}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,800] Trial 241 finished with value: 0.08957 and parameters: {'alpha': 0.15623512973060985}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,806] Trial 242 finished with value: 0.08956 and parameters: {'alpha': 0.16545634549248395}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,812] Trial 243 finished with value: 0.08963 and parameters: {'alpha': 0.14277369103400714}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,819] Trial 244 finished with value: 0.08995 and parameters: {'alpha': 0.18462293002314023}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,825] Trial 245 finished with value: 0.08961 and parameters: {'alpha': 0.16875824233188694}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,831] Trial 246 finished with value: 0.08964 and parameters: {'alpha': 0.1395586298483935}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,836] Trial 247 finished with value: 0.09073 and parameters: {'alpha': 0.20453893773578066}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,842] Trial 248 finished with value: 0.08957 and parameters: {'alpha': 0.16154607910618224}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,847] Trial 249 finished with value: 0.08962 and parameters: {'alpha': 0.1184570861000807}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,853] Trial 250 finished with value: 0.08999 and parameters: {'alpha': 0.185991093095649}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,858] Trial 251 finished with value: 0.08964 and parameters: {'alpha': 0.14114526076466732}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,864] Trial 252 finished with value: 0.09197 and parameters: {'alpha': 0.22943641044915172}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,870] Trial 253 finished with value: 0.08957 and parameters: {'alpha': 0.15879679448262207}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,877] Trial 254 finished with value: 0.08964 and parameters: {'alpha': 0.13255357801790743}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,884] Trial 255 finished with value: 0.08999 and parameters: {'alpha': 0.18590247926181708}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,892] Trial 256 finished with value: 0.08957 and parameters: {'alpha': 0.1633826094675861}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,898] Trial 257 finished with value: 0.09006 and parameters: {'alpha': 0.1070107473630588}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,904] Trial 258 finished with value: 0.09134 and parameters: {'alpha': 0.21790658951936392}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,910] Trial 259 finished with value: 0.08962 and parameters: {'alpha': 0.14641111337392762}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,916] Trial 260 finished with value: 0.09004 and parameters: {'alpha': 0.18753717289627828}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,922] Trial 261 finished with value: 0.08963 and parameters: {'alpha': 0.17004309918548383}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,926] Trial 262 finished with value: 0.08963 and parameters: {'alpha': 0.1315443913903669}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,933] Trial 263 finished with value: 0.09379 and parameters: {'alpha': 0.2586772192282022}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,939] Trial 264 finished with value: 0.09066 and parameters: {'alpha': 0.20288362678390906}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,945] Trial 265 finished with value: 0.0896 and parameters: {'alpha': 0.14983473512879575}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,950] Trial 266 finished with value: 0.08962 and parameters: {'alpha': 0.11739380667100466}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,956] Trial 267 finished with value: 0.0897 and parameters: {'alpha': 0.17359872998785747}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,960] Trial 268 finished with value: 0.08964 and parameters: {'alpha': 0.13555551888835582}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,965] Trial 269 finished with value: 0.08957 and parameters: {'alpha': 0.15840962169496228}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,971] Trial 270 finished with value: 0.0908 and parameters: {'alpha': 0.20606176118363143}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,978] Trial 271 finished with value: 0.08959 and parameters: {'alpha': 0.1233552798080917}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,984] Trial 272 finished with value: 0.08987 and parameters: {'alpha': 0.18224991430116372}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,990] Trial 273 finished with value: 0.08957 and parameters: {'alpha': 0.1546740497349251}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:53,995] Trial 274 finished with value: 0.09104 and parameters: {'alpha': 0.0951659236983128}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,001] Trial 275 finished with value: 0.09207 and parameters: {'alpha': 0.2312007336692613}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,007] Trial 276 finished with value: 0.0899 and parameters: {'alpha': 0.18321952221228457}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,014] Trial 277 finished with value: 0.16914 and parameters: {'alpha': 9.721237052116361}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,019] Trial 278 finished with value: 0.08963 and parameters: {'alpha': 0.14310088914189123}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,027] Trial 279 finished with value: 0.08957 and parameters: {'alpha': 0.16426295390100398}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,032] Trial 280 finished with value: 0.08978 and parameters: {'alpha': 0.1124520759210599}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,039] Trial 281 finished with value: 0.08964 and parameters: {'alpha': 0.13228076386966753}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,045] Trial 282 finished with value: 0.09083 and parameters: {'alpha': 0.20686725198365646}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,051] Trial 283 finished with value: 0.08961 and parameters: {'alpha': 0.14795727921187585}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,057] Trial 284 finished with value: 0.11222 and parameters: {'alpha': 0.786949512845926}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,063] Trial 285 finished with value: 0.08987 and parameters: {'alpha': 0.18217811987604474}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,068] Trial 286 finished with value: 0.09288 and parameters: {'alpha': 0.2438732319936802}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,074] Trial 287 finished with value: 0.0896 and parameters: {'alpha': 0.16845005043642378}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,079] Trial 288 finished with value: 0.08962 and parameters: {'alpha': 0.1281412517325473}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,085] Trial 289 finished with value: 0.09079 and parameters: {'alpha': 0.20593978554340261}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,092] Trial 290 finished with value: 0.09523 and parameters: {'alpha': 0.28468222042646535}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,099] Trial 291 finished with value: 0.08957 and parameters: {'alpha': 0.1558431361667368}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,104] Trial 292 finished with value: 0.08964 and parameters: {'alpha': 0.14065830009628172}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,109] Trial 293 finished with value: 0.09003 and parameters: {'alpha': 0.1871090566688034}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,115] Trial 294 finished with value: 0.08972 and parameters: {'alpha': 0.11393210640140496}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,120] Trial 295 finished with value: 0.08956 and parameters: {'alpha': 0.16501171231430373}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,126] Trial 296 finished with value: 0.09174 and parameters: {'alpha': 0.22511833186838967}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,132] Trial 297 finished with value: 0.08969 and parameters: {'alpha': 0.17275370269459353}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,137] Trial 298 finished with value: 0.09055 and parameters: {'alpha': 0.20025135189772372}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,143] Trial 299 finished with value: 0.08963 and parameters: {'alpha': 0.1443474352928184}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,148] Trial 300 finished with value: 0.08961 and parameters: {'alpha': 0.12674554725139434}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,154] Trial 301 finished with value: 0.08956 and parameters: {'alpha': 0.16576520402402128}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,159] Trial 302 finished with value: 0.09004 and parameters: {'alpha': 0.1875671111160601}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,164] Trial 303 finished with value: 0.08957 and parameters: {'alpha': 0.15497305345956525}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,170] Trial 304 finished with value: 0.08969 and parameters: {'alpha': 0.17282255777258274}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,177] Trial 305 finished with value: 0.08964 and parameters: {'alpha': 0.13661528557653724}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,182] Trial 306 finished with value: 0.09064 and parameters: {'alpha': 0.0989294930706012}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,188] Trial 307 finished with value: 0.09147 and parameters: {'alpha': 0.2201417543389499}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,193] Trial 308 finished with value: 0.09389 and parameters: {'alpha': 0.2602848955845513}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,199] Trial 309 finished with value: 0.08958 and parameters: {'alpha': 0.1535398069673818}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,207] Trial 310 finished with value: 0.09025 and parameters: {'alpha': 0.19359517399350604}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,212] Trial 311 finished with value: 0.08961 and parameters: {'alpha': 0.12021010052506136}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,218] Trial 312 finished with value: 0.08957 and parameters: {'alpha': 0.1672525366496461}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:54,224] Trial 313 finished with value: 0.08963 and parameters: {'alpha': 0.14313172899830126}. Best is trial 85 with value: 0.08956.
# ...
# [I 2026-05-20 12:30:58,501] Trial 897 finished with value: 0.09141 and parameters: {'alpha': 0.219127417538796}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,512] Trial 898 finished with value: 0.08957 and parameters: {'alpha': 0.15870728040414928}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,525] Trial 899 finished with value: 0.09011 and parameters: {'alpha': 0.18999666293717857}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,539] Trial 900 finished with value: 0.08964 and parameters: {'alpha': 0.13282551378519128}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,549] Trial 901 finished with value: 0.08957 and parameters: {'alpha': 0.16704134037244625}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,559] Trial 902 finished with value: 0.0896 and parameters: {'alpha': 0.15070209938364243}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,574] Trial 903 finished with value: 0.09085 and parameters: {'alpha': 0.20724387485614554}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,583] Trial 904 finished with value: 0.09362 and parameters: {'alpha': 0.2558435505798644}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,591] Trial 905 finished with value: 0.08961 and parameters: {'alpha': 0.12606219741503552}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,598] Trial 906 finished with value: 0.08982 and parameters: {'alpha': 0.17970402376628214}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,605] Trial 907 finished with value: 0.0896 and parameters: {'alpha': 0.1498522020900517}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,613] Trial 908 finished with value: 0.10008 and parameters: {'alpha': 0.37902916223128363}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,621] Trial 909 finished with value: 0.08969 and parameters: {'alpha': 0.1729055430858518}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,630] Trial 910 finished with value: 0.09175 and parameters: {'alpha': 0.22531656200738537}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,637] Trial 911 finished with value: 0.08961 and parameters: {'alpha': 0.11921470143277142}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,645] Trial 912 finished with value: 0.09037 and parameters: {'alpha': 0.19622971429103006}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,653] Trial 913 finished with value: 0.08964 and parameters: {'alpha': 0.1364858019003402}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,660] Trial 914 finished with value: 0.08957 and parameters: {'alpha': 0.15771938075270225}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,669] Trial 915 finished with value: 0.09017 and parameters: {'alpha': 0.1918927409818103}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,677] Trial 916 finished with value: 0.09271 and parameters: {'alpha': 0.07957794792197115}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,684] Trial 917 finished with value: 0.08957 and parameters: {'alpha': 0.16712100707709812}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,692] Trial 918 finished with value: 0.08963 and parameters: {'alpha': 0.14339286783038044}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,699] Trial 919 finished with value: 0.09189 and parameters: {'alpha': 0.22793395943333095}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,707] Trial 920 finished with value: 0.0899 and parameters: {'alpha': 0.10929436943291371}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,716] Trial 921 finished with value: 0.08966 and parameters: {'alpha': 0.17146642821992128}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,724] Trial 922 finished with value: 0.08964 and parameters: {'alpha': 0.1322402542908103}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,736] Trial 923 finished with value: 0.09033 and parameters: {'alpha': 0.1953600940135352}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,746] Trial 924 finished with value: 0.095 and parameters: {'alpha': 0.2801883190734145}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,754] Trial 925 finished with value: 0.08958 and parameters: {'alpha': 0.15376705862710907}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,761] Trial 926 finished with value: 0.08978 and parameters: {'alpha': 0.17771545003906625}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,770] Trial 927 finished with value: 0.09108 and parameters: {'alpha': 0.21298851166325009}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,779] Trial 928 finished with value: 0.08964 and parameters: {'alpha': 0.13607919792011167}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,786] Trial 929 finished with value: 0.08957 and parameters: {'alpha': 0.15629783076237397}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,795] Trial 930 finished with value: 0.08962 and parameters: {'alpha': 0.11775125195125294}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,804] Trial 931 finished with value: 0.09287 and parameters: {'alpha': 0.243717812919394}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,812] Trial 932 finished with value: 0.08989 and parameters: {'alpha': 0.18297058245897682}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,822] Trial 933 finished with value: 0.0896 and parameters: {'alpha': 0.14955379631051252}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,830] Trial 934 finished with value: 0.09034 and parameters: {'alpha': 0.1956832664207054}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,841] Trial 935 finished with value: 0.09055 and parameters: {'alpha': 0.10010763919181978}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,850] Trial 936 finished with value: 0.08963 and parameters: {'alpha': 0.1307362359950498}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,859] Trial 937 finished with value: 0.08956 and parameters: {'alpha': 0.16656014789619275}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,866] Trial 938 finished with value: 0.09125 and parameters: {'alpha': 0.21639835009401487}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,874] Trial 939 finished with value: 0.08972 and parameters: {'alpha': 0.1743824144085706}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,882] Trial 940 finished with value: 0.08956 and parameters: {'alpha': 0.1658814091416301}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,890] Trial 941 finished with value: 0.10417 and parameters: {'alpha': 0.013878759835066418}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,898] Trial 942 finished with value: 0.09085 and parameters: {'alpha': 0.20725843203765879}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,907] Trial 943 finished with value: 0.08963 and parameters: {'alpha': 0.16986308796627372}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,916] Trial 944 finished with value: 0.09259 and parameters: {'alpha': 0.2394024476009634}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,923] Trial 945 finished with value: 0.08958 and parameters: {'alpha': 0.15319043636810567}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,932] Trial 946 finished with value: 0.09013 and parameters: {'alpha': 0.1904718221159561}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,939] Trial 947 finished with value: 0.08957 and parameters: {'alpha': 0.1640923326539636}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,945] Trial 948 finished with value: 0.08964 and parameters: {'alpha': 0.13598175072865004}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,955] Trial 949 finished with value: 0.09052 and parameters: {'alpha': 0.1995577040227297}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,964] Trial 950 finished with value: 0.09476 and parameters: {'alpha': 0.2757654713939958}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,973] Trial 951 finished with value: 0.15436 and parameters: {'alpha': 5.770748406831148}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,981] Trial 952 finished with value: 0.08968 and parameters: {'alpha': 0.17242151432218572}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,989] Trial 953 finished with value: 0.08961 and parameters: {'alpha': 0.14766183118144666}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:58,996] Trial 954 finished with value: 0.09205 and parameters: {'alpha': 0.23080489448553315}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,005] Trial 955 finished with value: 0.0896 and parameters: {'alpha': 0.1215955062847128}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,015] Trial 956 finished with value: 0.09621 and parameters: {'alpha': 0.047333928259680795}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,024] Trial 957 finished with value: 0.09 and parameters: {'alpha': 0.1862121415418275}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,034] Trial 958 finished with value: 0.08957 and parameters: {'alpha': 0.15589000136333772}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,042] Trial 959 finished with value: 0.08964 and parameters: {'alpha': 0.13680851348187384}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,049] Trial 960 finished with value: 0.09088 and parameters: {'alpha': 0.20810685942041185}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,057] Trial 961 finished with value: 0.08967 and parameters: {'alpha': 0.17170327173981317}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,065] Trial 962 finished with value: 0.08958 and parameters: {'alpha': 0.15362750792388316}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,073] Trial 963 finished with value: 0.08968 and parameters: {'alpha': 0.11505520409283991}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,079] Trial 964 finished with value: 0.09005 and parameters: {'alpha': 0.18796675445331806}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,090] Trial 965 finished with value: 0.09205 and parameters: {'alpha': 0.2308834523225127}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,098] Trial 966 finished with value: 0.08964 and parameters: {'alpha': 0.13442596837350762}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,105] Trial 967 finished with value: 0.08956 and parameters: {'alpha': 0.16580332711644588}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,116] Trial 968 finished with value: 0.08957 and parameters: {'alpha': 0.16723305856882412}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,132] Trial 969 finished with value: 0.0905 and parameters: {'alpha': 0.1992182816801878}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,147] Trial 970 finished with value: 0.08962 and parameters: {'alpha': 0.14572913024147388}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,161] Trial 971 finished with value: 0.09355 and parameters: {'alpha': 0.2545979014781659}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,171] Trial 972 finished with value: 0.0898 and parameters: {'alpha': 0.17855258224259338}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,183] Trial 973 finished with value: 0.08957 and parameters: {'alpha': 0.16001717616501998}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,194] Trial 974 finished with value: 0.0896 and parameters: {'alpha': 0.12229250755275478}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,203] Trial 975 finished with value: 0.09107 and parameters: {'alpha': 0.21271135114438572}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,212] Trial 976 finished with value: 0.08964 and parameters: {'alpha': 0.14103576423415107}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,221] Trial 977 finished with value: 0.08976 and parameters: {'alpha': 0.17639664001422023}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,230] Trial 978 finished with value: 0.09022 and parameters: {'alpha': 0.10478968240979525}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,238] Trial 979 finished with value: 0.09824 and parameters: {'alpha': 0.3402071177430141}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,247] Trial 980 finished with value: 0.09037 and parameters: {'alpha': 0.19622705038291594}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,255] Trial 981 finished with value: 0.08957 and parameters: {'alpha': 0.1584516295776897}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,264] Trial 982 finished with value: 0.08963 and parameters: {'alpha': 0.13094853606074752}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,273] Trial 983 finished with value: 0.09133 and parameters: {'alpha': 0.21766915580613524}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,281] Trial 984 finished with value: 0.08978 and parameters: {'alpha': 0.177917097273183}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,289] Trial 985 finished with value: 0.0896 and parameters: {'alpha': 0.1496666271336123}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,298] Trial 986 finished with value: 0.09008 and parameters: {'alpha': 0.1887447909090237}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,307] Trial 987 finished with value: 0.093 and parameters: {'alpha': 0.2457963261232411}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,318] Trial 988 finished with value: 0.08957 and parameters: {'alpha': 0.15751643015342534}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,332] Trial 989 finished with value: 0.08961 and parameters: {'alpha': 0.11880277708451002}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,346] Trial 990 finished with value: 0.08964 and parameters: {'alpha': 0.13652235300385662}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,358] Trial 991 finished with value: 0.08963 and parameters: {'alpha': 0.1698552573387981}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,367] Trial 992 finished with value: 0.09172 and parameters: {'alpha': 0.08896296639849612}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,377] Trial 993 finished with value: 0.09084 and parameters: {'alpha': 0.20714880910331424}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,387] Trial 994 finished with value: 0.08962 and parameters: {'alpha': 0.146738444120049}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,395] Trial 995 finished with value: 0.09551 and parameters: {'alpha': 0.29001070658963934}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,403] Trial 996 finished with value: 0.08986 and parameters: {'alpha': 0.18201288979578778}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,411] Trial 997 finished with value: 0.08957 and parameters: {'alpha': 0.16373932129264526}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,420] Trial 998 finished with value: 0.08961 and parameters: {'alpha': 0.12591883052663}. Best is trial 85 with value: 0.08956.
# [I 2026-05-20 12:30:59,428] Trial 999 finished with value: 0.09105 and parameters: {'alpha': 0.21234313786615183}. Best is trial 85 with value: 0.08956.
# Best params: {'alpha': 0.16479944839093572}
# Best validation WAPE (%): 0.08956
# Best validation RMSE: 0.33
# Best validation MAE: 0.26
# Train RMSE: 0.2
# Train MAE: 0.15
# Train WAPE (%): 0.06924
# Test RMSE: 0.49
# Test MAE: 0.4
# Test WAPE (%): 0.16273
# Overfitting? True

# %% [markdown]
# ---

# %% [markdown]
# ## **Ploting models**

# %%
from sklearn.base import clone
import plotly.graph_objects as go
from IPython.display import HTML, display

def build_model(variables, models=models):
    scores_train = {}
    scores_test = {}
    predictions_test = {}

    model_cols = [TARGET_COL] + variables
    train_data = df_train[model_cols].dropna().copy()
    test_data = df_test[model_cols].dropna().copy()

    common_dates = train_data.index.intersection(test_data.index)
    test_data = test_data.drop(index=common_dates)

    X_train = train_data[variables]
    y_train = train_data[TARGET_COL]

    X_test = test_data[variables]
    y_test = test_data[TARGET_COL]

    for model_name, clf in models.items():
        fitted_model = clone(clf)
        fitted_model.fit(X_train, y_train)

        pred_train = fitted_model.predict(X_train)
        pred_test = fitted_model.predict(X_test)

        scores_train[model_name] = regression_metrics(y_train, pred_train)
        scores_test[model_name] = regression_metrics(y_test, pred_test)
        predictions_test[model_name] = pred_test

    return scores_train, scores_test, predictions_test, models


def plot_predictions(y_true, predictions, models_to_plot=None, title="Previsoes vs Valores Reais"):
    fig = go.Figure()

    fig.add_trace(
        go.Scatter(
            x=y_true.index,
            y=y_true.values,
            mode="lines",
            name="Valores Reais",
            line=dict(color= "#8E9091", width=2.5),
        )
    )

    if models_to_plot is None:
        models_to_plot = list(predictions.keys())

    for model_name in models_to_plot:
        fig.add_trace(
            go.Scatter(
                x=y_true.index,
                y=predictions[model_name],
                mode="lines",
                name=model_name,
                line=dict(width=2),
            )
        )

    fig.update_layout(
        title=dict(text=title, x=0.02),
        xaxis_title="Data",
        yaxis_title="Valor",
        template="plotly_white",
        hovermode="x unified",
        height=560,
        margin=dict(l=50, r=30, t=90, b=80),
        legend=dict(
            orientation="h",
            yanchor="bottom",
            y=1.02,
            xanchor="center",
            x=0.5,
        ),
    )
    fig.update_xaxes(tickangle=-35)

    display(HTML(fig.to_html(full_html=False, include_plotlyjs="cdn")))

# %%
# 1) Em nível
train, test, preds, _ = build_model(THEORETICAL_VARIABLES)
best_model_level = theoretical_metrics_df.iloc[0]["model"]

print(f"Best model in level: {best_model_level}")
plot_predictions(
    df_test[TARGET_COL],
    preds,
    models_to_plot=[best_model_level],
    title=f"Best model in level (Theoretical Features): {best_model_level}",
)

# 2) Desfasamento da variável alvo até lag 3

def performance_to_df(scores_train, scores_test):
    rows = []
    for model_name in scores_train.keys():
        rows.append({
            "model": model_name,
            "train_rmse": scores_train[model_name][0],
            "train_mae": scores_train[model_name][1],
            "train_wape": scores_train[model_name][2],
            "test_rmse": scores_test[model_name][0],
            "test_mae": scores_test[model_name][1],
            "test_wape": scores_test[model_name][2],
        })
    return pd.DataFrame(rows)


target_lags_1 = [f"{TARGET_COL}_lag_1"]
target_lags_2 = [f"{TARGET_COL}_lag_{i}" for i in range(1, 3)]
target_lags_3 = [f"{TARGET_COL}_lag_{i}" for i in range(1, 4)]

train1, test1, preds1, _ = build_model(target_lags_1)
train2, test2, preds2, _ = build_model(target_lags_2)
train3, test3, preds3, _ = build_model(target_lags_3)

perf1 = performance_to_df(train1, test1)
perf2 = performance_to_df(train2, test2)
perf3 = performance_to_df(train3, test3)

rank1 = rank_models_by_average_test_rank(perf1)
rank2 = rank_models_by_average_test_rank(perf2)
rank3 = rank_models_by_average_test_rank(perf3)

best_model_lag1 = rank1.iloc[0]["model"]
best_model_lag2 = rank2.iloc[0]["model"]
best_model_lag3 = rank3.iloc[0]["model"]

preds_target_lags = {
    f"Lag 1 ({best_model_lag1})": preds1[best_model_lag1],
    f"Lag 2 ({best_model_lag2})": preds2[best_model_lag2],
    f"Lag 3 ({best_model_lag3})": preds3[best_model_lag3],
}

print(f"Best model for lag 1: {best_model_lag1}")
print(f"Best model for lag 2: {best_model_lag2}")
print(f"Best model for lag 3: {best_model_lag3}")

plot_predictions(
    df_test[TARGET_COL],
    preds_target_lags,
    models_to_plot=[
        f"Lag 1 ({best_model_lag1})",
        f"Lag 2 ({best_model_lag2})",
        f"Lag 3 ({best_model_lag3})",
    ],
    title="Valores reais vs previsões com lags até 3",
)


# 3) Melhor número de lags teóricas vs melhor número de lags computacionais


best_lag_theoretical = int(lag_performance_df_theoretical.loc[0, "lag"])
best_model_theoretical = lag_performance_df_theoretical.loc[0, "model"]

lags_theoretical = [
    f"{key}_lag_{v}"
    for key, values in var_lags.items()
    if key in THEORETICAL_VARIABLES
    for v in values
    if v <= best_lag_theoretical
]

X_train_theoretical = df_train[THEORETICAL_VARIABLES + lags_theoretical].dropna()
y_train_theoretical = df_train[TARGET_COL].iloc[best_lag_theoretical:]

X_test_theoretical = df_test[THEORETICAL_VARIABLES + lags_theoretical]
pred_theoretical = clone(models[best_model_theoretical]).fit(
    X_train_theoretical, y_train_theoretical
).predict(X_test_theoretical)


best_lag_computacional = int(lag_performance_df_computacional.loc[0, "lag"])
best_model_computacional = lag_performance_df_computacional.loc[0, "model"]

lags_computacional = [
    f"{key}_lag_{v}"
    for key, values in var_lags.items()
    if key in COMPUTACIONAL_VARIABLES
    for v in values
    if v <= best_lag_computacional
]

target_lags = ["inflation_target_lag_1"]

X_train_computacional = df_train[COMPUTACIONAL_VARIABLES + lags_computacional + target_lags].dropna()
y_train_computacional = df_train[TARGET_COL].iloc[best_lag_computacional:]

X_test_computacional = df_test[COMPUTACIONAL_VARIABLES + lags_computacional + target_lags]
pred_computacional = clone(models[best_model_computacional]).fit(
    X_train_computacional, y_train_computacional
).predict(X_test_computacional)


plot_predictions(
    df_test[TARGET_COL],
    {
        f"Teóricas | {best_model_theoretical} | lag {best_lag_theoretical}": pred_theoretical,
        f"Computacionais | {best_model_computacional} | lag {best_lag_computacional}": pred_computacional,
    },
    title="Valores reais vs melhor modelo teórico e melhor modelo computacional",
)

# 4) Best features
# best_model_best_features = best_features_metrics_df.iloc[0]["model"]

# train, test, preds, _ = build_model(BEST_FEATURES)

# print(f"Best model with Most Important Variables: {best_model_best_features}")
# plot_predictions(
#     df_test[TARGET_COL],
#     preds,
#     models_to_plot=[best_model_best_features],
#     title=f"Best model with Most Important Variables: {best_model_best_features}",
# )

train, test, preds, _ = build_model(BEST_FEATURES)

model_cols = [TARGET_COL] + BEST_FEATURES
test_data = df_test[model_cols].dropna().copy()
y_test_local = test_data[TARGET_COL]

top2_models = best_features_metrics_df.iloc[[0, 1]]["model"].tolist()

plot_predictions(
    y_true=y_test_local,
    predictions=preds,
    models_to_plot=top2_models,
    title=f"Top 2 models with Most Important Variables: {', '.join(top2_models)}",
)


train, test, preds, _ = build_model(BEST_FEATURES)

all_models = list(best_features_metrics_df["model"])

plot_predictions(
    df_test[TARGET_COL],
    preds,
    models_to_plot=all_models,
    title="Comparação de todos os modelos com as melhores features",
)
# Out:
# Best model in level: Ridge
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="325dcb24-cb65-4f68-9cf9-dbd46d1569a0" class="plotly-graph-div" style="height:560px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("325dcb24-cb65-4f68-9cf9-dbd46d1569a0")) {                    Plotly.newPlot(                        "325dcb24-cb65-4f68-9cf9-dbd46d1569a0",                        [{"line":{"color":"#8E9091","width":2.5},"mode":"lines","name":"Valores Reais","x":["2023-07-01T00:00:00.000000000","2023-08-01T00:00:00.000000000","2023-09-01T00:00:00.000000000","2023-10-01T00:00:00.000000000","2023-11-01T00:00:00.000000000","2023-12-01T00:00:00.000000000","2024-01-01T00:00:00.000000000","2024-02-01T00:00:00.000000000","2024-03-01T00:00:00.000000000","2024-04-01T00:00:00.000000000","2024-05-01T00:00:00.000000000","2024-06-01T00:00:00.000000000","2024-07-01T00:00:00.000000000","2024-08-01T00:00:00.000000000","2024-09-01T00:00:00.000000000","2024-10-01T00:00:00.000000000","2024-11-01T00:00:00.000000000","2024-12-01T00:00:00.000000000","2025-01-01T00:00:00.000000000","2025-02-01T00:00:00.000000000","2025-03-01T00:00:00.000000000","2025-04-01T00:00:00.000000000","2025-05-01T00:00:00.000000000","2025-06-01T00:00:00.000000000","2025-07-01T00:00:00.000000000","2025-08-01T00:00:00.000000000","2025-09-01T00:00:00.000000000","2025-10-01T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"zczMzMzMCECamZmZmZkNQM3MzMzMzAxAzczMzMzMAEAAAAAAAAD4P2ZmZmZmZvY\u002fZmZmZmZmAkDNzMzMzMwAQGZmZmZmZgJAmpmZmZmZAUDNzMzMzMwIQGZmZmZmZgZAAAAAAAAABEBmZmZmZmb+P83MzMzMzABAZmZmZmZmAkAAAAAAAAAEQAAAAAAAAAhAAAAAAAAABEAzMzMzMzMDQGZmZmZmZv4\u002fzczMzMzMAEBmZmZmZmYCQDMzMzMzMwNAzczMzMzMBEBmZmZmZmYGQDMzMzMzMwNAZmZmZmZmAkA="},"type":"scatter"},{"line":{"width":2},"mode":"lines","name":"Ridge","x":["2023-07-01T00:00:00.000000000","2023-08-01T00:00:00.000000000","2023-09-01T00:00:00.000000000","2023-10-01T00:00:00.000000000","2023-11-01T00:00:00.000000000","2023-12-01T00:00:00.000000000","2024-01-01T00:00:00.000000000","2024-02-01T00:00:00.000000000","2024-03-01T00:00:00.000000000","2024-04-01T00:00:00.000000000","2024-05-01T00:00:00.000000000","2024-06-01T00:00:00.000000000","2024-07-01T00:00:00.000000000","2024-08-01T00:00:00.000000000","2024-09-01T00:00:00.000000000","2024-10-01T00:00:00.000000000","2024-11-01T00:00:00.000000000","2024-12-01T00:00:00.000000000","2025-01-01T00:00:00.000000000","2025-02-01T00:00:00.000000000","2025-03-01T00:00:00.000000000","2025-04-01T00:00:00.000000000","2025-05-01T00:00:00.000000000","2025-06-01T00:00:00.000000000","2025-07-01T00:00:00.000000000","2025-08-01T00:00:00.000000000","2025-09-01T00:00:00.000000000","2025-10-01T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"9g1gXy9oEkBMNArItqwUQAjwdIKP0Q1AUJIz0oxzD0AUnkDLpmMKQDJQ7cXxHg9A08S5Yn1uEUCICAirDjMPQJyT+khN2QxAauuOqXV7DUDIp\u002f9jOT4MQLjI6UHqzAxAFDMLByMZCUDucb+fhJYNQPfB4rdmxANA6pS4uP0sAUBWDombZLYFQLo0upIpTQlAeJHKwc7XBUDoGto\u002f6DUHQBCUITxamQBAbES\u002fJ8LC\u002fj\u002fqYBhYIFj\u002fP5g8+IFHRfs\u002fmD9LdHIz+j9kOFCK+WL8P\u002fBwy1DAcvM\u002faNFa2FGK8j8="},"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"color ...
# Best model for lag 1: Ridge
# Best model for lag 2: RF - MAE
# Best model for lag 3: RF - MAE
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="b42c24f4-4b3f-4d37-973d-f122d8abd087" class="plotly-graph-div" style="height:560px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b42c24f4-4b3f-4d37-973d-f122d8abd087")) {                    Plotly.newPlot(                        "b42c24f4-4b3f-4d37-973d-f122d8abd087",                        [{"line":{"color":"#8E9091","width":2.5},"mode":"lines","name":"Valores Reais","x":["2023-07-01T00:00:00.000000000","2023-08-01T00:00:00.000000000","2023-09-01T00:00:00.000000000","2023-10-01T00:00:00.000000000","2023-11-01T00:00:00.000000000","2023-12-01T00:00:00.000000000","2024-01-01T00:00:00.000000000","2024-02-01T00:00:00.000000000","2024-03-01T00:00:00.000000000","2024-04-01T00:00:00.000000000","2024-05-01T00:00:00.000000000","2024-06-01T00:00:00.000000000","2024-07-01T00:00:00.000000000","2024-08-01T00:00:00.000000000","2024-09-01T00:00:00.000000000","2024-10-01T00:00:00.000000000","2024-11-01T00:00:00.000000000","2024-12-01T00:00:00.000000000","2025-01-01T00:00:00.000000000","2025-02-01T00:00:00.000000000","2025-03-01T00:00:00.000000000","2025-04-01T00:00:00.000000000","2025-05-01T00:00:00.000000000","2025-06-01T00:00:00.000000000","2025-07-01T00:00:00.000000000","2025-08-01T00:00:00.000000000","2025-09-01T00:00:00.000000000","2025-10-01T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"zczMzMzMCECamZmZmZkNQM3MzMzMzAxAzczMzMzMAEAAAAAAAAD4P2ZmZmZmZvY\u002fZmZmZmZmAkDNzMzMzMwAQGZmZmZmZgJAmpmZmZmZAUDNzMzMzMwIQGZmZmZmZgZAAAAAAAAABEBmZmZmZmb+P83MzMzMzABAZmZmZmZmAkAAAAAAAAAEQAAAAAAAAAhAAAAAAAAABEAzMzMzMzMDQGZmZmZmZv4\u002fzczMzMzMAEBmZmZmZmYCQDMzMzMzMwNAzczMzMzMBEBmZmZmZmYGQDMzMzMzMwNAZmZmZmZmAkA="},"type":"scatter"},{"line":{"width":2},"mode":"lines","name":"Lag 1 (Ridge)","x":["2023-07-01T00:00:00.000000000","2023-08-01T00:00:00.000000000","2023-09-01T00:00:00.000000000","2023-10-01T00:00:00.000000000","2023-11-01T00:00:00.000000000","2023-12-01T00:00:00.000000000","2024-01-01T00:00:00.000000000","2024-02-01T00:00:00.000000000","2024-03-01T00:00:00.000000000","2024-04-01T00:00:00.000000000","2024-05-01T00:00:00.000000000","2024-06-01T00:00:00.000000000","2024-07-01T00:00:00.000000000","2024-08-01T00:00:00.000000000","2024-09-01T00:00:00.000000000","2024-10-01T00:00:00.000000000","2024-11-01T00:00:00.000000000","2024-12-01T00:00:00.000000000","2025-01-01T00:00:00.000000000","2025-02-01T00:00:00.000000000","2025-03-01T00:00:00.000000000","2025-04-01T00:00:00.000000000","2025-05-01T00:00:00.000000000","2025-06-01T00:00:00.000000000","2025-07-01T00:00:00.000000000","2025-08-01T00:00:00.000000000","2025-09-01T00:00:00.000000000","2025-10-01T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"DPEDT2AFC0Cc0FKF5asIQHwRtRjbXg1ArAZ61VyWDEB9ZATl9tYAQDlHRKMCSPg\u002fmTHOHAa39j8cenpr82cCQH1kBOX21gBAHHp6a\u002fNnAkBNbz8odZ8BQJzQUoXlqwhALLChu2pSBkC8j\u002fDx7\u002fgDQLmdHL30i\u002f4\u002ffWQE5fbWAEAcenpr82cCQLyP8PHv+ANAzMUXQmfjB0C8j\u002fDx7\u002fgDQOyEta5xMANAuZ0cvfSL\u002fj99ZATl9tYAQBx6emvzZwJA7IS1rnEwA0CNmis1bsEEQCywobtqUgZA7IS1rnEwA0A="},"type":"scatter"},{"line":{"width":2},"mode":"lines","name":"Lag 2 (RF - MAE)","x":["2023-07-01T00:00:00.000000000","2023-08-01T00:00:00.000000000","2023-09-01T00:00:00.000000000","2023-10-01T00:00:00.000000000","2023-11-01T00:00:00.000000000","2023-12-01T00:00:00.000000000","2024-01-01T00:00:00.000000000","2024-02-01T00:00:00.000000000","2024-03-01T00:00:00.000000000","2024-04-01T00:00:00.000000000","2024-05-01T00:00:00.000000000","2024-06-01T00:00:00.000000000","2024-07-01T00:00:00.000000000","2024-08-01T00:00:00.000000000","2024-09-01T00:00:00.000000000","2024-10-01T00:00:00.000000000","2024-11-01T00:00:00.000000000","2024-12-01T00:00:00.000000000","2025-01-01T00:00:00.000000000","2025-02 ...
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="f2f69dbb-9855-4511-a521-3c9b888950b3" class="plotly-graph-div" style="height:560px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f2f69dbb-9855-4511-a521-3c9b888950b3")) {                    Plotly.newPlot(                        "f2f69dbb-9855-4511-a521-3c9b888950b3",                        [{"line":{"color":"#8E9091","width":2.5},"mode":"lines","name":"Valores Reais","x":["2023-07-01T00:00:00.000000000","2023-08-01T00:00:00.000000000","2023-09-01T00:00:00.000000000","2023-10-01T00:00:00.000000000","2023-11-01T00:00:00.000000000","2023-12-01T00:00:00.000000000","2024-01-01T00:00:00.000000000","2024-02-01T00:00:00.000000000","2024-03-01T00:00:00.000000000","2024-04-01T00:00:00.000000000","2024-05-01T00:00:00.000000000","2024-06-01T00:00:00.000000000","2024-07-01T00:00:00.000000000","2024-08-01T00:00:00.000000000","2024-09-01T00:00:00.000000000","2024-10-01T00:00:00.000000000","2024-11-01T00:00:00.000000000","2024-12-01T00:00:00.000000000","2025-01-01T00:00:00.000000000","2025-02-01T00:00:00.000000000","2025-03-01T00:00:00.000000000","2025-04-01T00:00:00.000000000","2025-05-01T00:00:00.000000000","2025-06-01T00:00:00.000000000","2025-07-01T00:00:00.000000000","2025-08-01T00:00:00.000000000","2025-09-01T00:00:00.000000000","2025-10-01T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"zczMzMzMCECamZmZmZkNQM3MzMzMzAxAzczMzMzMAEAAAAAAAAD4P2ZmZmZmZvY\u002fZmZmZmZmAkDNzMzMzMwAQGZmZmZmZgJAmpmZmZmZAUDNzMzMzMwIQGZmZmZmZgZAAAAAAAAABEBmZmZmZmb+P83MzMzMzABAZmZmZmZmAkAAAAAAAAAEQAAAAAAAAAhAAAAAAAAABEAzMzMzMzMDQGZmZmZmZv4\u002fzczMzMzMAEBmZmZmZmYCQDMzMzMzMwNAzczMzMzMBEBmZmZmZmYGQDMzMzMzMwNAZmZmZmZmAkA="},"type":"scatter"},{"line":{"width":2},"mode":"lines","name":"Te\u00f3ricas | LGBMRegressor | lag 10","x":["2023-07-01T00:00:00.000000000","2023-08-01T00:00:00.000000000","2023-09-01T00:00:00.000000000","2023-10-01T00:00:00.000000000","2023-11-01T00:00:00.000000000","2023-12-01T00:00:00.000000000","2024-01-01T00:00:00.000000000","2024-02-01T00:00:00.000000000","2024-03-01T00:00:00.000000000","2024-04-01T00:00:00.000000000","2024-05-01T00:00:00.000000000","2024-06-01T00:00:00.000000000","2024-07-01T00:00:00.000000000","2024-08-01T00:00:00.000000000","2024-09-01T00:00:00.000000000","2024-10-01T00:00:00.000000000","2024-11-01T00:00:00.000000000","2024-12-01T00:00:00.000000000","2025-01-01T00:00:00.000000000","2025-02-01T00:00:00.000000000","2025-03-01T00:00:00.000000000","2025-04-01T00:00:00.000000000","2025-05-01T00:00:00.000000000","2025-06-01T00:00:00.000000000","2025-07-01T00:00:00.000000000","2025-08-01T00:00:00.000000000","2025-09-01T00:00:00.000000000","2025-10-01T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"eiqOwTPEBUA3QxBt\u002fMEEQK5x9G5BJANAnQo5l8QAAUARcr+bvVj9PyEWB4djIfw\u002fg2Zp2hGh\u002fz+SVexe+87\u002fP8EIUbIHcQBAIdozJdv9\u002fz+e\u002fEaawhwDQCn6NJIqrAJAAGFNz6cwBECHQs27lgUEQCQV9alhNgVAK8DEQncqBUBZaD23pRYGQEjcWdXHGwZAXOJ2JaCiBkANgFOwVw0GQOsL53KV3AJAP1zIPzTgAkCB6ayOWsoBQKbe6THm+gBAPOoQzSFKAECcoVTykOAAQLsMvU\u002fnngBAuRfeWDp3AEA="},"type":"scatter"},{"line":{"width":2},"mode":"lines","name":"Computacionais | Ridge | lag 12","x":["2023-07-01T00:00:00.000000000","2023-08-01T00:00:00.000000000","2023-09-01T00:00:00.000000000","2023-10-01T00:00:00.000000000","2023-11-01T00:00:00.000000000","2023-12-01T00:00:00.000000000","2024-01-01T00:00:00.000000000","2024-02-01T00:00:00.000000000","2024-03-01T00:00:00.000000000","2024-04-01T00:00:00.000000000","2024-05-01T00:00:00.000000000","2024-06-01T00:00:00.000000000","2024-07-01T00:00:00.000000000","2024-08-01T00:00:00.000000000","2024-09-01T00:00:00.000000000","2024-10-01T00:00:00.000000000","2024-11-01T00:00:00.000000000","2024-12-01T00:00:00.000000000","2025-01-0 ...
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="8504b23b-1515-420d-9c30-c93b76f53943" class="plotly-graph-div" style="height:560px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8504b23b-1515-420d-9c30-c93b76f53943")) {                    Plotly.newPlot(                        "8504b23b-1515-420d-9c30-c93b76f53943",                        [{"line":{"color":"#8E9091","width":2.5},"mode":"lines","name":"Valores Reais","x":["2023-07-01T00:00:00.000000000","2023-08-01T00:00:00.000000000","2023-09-01T00:00:00.000000000","2023-10-01T00:00:00.000000000","2023-11-01T00:00:00.000000000","2023-12-01T00:00:00.000000000","2024-01-01T00:00:00.000000000","2024-02-01T00:00:00.000000000","2024-03-01T00:00:00.000000000","2024-04-01T00:00:00.000000000","2024-05-01T00:00:00.000000000","2024-06-01T00:00:00.000000000","2024-07-01T00:00:00.000000000","2024-08-01T00:00:00.000000000","2024-09-01T00:00:00.000000000","2024-10-01T00:00:00.000000000","2024-11-01T00:00:00.000000000","2024-12-01T00:00:00.000000000","2025-01-01T00:00:00.000000000","2025-02-01T00:00:00.000000000","2025-03-01T00:00:00.000000000","2025-04-01T00:00:00.000000000","2025-05-01T00:00:00.000000000","2025-06-01T00:00:00.000000000","2025-07-01T00:00:00.000000000","2025-08-01T00:00:00.000000000","2025-09-01T00:00:00.000000000","2025-10-01T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"zczMzMzMCECamZmZmZkNQM3MzMzMzAxAzczMzMzMAEAAAAAAAAD4P2ZmZmZmZvY\u002fZmZmZmZmAkDNzMzMzMwAQGZmZmZmZgJAmpmZmZmZAUDNzMzMzMwIQGZmZmZmZgZAAAAAAAAABEBmZmZmZmb+P83MzMzMzABAZmZmZmZmAkAAAAAAAAAEQAAAAAAAAAhAAAAAAAAABEAzMzMzMzMDQGZmZmZmZv4\u002fzczMzMzMAEBmZmZmZmYCQDMzMzMzMwNAzczMzMzMBEBmZmZmZmYGQDMzMzMzMwNAZmZmZmZmAkA="},"type":"scatter"},{"line":{"width":2},"mode":"lines","name":"Ridge","x":["2023-07-01T00:00:00.000000000","2023-08-01T00:00:00.000000000","2023-09-01T00:00:00.000000000","2023-10-01T00:00:00.000000000","2023-11-01T00:00:00.000000000","2023-12-01T00:00:00.000000000","2024-01-01T00:00:00.000000000","2024-02-01T00:00:00.000000000","2024-03-01T00:00:00.000000000","2024-04-01T00:00:00.000000000","2024-05-01T00:00:00.000000000","2024-06-01T00:00:00.000000000","2024-07-01T00:00:00.000000000","2024-08-01T00:00:00.000000000","2024-09-01T00:00:00.000000000","2024-10-01T00:00:00.000000000","2024-11-01T00:00:00.000000000","2024-12-01T00:00:00.000000000","2025-01-01T00:00:00.000000000","2025-02-01T00:00:00.000000000","2025-03-01T00:00:00.000000000","2025-04-01T00:00:00.000000000","2025-05-01T00:00:00.000000000","2025-06-01T00:00:00.000000000","2025-07-01T00:00:00.000000000","2025-08-01T00:00:00.000000000","2025-09-01T00:00:00.000000000","2025-10-01T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"AhBzCdE8B0BEftX4YgkKQHB+CLOQBw1Aky0WbUEgB0A81QuQ06j5PzCbqilfk\u002fU\u002fZDr+bPLi\u002fj91Dg\u002fUtm0FQCCL3YdWlgRA8GN1Ahd7BUAwBev2B9YGQPwjF7Zi8QpAzHGpjAz6BUC4\u002fSyqNVkAQOrX5MDutfs\u002fQLgNPXQzAUAiWzpVhf4DQJkSk8rewwZA8hS6feolCEDV34XURsMDQEyOaVrljwBAIAh3PL8d\u002fT\u002f8GSYnMvT8P7DHIWflgwBA87vT52z\u002fAUBcArV3p\u002fABQKqKqi5xTgFA\u002fkGWnF5U\u002fj8="},"type":"scatter"},{"line":{"width":2},"mode":"lines","name":"LGBMRegressor","x":["2023-07-01T00:00:00.000000000","2023-08-01T00:00:00.000000000","2023-09-01T00:00:00.000000000","2023-10-01T00:00:00.000000000","2023-11-01T00:00:00.000000000","2023-12-01T00:00:00.000000000","2024-01-01T00:00:00.000000000","2024-02-01T00:00:00.000000000","2024-03-01T00:00:00.000000000","2024-04-01T00:00:00.000000000","2024-05-01T00:00:00.000000000","2024-06-01T00:00:00.000000000","2024-07-01T00:00:00.000000000","2024-08-01T00:00:00.000000000","2024-09-01T00:00:00.000000000","2024-10-01T00:00:00.000000000","2024-11-01T00:00:00.000000000","2024-12-01T00:00:00.000000000","2025-01-01T00:00:00.000000000","202 ...
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="e558248d-f6f8-4eba-a6bc-0c63215b9c10" class="plotly-graph-div" style="height:560px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e558248d-f6f8-4eba-a6bc-0c63215b9c10")) {                    Plotly.newPlot(                        "e558248d-f6f8-4eba-a6bc-0c63215b9c10",                        [{"line":{"color":"#8E9091","width":2.5},"mode":"lines","name":"Valores Reais","x":["2023-07-01T00:00:00.000000000","2023-08-01T00:00:00.000000000","2023-09-01T00:00:00.000000000","2023-10-01T00:00:00.000000000","2023-11-01T00:00:00.000000000","2023-12-01T00:00:00.000000000","2024-01-01T00:00:00.000000000","2024-02-01T00:00:00.000000000","2024-03-01T00:00:00.000000000","2024-04-01T00:00:00.000000000","2024-05-01T00:00:00.000000000","2024-06-01T00:00:00.000000000","2024-07-01T00:00:00.000000000","2024-08-01T00:00:00.000000000","2024-09-01T00:00:00.000000000","2024-10-01T00:00:00.000000000","2024-11-01T00:00:00.000000000","2024-12-01T00:00:00.000000000","2025-01-01T00:00:00.000000000","2025-02-01T00:00:00.000000000","2025-03-01T00:00:00.000000000","2025-04-01T00:00:00.000000000","2025-05-01T00:00:00.000000000","2025-06-01T00:00:00.000000000","2025-07-01T00:00:00.000000000","2025-08-01T00:00:00.000000000","2025-09-01T00:00:00.000000000","2025-10-01T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"zczMzMzMCECamZmZmZkNQM3MzMzMzAxAzczMzMzMAEAAAAAAAAD4P2ZmZmZmZvY\u002fZmZmZmZmAkDNzMzMzMwAQGZmZmZmZgJAmpmZmZmZAUDNzMzMzMwIQGZmZmZmZgZAAAAAAAAABEBmZmZmZmb+P83MzMzMzABAZmZmZmZmAkAAAAAAAAAEQAAAAAAAAAhAAAAAAAAABEAzMzMzMzMDQGZmZmZmZv4\u002fzczMzMzMAEBmZmZmZmYCQDMzMzMzMwNAzczMzMzMBEBmZmZmZmYGQDMzMzMzMwNAZmZmZmZmAkA="},"type":"scatter"},{"line":{"width":2},"mode":"lines","name":"Ridge","x":["2023-07-01T00:00:00.000000000","2023-08-01T00:00:00.000000000","2023-09-01T00:00:00.000000000","2023-10-01T00:00:00.000000000","2023-11-01T00:00:00.000000000","2023-12-01T00:00:00.000000000","2024-01-01T00:00:00.000000000","2024-02-01T00:00:00.000000000","2024-03-01T00:00:00.000000000","2024-04-01T00:00:00.000000000","2024-05-01T00:00:00.000000000","2024-06-01T00:00:00.000000000","2024-07-01T00:00:00.000000000","2024-08-01T00:00:00.000000000","2024-09-01T00:00:00.000000000","2024-10-01T00:00:00.000000000","2024-11-01T00:00:00.000000000","2024-12-01T00:00:00.000000000","2025-01-01T00:00:00.000000000","2025-02-01T00:00:00.000000000","2025-03-01T00:00:00.000000000","2025-04-01T00:00:00.000000000","2025-05-01T00:00:00.000000000","2025-06-01T00:00:00.000000000","2025-07-01T00:00:00.000000000","2025-08-01T00:00:00.000000000","2025-09-01T00:00:00.000000000","2025-10-01T00:00:00.000000000"],"y":{"dtype":"f8","bdata":"AhBzCdE8B0BEftX4YgkKQHB+CLOQBw1Aky0WbUEgB0A81QuQ06j5PzCbqilfk\u002fU\u002fZDr+bPLi\u002fj91Dg\u002fUtm0FQCCL3YdWlgRA8GN1Ahd7BUAwBev2B9YGQPwjF7Zi8QpAzHGpjAz6BUC4\u002fSyqNVkAQOrX5MDutfs\u002fQLgNPXQzAUAiWzpVhf4DQJkSk8rewwZA8hS6feolCEDV34XURsMDQEyOaVrljwBAIAh3PL8d\u002fT\u002f8GSYnMvT8P7DHIWflgwBA87vT52z\u002fAUBcArV3p\u002fABQKqKqi5xTgFA\u002fkGWnF5U\u002fj8="},"type":"scatter"},{"line":{"width":2},"mode":"lines","name":"LGBMRegressor","x":["2023-07-01T00:00:00.000000000","2023-08-01T00:00:00.000000000","2023-09-01T00:00:00.000000000","2023-10-01T00:00:00.000000000","2023-11-01T00:00:00.000000000","2023-12-01T00:00:00.000000000","2024-01-01T00:00:00.000000000","2024-02-01T00:00:00.000000000","2024-03-01T00:00:00.000000000","2024-04-01T00:00:00.000000000","2024-05-01T00:00:00.000000000","2024-06-01T00:00:00.000000000","2024-07-01T00:00:00.000000000","2024-08-01T00:00:00.000000000","2024-09-01T00:00:00.000000000","2024-10-01T00:00:00.000000000","2024-11-01T00:00:00.000000000","2024-12-01T00:00:00.000000000","2025-01-01T00:00:00.000000000","202 ...
